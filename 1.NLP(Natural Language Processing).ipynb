# %%
NLP : 
is the art and science which helps us extract information from text and use it in our computations and algorithms. 

Data Science -- usig data to make decisions.

# %% [markdown]
# #### Parts :

# %%
1.Tokenization                                                                                                            
2.Stopwords                                                                                                                  
3.Stemming                                                                                                                   
4.Lemmatisation                                                                                                             
5.Part-of-Speech Tagging                                                                                                    
6.Chunking , Chinking                                                                                                         
7.Named Entity Recognition                                                                                                    

8.Word Embeddings : 
types : 1.Count vectorizer, 2.TF-IDF, 3.Co-Occurrence matrix, 4.Word2Vec (1.CBOW, 2.Skip-Gram)  
5.Glove (Global Vectors for Word Representation) its pre-trained , 6.FastText.

# %%
Applications : 

1.Sentiment Analysis, 2.Topic Modeling, 3.Text Generation, 4.Chatbot, 5.Speech Recognition, 6.Machine Translator, 7.Spell check
8.Information extraction(Retrieval), 9.Keyword Search, 10.Advertisement matching, 11.Document Clustering

# %%
corpus or text corpus : 
is a large and structured set of texts, they are used to do statistical analysis and hypothesis testing,
checking occurrences or validating linguistic rules within a specific language territory.

# %% [markdown]
# ## -----------------------

# %% [markdown]
# ## 1. Tokenization :

# %%
a.Break a complex sentence into words                                                                                
b.Understand the importance of each  word w.r.t. the sentence                                                           
c.Produce a structural description on an input sentence                                                                 
d.It has Bigrams(Token of two consecutive written words), Trigrams(3 consecutive words), Ngrams(n no. of consecutive words)

# %%
# Tokenizing -- is form of grouping things
# corpora -- is body of text (ex: medical journals, presidential speeches)

# lexicon -- words and their meanings like : dict but in different fields 
# (ex: investor speak 'bull' - means bullish ,someone who is positive about the market )
# (ex: person speak 'bull' in english 'bull' , means animal)

# %% [markdown]
# ##### Implementation

# %%
import nltk                                                                      # nltk.download() 
from nltk.tokenize import sent_tokenize, word_tokenize

example_text = '''Hello Mr. Smith, how are you doing today? 
                The weather is great and The Python is awesome. The sky is pink-bluish'''

print(sent_tokenize(example_text))               # simply print

for i in word_tokenize(example_text):            # or use like for loop 
    print(i)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great and The Python is awesome.', 'The sky is pink-bluish']
# Hello
# Mr.
# Smith
# ,
# how
# are
# you
# doing
# today
# ?
# The
# weather
# is
# great
# and
# The
# Python
# is
# awesome
# .
# The
# sky
# is
# pink-bluish

# %%
import os                                       # Using corpora folder
import nltk
import nltk.corpus                         

print(nltk.__file__)    # it shows file loc. for init file of corpora folder
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\__init__.py

# %%
# shows all files of corpora folder, we can use files for analysis & text

print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_tagged.zip', 'movie_reviews', 'movie_reviews.zip', 'mte_teip5', 'mte_teip5.zip', 'names', 'names.zip', 'nombank.1.0.zip', 'nonbreaking_prefixes', 'nonbreaking_prefixes.zip', 'nps_chat', 'nps_chat.zip', 'omw', 'omw.zip', 'opinion_lexicon', 'opinion_lexicon.zip', 'panlex_swadesh.zip', 'paradigms', 'paradigms.zip', 'pil', 'pil.zip', 'pl196x', 'pl196x.zip', 'ppattach', 'ppattach.zip', 'problem_reports', 'problem_reports.zip', 'product_reviews_1', 'product_reviews_1.zip', 'product_reviews_2', 'product_reviews_2.zip', 'propbank.zip', 'pros_cons', 'pros_cons.zip', 'ptb', 'ptb.zip', 'qc', 'qc.zip', 'reuters.zip', 'rte', 'rte.zip', 'semcor.zip', 'senseval', 'senseval.zip', 'sentence_polarity', 'sentence_polarity.zip', 'sentiwordnet', 'sentiwordnet.zip', 'shakespeare', 'shakespeare.zip', 'sinica_treebank', 'sinica_treebank.zip', 'smultron', 'smultron.zip', 'state_union', 'state_union.zip', 'stopwords', 'stopwords.zip', 'subjectivity', 'subjectivity.zip', 'swadesh', 'swadesh.zip', 'switchboard', 'switchboard.zip', 'timit', 'timit.zip', 'toolbox', 'toolbox.zip', 'treebank', 'treebank.zip', 'twitter_samples', 'twitter_samples.zip', 'udhr', 'udhr.zip', 'udhr2', 'udhr2.zip', 'unicode_samples', 'unicode_samples.zip', 'universal_treebanks_v20.zip', 'verbnet', 'verbnet.zip', 'verbnet3', 'verbnet3.zip', 'webtext', 'webtext.zip', 'wordnet', 'wordnet.zip', 'wordnet_ic', 'wordnet_ic.zip', 'words', 'words.zip', 'ycoe', 'ycoe.zip']

# %%
# gives all files of gutenberg folder from corpora

nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
hamlet = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')   # givses elments of file
hamlet
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
for word in hamlet[:500]:                 # taking 1st 500 words
    print(word, sep=' ', end=' ')
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Barnardo and Francisco two Centinels . Barnardo . Who ' s there ? Fran . Nay answer me : Stand & vnfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran . Not a Mouse stirring Barn . Well , goodnight . If you do meet Horatio and Marcellus , the Riuals of my Watch , bid them make hast . Enter Horatio and Marcellus . Fran . I thinke I heare them . Stand : who ' s there ? Hor . Friends to this ground Mar . And Leige - men to the Dane Fran . Giue you good night Mar . O farwel honest Soldier , who hath relieu ' d you ? Fra . Barnardo ha ' s my place : giue you goodnight . Exit Fran . Mar . Holla Barnardo Bar . Say , what is Horatio there ? Hor . A peece of him Bar . Welcome Horatio , welcome good Marcellus Mar . What , ha ' s this thing appear ' d againe to night Bar . I haue seene nothing Mar . Horatio saies , ' tis but our Fantasie , And will not let beleefe take hold of him Touching this dreaded sight , twice seene of vs , Therefore I haue intreated him along With vs , to watch the minutes of this Night , That if againe this Apparition come , He may approue our eyes , and speake to it Hor . Tush , tush , ' twill not appeare Bar . Sit downe a - while , And let vs once againe assaile your eares , That are so fortified against our Story , What we two Nights haue seene Hor . Well , sit we downe , And let vs heare Barnardo speake of this Barn . Last night of all , When yond same Starre that ' s Westward from the Pole Had made his course t ' illume that part of Heauen Where now it burnes , Marcellus and my selfe , The Bell then beating one Mar . Peace , breake thee of : Enter the Ghost . Looke where it comes againe Barn . In the same figure , like the King that ' s dead Mar . Thou art a Scholler ; speake to it Horatio Barn . Lookes it not like the King ? Marke it Horatio Hora . Most like : It harrowes me with fear & wonder Barn . It would be spoke too Mar . Question it Horatio Hor . What art

# %%
from nltk.tokenize import word_tokenize

hamlet_tokens = word_tokenize(str(hamlet[:20]))
# hamlet_tokens
len(hamlet_tokens)
# Out:
# 65

# %%
from nltk.probability import FreqDist      # frquency distribution
fdist = FreqDist()                      # finding wordcount of all words in the paragraph

# %%
for word in hamlet_tokens:
    fdist[word.lower()]+=1          # wordcount of all words
fdist
# Out:
# FreqDist({"'": 24, ',': 19, '[': 2, ']': 2, '.': 2, "'the": 1, "'tragedie": 1, "'of": 1, "'hamlet": 1, "'by": 1, ...})

# %%
fdist_top10 = fdist.most_common(10)           # gives most common words used
fdist_top10
# Out:
# [("'", 24),
#  (',', 19),
#  ('[', 2),
#  (']', 2),
#  ('.', 2),
#  ("'the", 1),
#  ("'tragedie", 1),
#  ("'of", 1),
#  ("'hamlet", 1),
#  ("'by", 1)]

# %%
from nltk.tokenize import blankline_tokenize

hamlet_blank = blankline_tokenize(str(hamlet))     
len(hamlet_blank)        # gives how many paragraph we have and what all paragraphs are separated by new line
# Out:
# 1

# %%
from nltk.util import bigrams, trigrams, ngrams

string = "The best and most beautiful thing in the world can not be seen or touched, they must be felt with the heart."
quote_tokens = nltk.word_tokenize(string)          
print('tokenization : ', quote_tokens)                                          # 1. we tokenize into words
print(50*"-")

quote_bigrams = list(nltk.bigrams(quote_tokens))          # 2. making bigrams of it , it is in list form so using list
print('Bigrams : ', quote_bigrams)
print(50*"-")

quote_trigrams = list(nltk.trigrams(quote_tokens))      # 3. making trigrams of it  
print('trigrams : ', quote_trigrams)
print(50*"-")

quote_ngrams = list(nltk.ngrams(quote_tokens, 4))      # 3. ngrams , we have to give no. for N like here we use 4 here(any no.) 
print('ngrams : ', quote_ngrams)
print(50*"-")
# Out:
# tokenization :  ['The', 'best', 'and', 'most', 'beautiful', 'thing', 'in', 'the', 'world', 'can', 'not', 'be', 'seen', 'or', 'touched', ',', 'they', 'must', 'be', 'felt', 'with', 'the', 'heart', '.']
# --------------------------------------------------
# Bigrams :  [('The', 'best'), ('best', 'and'), ('and', 'most'), ('most', 'beautiful'), ('beautiful', 'thing'), ('thing', 'in'), ('in', 'the'), ('the', 'world'), ('world', 'can'), ('can', 'not'), ('not', 'be'), ('be', 'seen'), ('seen', 'or'), ('or', 'touched'), ('touched', ','), (',', 'they'), ('they', 'must'), ('must', 'be'), ('be', 'felt'), ('felt', 'with'), ('with', 'the'), ('the', 'heart'), ('heart', '.')]
# --------------------------------------------------
# trigrams :  [('The', 'best', 'and'), ('best', 'and', 'most'), ('and', 'most', 'beautiful'), ('most', 'beautiful', 'thing'), ('beautiful', 'thing', 'in'), ('thing', 'in', 'the'), ('in', 'the', 'world'), ('the', 'world', 'can'), ('world', 'can', 'not'), ('can', 'not', 'be'), ('not', 'be', 'seen'), ('be', 'seen', 'or'), ('seen', 'or', 'touched'), ('or', 'touched', ','), ('touched', ',', 'they'), (',', 'they', 'must'), ('they', 'must', 'be'), ('must', 'be', 'felt'), ('be', 'felt', 'with'), ('felt', 'with', 'the'), ('with', 'the', 'heart'), ('the', 'heart', '.')]
# --------------------------------------------------
# ngrams :  [('The', 'best', 'and', 'most'), ('best', 'and', 'most', 'beautiful'), ('and', 'most', 'beautiful', 'thing'), ('most', 'beautiful', 'thing', 'in'), ('beautiful', 'thing', 'in', 'the'), ('thing', 'in', 'the', 'world'), ('in', 'the', 'world', 'can'), ('the', 'world', 'can', 'not'), ('world', 'can', 'not', 'be'), ('can', 'not', 'be', 'seen'), ('not', 'be', 'seen', 'or'), ('be', 'seen', 'or', 'touched'), ('seen', 'or', 'touched', ','), ('or', 'touched', ',', 'they'), ('touched', ',', 'they', 'must'), (',', 'they', 'must', 'be'), ('they', 'must', 'be', 'felt'), ('must', 'be', 'felt', 'with'), ('be', 'felt', 'with', 'the'), ('felt', 'with', 'the', 'heart'), ('with', 'the', 'heart', '.')]
# --------------------------------------------------

# %% [markdown]
# ## -------------------------------------

# %% [markdown]
# ## 2. Stopwords :

# %% [markdown]
# #### nltk has its own list of stopwords, we can import from nltk.corpus they are helpful in processing sentences, but not helpful in processing of the language.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

example_sent = "This is an example showing off stop word filtration."

stop_words = set(stopwords.words("english"))   # english - is an lang. of which stopwordS are using word_tokenize
# print(stop_words)    # just to check print what are stop_words = filtered_sent(example_sent)

words = word_tokenize(example_sent)

# filtered_sent = []                  
# for w in words:
#     if w not in stop_words:
#         filtered_sent.append(w)

# print(filtered_sent)    


# or use list comprehension instaead of for loop
filtered_sent = [w for w in words if w not in stop_words]
print(filtered_sent)
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration', '.']

# %%
from nltk.corpus import stopwords           # gives list of stopwords

len(stopwords.words('english'))         # remove - len() and use print to see the list.
# Out:
# 179

# %% [markdown]
# #### Most of the words are stopwords and punctuation hence can be removed , Now use 'compile()' from 're' module to create a string that matches any digit or special character and then see how we can remove these stopewords.

# %%
import re
punctuation = re.compile(r'-.?|:;()|0-9]')

post_puctuation = []
for words in hamlet_tokens:
    word = punctuation.sub("",words)
    if len(word)>0:
        post_puctuation.append(word)
        
# post_puctuation                        # see there are no stopwords here in the particular given output. see list remove len 
len(post_puctuation)
# Out:
# 65

# %% [markdown]
# ## -------------------------------------

# %% [markdown]
# ## 3. Stemming :

# %%
Stemming : 
Normalize words into its base (or root) form. 
It fixes pre-fix and suffix both, result sometimes may not be likely.
Its a rule based process of stripping(removing) the suffixes. (like: ing, ly, es, s)
        
Stemming : used where meaning of words not important (ex: spam detection)

3 types : PorterStemmer , LancasterStemmer , SnowballStemmer

# %% [markdown]
# ##### PorterStemmer

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

example_words = ["python", "pythoner", "pythoning", "pythoned", "pythonly"]
# for w in example_words:          # stemming of 'example_words' , here we have words in it.
#     print(ps.stem(w))


new_text = "It is very important to be pythonly when you are pythoner and doing grey pythoned examples. The pythoning oncely."
words = word_tokenize(new_text)     # Here we have sentence, so 1st tokenize sentence into words , 2nd stemming of words.
for w in words:
    print(ps.stem(w))
# Out:
# It
# is
# veri
# import
# to
# be
# pythonli
# when
# you
# are
# python
# and
# do
# grey
# python
# exampl
# .
# the
# python
# onc
# .

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

words_to_stem = ['give', 'given', 'giving', 'gave']
for words in words_to_stem:
    print(words + ':' + ps.stem(words))
# Out:
# give:give
# given:given
# giving:give
# gave:gave

# %% [markdown]
# ##### LancasterStemmer

# %%
from nltk.stem import LancasterStemmer              # Lancaster is more aggressive than Porter Stemmer.
ls = LancasterStemmer()
for words in words_to_stem:
    print(words + ':' + ls.stem(words))         # Lancaster : use it as how many times (giv) in words used , for other : Porter
# Out:
# give:giv
# given:giv
# giving:giv
# gave:gav

# %% [markdown]
# ##### SnowballStemmer : in this we have to specify  language

# %%
from nltk.stem import SnowballStemmer
ss = SnowballStemmer(language='english')      # but in this we have to specify - language

for words in words_to_stem:
    print(words + ':' + ls.stem(words))
# Out:
# give:giv
# given:giv
# giving:giv
# gave:gav

# %%
word_list = ['enemy','fellowship','friends','stabilise','misunderstanding','sunlight','football','pedler','roadster','awkward']
print("{0:20}{1:20}{2:20}{3:20}".format('Words', 'Porter Stemmer', 'Lancaster Stemmer', 'Snowball Stemmer''\n'))

for word in word_list:
    print("{0:20}{1:20}{2:20}{3:20}".format(word, ps.stem(word), ls.stem(word), ss.stem(word)))    # All 3
# Out:
# Words               Porter Stemmer      Lancaster Stemmer   Snowball Stemmer
#
# enemy               enemi               enemy               enemi
# fellowship          fellowship          fellow              fellowship
# friends             friend              friend              friend
# stabilise           stabilis            stabl               stabilis
# misunderstanding    misunderstand       misunderstand       misunderstand
# sunlight            sunlight            sunlight            sunlight
# football            footbal             footbal             footbal
# pedler              pedler              pedl                pedler
# roadster            roadster            roadst              roadster
# awkward             awkward             awkward             awkward

# %% [markdown]
# ## ---------------------------------------------

# %% [markdown]
# ## 4. Lemmatization :

# %%
consider the morphological anlysis of word, using a detailed dictionary which the algorithm can look into.
a.Groups together different inflected forms of a word , called Lemma.  
b.somehow similar to stemming , as it maps several words into one common root.  
c.Output of lemmatization is a proper word. 
d.EX : going, went, gone --> go 

Lemmatization : used when meaning of word is important (ex: Question-Answering app.)

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

lem = WordNetLemmatizer()

words_to_stem = ['give', 'given', 'giving', 'gave']
for words in words_to_stem:
    print(words + ' : ' + lem.lemmatize(words))       # bocz, we not assign any pos-tags here and assumes all words- Noun
# Out:
# give : give
# given : given
# giving : giving
# gave : gave

# %%
lem.lemmatize('corpora')
# Out:
# 'corpus'

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

lem = WordNetLemmatizer()
ps = PorterStemmer()

word = "multiplying"

lem.lemmatize(word, "v")      # v- verb attribute
# ps.stem(word)
# Out:
# 'multiply'

# %% [markdown]
# ## -----------------------------------------------

# %% [markdown]
# ## 5. POS (Part of Speech) tagging :

# %%
pos_tag : 
gives Part of speech ( This means labeling words in a sentence as nouns, adjectives, verbs...etc.)
# link : https://pythonprogramming.net/part-of-speech-tagging-nltk-tutorial/
# (PRP: personal pronoun, NN: Noun singular, IN: preposition, etc....)
          
( so many POS here google it - noun , adverb etc.)

# %%
sent = "Timothy is a natural when it comes to drawing"       # 1st tokenize it , then took pos-tags
sent_tokens = word_tokenize(sent)

for token in sent_tokens:
    print(nltk.pos_tag([token]))         # use [token] create a list for it.
# Out:
# [('Timothy', 'NN')]
# [('is', 'VBZ')]
# [('a', 'DT')]
# [('natural', 'JJ')]
# [('when', 'WRB')]
# [('it', 'PRP')]
# [('comes', 'VBZ')]
# [('to', 'TO')]
# [('drawing', 'VBG')]

# %%
from nltk import word_tokenize, pos_tag

text = "I am learning Natural Language Processing from sentdex"

tokens = word_tokenize(text)
pos_tag(tokens)
# Out:
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('learning', 'VBG'),
#  ('Natural', 'NNP'),
#  ('Language', 'NNP'),
#  ('Processing', 'VBG'),
#  ('from', 'IN'),
#  ('sentdex', 'NN')]

# %%
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer       # PunktSentenceTokenizer : is Unsupervise ML tokenizer  

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_token = PunktSentenceTokenizer(train_text)
tokenized = custom_token.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)
    
    except Exception as e:
        print(str(e))
        
# process_content()        # we don;t run it bcoz its big  , use ctrl+c to break

# %% [markdown]
# ## --------------------------------------

# %% [markdown]
# ## 6. Chunking :

# %%
chunking : 
is a process by which individual pieces of information are bound together into a meaningful whole.
picks individual piece(or tokens) of information and group them into bigger pieces called chunks.

# %%
from nltk.corpus import state_union                     # from corpus folder taking-> state_union.
from nltk.tokenize import PunktSentenceTokenizer       # PunktSentenceTokenizer : is Unsupervise ML tokenizer  

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_token = PunktSentenceTokenizer(train_text)
tokenized = custom_token.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            chunkGram = r"""Chunk : {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            
#             chunked.draw()
            
            print(chunked)
            
#             print(tagged)
    
    except Exception as e:
        print(str(e))
        
process_content()
# Out:
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (Chunk ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk THE/NNP UNION/NNP January/NNP)
#   31/CD
#   ,/,
#   2006/CD
#   (Chunk THE/NNP PRESIDENT/NNP)
#   :/:
#   (Chunk Thank/NNP)
#   you/PRP
#   all/DT
#   ./.)
# (S
#   (Chunk Mr./NNP Speaker/NNP)
#   ,/,
#   (Chunk Vice/NNP President/NNP Cheney/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   the/DT
#   (Chunk Supreme/NNP Court/NNP)
#   and/CC
#   diplomatic/JJ
#   corps/NN
#   ,/,
#   distinguished/JJ
#   guests/NNS
#   ,/,
#   and/CC
#   fellow/JJ
#   citizens/NNS
#   :/:
#   Today/VB
#   our/PRP$
#   nation/NN
#   lost/VBD
#   a/DT
#   beloved/VBN
#   ,/,
#   graceful/JJ
#   ,/,
#   courageous/JJ
#   woman/NN
#   who/WP
#   (Chunk called/VBD America/NNP)
#   to/TO
#   its/PRP$
#   founding/NN
#   ideals/NNS
#   and/CC
#   carried/VBD
#   on/IN
#   a/DT
#   noble/JJ
#   dream/NN
#   ./.)
# (S
#   Tonight/NN
#   we/PRP
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   hope/NN
#   of/IN
#   a/DT
#   glad/JJ
#   reunion/NN
#   with/IN
#   the/DT
#   husband/NN
#   who/WP
#   was/VBD
#   taken/VBN
#   so/RB
#   long/RB
#   ago/RB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   grateful/JJ
#   for/IN
#   the/DT
#   good/JJ
#   life/NN
#   of/IN
#   (Chunk Coretta/NNP Scott/NNP King/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   reacts/VBZ
#   to/TO
#   applause/VB
#   during/IN
#   his/PRP$
#   (Chunk State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP)
#   ,/,
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP DraperEvery/NNP time/NN)
#   I/PRP
#   'm/VBP
#   invited/JJ
#   to/TO
#   this/DT
#   rostrum/NN
#   ,/,
#   I/PRP
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   privilege/NN
#   ,/,
#   and/CC
#   mindful/NN
#   of/IN
#   the/DT
#   history/NN
#   we/PRP
#   've/VBP
#   seen/VBN
#   together/RB
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   (Chunk Capitol/NNP dome/NN)
#   in/IN
#   moments/NNS
#   of/IN
#   national/JJ
#   mourning/NN
#   and/CC
#   national/JJ
#   achievement/NN
#   ./.)
# (S
#   We/PRP
#   (Chunk have/VBP served/VBN America/NNP)
#   through/IN
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   consequential/JJ
#   periods/NNS
#   of/IN
#   our/PRP$
#   history/NN
#   --/:
#   and/CC
#   it/PRP
#   has/VBZ
#   been/VBN
#   my/PRP$
#   honor/NN
#   to/TO
#   serve/VB
#   with/IN
#   you/PRP
#   ./.)
# (S
#   In/IN
#   a/DT
#   system/NN
#   of/IN
#   two/CD
#   parties/NNS
#   ,/,
#   two/CD
#   chambers/NNS
#   ,/,
#   and/CC
#   two/CD
#   elected/JJ
#   branches/NNS
#   ,/,
#   there/EX
#   will/MD
#   always/RB
#   be/VB
#   differences/NNS
#   and/CC
#   debate/NN
#   ./.)
# (S
#   But/CC
#   even/RB
#   tough/JJ
#   debates/NNS
#   can/MD
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   civil/JJ
#   tone/NN
#   ,/,
#   and/CC
#   our/PRP$
#   differences/NNS
#   can/MD
#   not/RB
#   be/VB
#   allowed/VBN
#   to/TO
#   harden/VB
#   into/IN
#   anger/NN
#   ./.)
# (S
#   To/TO
#   confront/VB
#   the/DT
#   great/JJ
#   issues/NNS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   must/MD
#   act/VB
#   in/IN
#   a/DT
#   spirit/NN
#   of/IN
#   goodwill/NN
#   and/CC
#   respect/NN
#   for/IN
#   one/CD
#   another/DT
#   --/:
#   and/CC
#   I/PRP
#   will/MD
#   do/VB
#   my/PRP$
#   part/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   the/DT
#   state/NN
#   of/IN
#   our/PRP$
#   (Chunk Union/NNP)
#   is/VBZ
#   strong/JJ
#   --/:
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   make/VB
#   it/PRP
#   stronger/JJR
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   In/IN
#   this/DT
#   decisive/JJ
#   year/NN
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   will/MD
#   make/VB
#   choices/NNS
#   that/WDT
#   determine/VBP
#   both/DT
#   the/DT
#   future/NN
#   and/CC
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   act/VB
#   confidently/RB
#   in/IN
#   pursuing/VBG
#   the/DT
#   enemies/NNS
#   of/IN
#   freedom/NN
#   --/:
#   or/CC
#   retreat/NN
#   from/IN
#   our/PRP$
#   duties/NNS
#   in/IN
#   the/DT
#   hope/NN
#   of/IN
#   an/DT
#   easier/JJR
#   life/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   build/VB
#   our/PRP$
#   prosperity/NN
#   by/IN
#   leading/VBG
#   the/DT
#   world/NN
#   economy/NN
#   --/:
#   or/CC
#   shut/VB
#   ourselves/PRP
#   off/RP
#   from/IN
#   trade/NN
#   and/CC
#   opportunity/NN
#   ./.)
# (S
#   In/IN
#   a/DT
#   complex/JJ
#   and/CC
#   challenging/JJ
#   time/NN
#   ,/,
#   the/DT
#   road/NN
#   of/IN
#   isolationism/NN
#   and/CC
#   protectionism/NN
#   may/MD
#   seem/VB
#   broad/JJ
#   and/CC
#   inviting/NN
#   --/:
#   yet/CC
#   it/PRP
#   ends/VBZ
#   in/IN
#   danger/NN
#   and/CC
#   decline/NN
#   ./.)
# (S
#   The/DT
#   only/JJ
#   way/NN
#   to/TO
#   protect/VB
#   our/PRP$
#   people/NNS
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   secure/VB
#   the/DT
#   peace/NN
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   control/VB
#   our/PRP$
#   destiny/NN
#   is/VBZ
#   by/IN
#   our/PRP$
#   leadership/NN
#   --/:
#   so/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   of/IN
#   (Chunk America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   lead/VB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Abroad/RB
#   ,/,
#   our/PRP$
#   nation/NN
#   is/VBZ
#   committed/VBN
#   to/TO
#   an/DT
#   historic/JJ
#   ,/,
#   long-term/JJ
#   goal/NN
#   --/:
#   we/PRP
#   seek/VBP
#   the/DT
#   end/NN
#   of/IN
#   tyranny/NN
#   in/IN
#   our/PRP$
#   world/NN
#   ./.)
# (S
#   Some/DT
#   dismiss/VBP
#   that/DT
#   goal/NN
#   as/IN
#   misguided/JJ
#   idealism/NN
#   ./.)
# (S
#   In/IN
#   reality/NN
#   ,/,
#   the/DT
#   future/JJ
#   security/NN
#   of/IN
#   (Chunk America/NNP)
#   depends/VBZ
#   on/IN
#   it/PRP
#   ./.)
# (S
#   On/IN
#   (Chunk September/NNP)
#   the/DT
#   11th/CD
#   ,/,
#   2001/CD
#   ,/,
#   we/PRP
#   found/VBD
#   that/IN
#   problems/NNS
#   originating/VBG
#   in/IN
#   a/DT
#   failed/JJ
#   and/CC
#   oppressive/JJ
#   state/NN
#   7,000/CD
#   miles/NNS
#   away/RB
#   could/MD
#   bring/VB
#   murder/NN
#   and/CC
#   destruction/NN
#   to/TO
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   (Chunk Dictatorships/NNP shelter/NN)
#   terrorists/NNS
#   ,/,
#   and/CC
#   feed/VB
#   resentment/NN
#   and/CC
#   radicalism/NN
#   ,/,
#   and/CC
#   seek/JJ
#   weapons/NNS
#   of/IN
#   mass/NN
#   destruction/NN
#   ./.)
# (S
#   Democracies/NNS
#   replace/VB
#   resentment/NN
#   with/IN
#   hope/NN
#   ,/,
#   respect/VB
#   the/DT
#   rights/NNS
#   of/IN
#   their/PRP$
#   citizens/NNS
#   and/CC
#   their/PRP$
#   neighbors/NNS
#   ,/,
#   and/CC
#   join/VB
#   the/DT
#   fight/NN
#   against/IN
#   terror/NN
#   ./.)
# (S
#   Every/DT
#   step/NN
#   toward/IN
#   freedom/NN
#   in/IN
#   the/DT
#   world/NN
#   makes/VBZ
#   our/PRP$
#   country/NN
#   safer/NN
#   --/:
#   so/IN
#   we/PRP
#   will/MD
#   act/VB
#   boldly/RB
#   in/IN
#   freedom/NN
#   's/POS
#   cause/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Far/RB
#   from/IN
#   being/VBG
#   a/DT
#   hopeless/NN
#   dream/NN
#   ,/,
#   the/DT
#   advance/NN
#   of/IN
#   freedom/NN
#   is/VBZ
#   the/DT
#   great/JJ
#   story/NN
#   of/IN
#   our/PRP$
#   time/NN
#   ./.)
# (S
#   In/IN
#   1945/CD
#   ,/,
#   there/EX
#   were/VBD
#   about/RB
#   two/CD
#   dozen/NN
#   lonely/RB
#   democracies/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S Today/NN ,/, there/EX are/VBP 122/CD ./.)
# (S
#   And/CC
#   we/PRP
#   're/VBP
#   writing/VBG
#   a/DT
#   new/JJ
#   chapter/NN
#   in/IN
#   the/DT
#   story/NN
#   of/IN
#   self-government/JJ
#   --/:
#   with/IN
#   women/NNS
#   lining/VBG
#   up/RP
#   to/TO
#   vote/VB
#   in/IN
#   (Chunk Afghanistan/NNP)
#   ,/,
#   and/CC
#   millions/NNS
#   of/IN
#   (Chunk Iraqis/NNP)
#   marking/VBG
#   their/PRP$
#   liberty/NN
#   with/IN
#   purple/JJ
#   ink/NN
#   ,/,
#   and/CC
#   men/NNS
#   and/CC
#   women/NNS
#   from/IN
#   (Chunk Lebanon/NNP)
#   to/TO
#   (Chunk Egypt/NNP)
#   debating/VBG
#   the/DT
#   rights/NNS
#   of/IN
#   individuals/NNS
#   and/CC
#   the/DT
#   necessity/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   At/IN
#   the/DT
#   start/NN
#   of/IN
#   2006/CD
#   ,/,
#   more/JJR
#   than/IN
#   half/PDT
#   the/DT
#   people/NNS
#   of/IN
#   our/PRP$
#   world/NN
#   live/VBP
#   in/IN
#   democratic/JJ
#   nations/NNS
#   ./.)
# (S
#   And/CC
#   we/PRP
#   do/VBP
#   not/RB
#   forget/VB
#   the/DT
#   other/JJ
#   half/NN
#   --/:
#   in/IN
#   places/NNS
#   like/IN
#   (Chunk Syria/NNP)
#   and/CC
#   (Chunk Burma/NNP)
#   ,/,
#   (Chunk Zimbabwe/NNP)
#   ,/,
#   (Chunk North/NNP Korea/NNP)
#   ,/,
#   and/CC
#   (Chunk Iran/NNP)
#   --/:
#   because/IN
#   the/DT
#   demands/NNS
#   of/IN
#   justice/NN
#   ,/,
#   and/CC
#   the/DT
#   peace/NN
#   of/IN
#   this/DT
#   world/NN
#   ,/,
#   require/VBP
#   their/PRP$
#   freedom/NN
#   ,/,
#   as/RB
#   well/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   delivers/VBZ
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP)
#   ,/,
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
#   can/MD
#   deny/VB
#   the/DT
#   success/NN
#   of/IN
#   freedom/NN
#   ,/,
#   but/CC
#   some/DT
#   men/NNS
#   rage/VB
#   and/CC
#   fight/VB
#   against/IN
#   it/PRP
#   ./.)
# (S
#   And/CC
#   one/CD
#   of/IN
#   the/DT
#   main/JJ
#   sources/NNS
#   of/IN
#   reaction/NN
#   and/CC
#   opposition/NN
#   is/VBZ
#   radical/JJ
#   (Chunk Islam/NNP)
#   --/:
#   the/DT
#   perversion/NN
#   by/IN
#   a/DT
#   few/JJ
#   of/IN
#   a/DT
#   noble/JJ
#   faith/NN
#   into/IN
#   an/DT
#   ideology/NN
#   of/IN
#   terror/NN
#   and/CC
#   death/NN
#   ./.)
# (S
#   Terrorists/NNS
#   like/IN
#   bin/NN
#   (Chunk Laden/NNP)
#   are/VBP
#   serious/JJ
#   about/IN
#   mass/NN
#   murder/NN
#   --/:
#   and/CC
#   all/DT
#   of/IN
#   us/PRP
#   must/MD
#   take/VB
#   their/PRP$
#   declared/JJ
#   intentions/NNS
#   seriously/RB
#   ./.)
# (S
#   They/PRP
#   seek/VBP
#   to/TO
#   impose/VB
#   a/DT
#   heartless/NN
#   system/NN
#   of/IN
#   totalitarian/JJ
#   control/NN
#   throughout/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP)
#   ,/,
#   and/CC
#   arm/NN
#   themselves/PRP
#   with/IN
#   weapons/NNS
#   of/IN
#   mass/NN
#   murder/NN
#   ./.)
# (S
#   Their/PRP$
#   aim/NN
#   is/VBZ
#   to/TO
#   seize/VB
#   power/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   ,/,
#   and/CC
#   use/VB
#   it/PRP
#   as/IN
#   a/DT
#   safe/JJ
#   haven/NN
#   to/TO
#   launch/VB
#   attacks/NNS
#   against/IN
#   (Chunk America/NNP)
#   and/CC
#   the/DT
#   world/NN
#   ./.)
# (S
#   Lacking/VBG
#   the/DT
#   military/JJ
#   strength/NN
#   to/TO
#   challenge/VB
#   us/PRP
#   directly/RB
#   ,/,
#   the/DT
#   terrorists/NNS
#   have/VBP
#   chosen/VBN
#   the/DT
#   weapon/NN
#   of/IN
#   fear/NN
#   ./.)
# (S
#   When/WRB
#   they/PRP
#   murder/VBP
#   children/NNS
#   at/IN
#   a/DT
#   school/NN
#   in/IN
#   (Chunk Beslan/NNP)
#   ,/,
#   or/CC
#   blow/VB
#   up/RP
#   commuters/NNS
#   in/IN
#   (Chunk London/NNP)
#   ,/,
#   or/CC
#   behead/VB
#   a/DT
#   bound/NN
#   captive/NN
#   ,/,
#   the/DT
#   terrorists/NNS
#   hope/VBP
#   these/DT
#   horrors/NNS
#   will/MD
#   break/VB
#   our/PRP$
#   will/MD
#   ,/,
#   allowing/VBG
#   the/DT
#   violent/NN
#   to/TO
#   inherit/VB
#   the/DT
#   (Chunk Earth/NNP)
#   ./.)
# (S
#   But/CC
#   they/PRP
#   have/VBP
#   miscalculated/VBN
#   :/:
#   We/PRP
#   love/VBP
#   our/PRP$
#   freedom/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   fight/VB
#   to/TO
#   keep/VB
#   it/PRP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   In/IN
#   a/DT
#   time/NN
#   of/IN
#   testing/VBG
#   ,/,
#   we/PRP
#   can/MD
#   not/RB
#   find/VB
#   security/NN
#   by/IN
#   abandoning/VBG
#   our/PRP$
#   commitments/NNS
#   and/CC
#   retreating/VBG
#   within/IN
#   our/PRP$
#   borders/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   were/VBD
#   to/TO
#   leave/VB
#   these/DT
#   vicious/JJ
#   attackers/NNS
#   alone/RB
#   ,/,
#   they/PRP
#   would/MD
#   not/RB
#   leave/VB
#   us/PRP
#   alone/RB
#   ./.)
# (S
#   They/PRP
#   would/MD
#   simply/RB
#   move/VB
#   the/DT
#   battlefield/NN
#   to/TO
#   our/PRP$
#   own/JJ
#   shores/NNS
#   ./.)
# (S There/EX is/VBZ no/DT peace/NN in/IN retreat/NN ./.)
# (S And/CC there/EX is/VBZ no/DT honor/NN in/IN retreat/NN ./.)
# (S
#   By/IN
#   allowing/VBG
#   radical/JJ
#   (Chunk Islam/NNP)
#   to/TO
#   work/VB
#   its/PRP$
#   will/MD
#   --/:
#   by/IN
#   leaving/VBG
#   an/DT
#   assaulted/JJ
#   world/NN
#   to/TO
#   fend/VB
#   for/IN
#   itself/PRP
#   --/:
#   we/PRP
#   would/MD
#   signal/VB
#   to/TO
#   all/PDT
#   that/IN
#   we/PRP
#   no/DT
#   longer/RBR
#   believe/VBP
#   in/IN
#   our/PRP$
#   own/JJ
#   ideals/NNS
#   ,/,
#   or/CC
#   even/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   courage/NN
#   ./.)
# (S
#   But/CC
#   our/PRP$
#   enemies/NNS
#   and/CC
#   our/PRP$
#   friends/NNS
#   can/MD
#   be/VB
#   certain/JJ
#   :/:
#   The/DT
#   (Chunk United/NNP)
#   States/NNPS
#   will/MD
#   not/RB
#   retreat/VB
#   from/IN
#   the/DT
#   world/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   never/RB
#   surrender/VB
#   to/TO
#   evil/VB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk America/NNP)
#   rejects/VBZ
#   the/DT
#   false/JJ
#   comfort/NN
#   of/IN
#   isolationism/NN
#   ./.)
# (S
#   We/PRP
#   are/VBP
#   the/DT
#   nation/NN
#   that/IN
#   saved/VBD
#   liberty/NN
#   in/IN
#   (Chunk Europe/NNP)
#   ,/,
#   and/CC
#   liberated/VBD
#   death/NN
#   camps/NNS
#   ,/,
#   and/CC
#   helped/VBD
#   raise/VB
#   up/RP
#   democracies/NNS
#   ,/,
#   and/CC
#   faced/VBD
#   down/IN
#   an/DT
#   evil/JJ
#   empire/NN
#   ./.)
# (S
#   Once/RB
#   again/RB
#   ,/,
#   we/PRP
#   accept/VBP
#   the/DT
#   call/NN
#   of/IN
#   history/NN
#   to/TO
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   and/CC
#   move/VB
#   this/DT
#   world/NN
#   toward/IN
#   peace/NN
#   ./.)
# (S
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terror/NN
#   networks/NNS
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   killed/VBN
#   or/CC
#   captured/VBN
#   many/JJ
#   of/IN
#   their/PRP$
#   leaders/NNS
#   --/:
#   and/CC
#   for/IN
#   the/DT
#   others/NNS
#   ,/,
#   their/PRP$
#   day/NN
#   will/MD
#   come/VB
#   ./.)
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   greets/VBZ
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   after/IN
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP)
#   ,/,
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP)
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (Chunk Afghanistan/NNP)
#   ,/,
#   where/WRB
#   a/DT
#   fine/JJ
#   (Chunk President/NNP)
#   and/CC
#   a/DT
#   (Chunk National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   terror/NN
#   while/IN
#   building/VBG
#   the/DT
#   institutions/NNS
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (Chunk Iraq/NNP)
#   ,/,
#   with/IN
#   a/DT
#   clear/JJ
#   plan/NN
#   for/IN
#   victory/NN
#   ./.)
# (S
#   First/RB
#   ,/,
#   we/PRP
#   (Chunk 're/VBP helping/VBG Iraqis/NNP)
#   build/VB
#   an/DT
#   inclusive/JJ
#   government/NN
#   ,/,
#   so/IN
#   that/DT
#   old/JJ
#   resentments/NNS
#   will/MD
#   be/VB
#   eased/VBN
#   and/CC
#   the/DT
#   insurgency/NN
#   will/MD
#   be/VB
#   marginalized/VBN
#   ./.)
# (S
#   Second/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   continuing/VBG
#   reconstruction/NN
#   efforts/NNS
#   ,/,
#   and/CC
#   helping/VBG
#   the/DT
#   (Chunk Iraqi/NNP government/NN)
#   to/TO
#   fight/VB
#   corruption/NN
#   and/CC
#   build/VB
#   a/DT
#   modern/JJ
#   economy/NN
#   ,/,
#   so/IN
#   all/DT
#   (Chunk Iraqis/NNP)
#   can/MD
#   experience/VB
#   the/DT
#   benefits/NNS
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   ,/,
#   third/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   striking/VBG
#   terrorist/JJ
#   targets/NNS
#   while/IN
#   we/PRP
#   train/VBP
#   Iraqi/JJ
#   forces/NNS
#   that/WDT
#   are/VBP
#   increasingly/RB
#   capable/JJ
#   of/IN
#   defeating/VBG
#   the/DT
#   enemy/NN
#   ./.)
# (S
#   (Chunk Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   their/PRP$
#   courage/NN
#   every/DT
#   day/NN
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   proud/JJ
#   to/TO
#   be/VB
#   their/PRP$
#   allies/NNS
#   in/IN
#   the/DT
#   cause/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   work/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   is/VBZ
#   difficult/JJ
#   because/IN
#   our/PRP$
#   enemy/NN
#   is/VBZ
#   brutal/JJ
#   ./.)
# (S
#   But/CC
#   that/DT
#   brutality/NN
#   has/VBZ
#   not/RB
#   stopped/VBN
#   the/DT
#   dramatic/JJ
#   progress/NN
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   In/IN
#   less/JJR
#   than/IN
#   three/CD
#   years/NNS
#   ,/,
#   the/DT
#   nation/NN
#   has/VBZ
#   gone/VBN
#   from/IN
#   dictatorship/NN
#   to/TO
#   liberation/NN
#   ,/,
#   to/TO
#   sovereignty/VB
#   ,/,
#   to/TO
#   a/DT
#   constitution/NN
#   ,/,
#   to/TO
#   national/JJ
#   elections/NNS
#   ./.)
# (S
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   our/PRP$
#   coalition/NN
#   has/VBZ
#   been/VBN
#   relentless/VBN
#   in/IN
#   shutting/VBG
#   off/RP
#   terrorist/JJ
#   infiltration/NN
#   ,/,
#   clearing/VBG
#   out/RP
#   insurgent/JJ
#   strongholds/NNS
#   ,/,
#   and/CC
#   turning/VBG
#   over/RP
#   territory/NN
#   to/TO
#   (Chunk Iraqi/NNP security/NN)
#   forces/NNS
#   ./.)
# (S
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   our/PRP$
#   plan/NN
#   for/IN
#   victory/NN
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   will/MD
#   of/IN
#   the/DT
#   (Chunk Iraqi/NNP)
#   people/NNS
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   skill/NN
#   and/CC
#   spirit/NN
#   of/IN
#   our/PRP$
#   military/JJ
#   ./.)
# (S
#   (Chunk Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   are/VBP
#   in/IN
#   this/DT
#   fight/NN
#   to/TO
#   win/VB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   winning/VBG
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   The/DT
#   road/NN
#   of/IN
#   victory/NN
#   is/VBZ
#   the/DT
#   road/NN
#   that/WDT
#   will/MD
#   take/VB
#   our/PRP$
#   troops/NNS
#   home/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   make/VBP
#   progress/NN
#   on/IN
#   the/DT
#   ground/NN
#   ,/,
#   and/CC
#   (Chunk Iraqi/NNP)
#   forces/NNS
#   increasingly/RB
#   take/VBP
#   the/DT
#   lead/NN
#   ,/,
#   we/PRP
#   should/MD
#   be/VB
#   able/JJ
#   to/TO
#   further/JJ
#   decrease/VB
#   our/PRP$
#   troop/NN
#   levels/NNS
#   --/:
#   but/CC
#   those/DT
#   decisions/NNS
#   will/MD
#   be/VB
#   made/VBN
#   by/IN
#   our/PRP$
#   military/JJ
#   commanders/NNS
#   ,/,
#   not/RB
#   by/IN
#   politicians/NNS
#   in/IN
#   (Chunk Washington/NNP)
#   ,/,
#   (Chunk D.C/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   coalition/NN
#   has/VBZ
#   learned/VBN
#   from/IN
#   our/PRP$
#   experience/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   adjusted/VBN
#   our/PRP$
#   military/JJ
#   tactics/NNS
#   and/CC
#   changed/VBD
#   our/PRP$
#   approach/NN
#   to/TO
#   reconstruction/NN
#   ./.)
# (S
#   Along/IN
#   the/DT
#   way/NN
#   ,/,
#   we/PRP
#   have/VBP
#   benefitted/VBN
#   from/IN
#   responsible/JJ
#   criticism/NN
#   and/CC
#   counsel/NN
#   offered/VBN
#   by/IN
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   coming/VBG
#   year/NN
#   ,/,
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   reach/VB
#   out/RP
#   and/CC
#   seek/VB
#   your/PRP$
#   good/JJ
#   advice/NN
#   ./.)
# (S
#   Yet/RB
#   ,/,
#   there/EX
#   is/VBZ
#   a/DT
#   difference/NN
#   between/IN
#   responsible/JJ
#   criticism/NN
#   that/WDT
#   aims/VBZ
#   for/IN
#   success/NN
#   ,/,
#   and/CC
#   defeatism/NN
#   that/WDT
#   refuses/VBZ
#   to/TO
#   acknowledge/VB
#   anything/NN
#   but/CC
#   failure/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Hindsight/NNP)
#   alone/RB
#   is/VBZ
#   not/RB
#   wisdom/JJ
#   ,/,
#   and/CC
#   second-guessing/NN
#   is/VBZ
#   not/RB
#   a/DT
#   strategy/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   With/IN
#   so/RB
#   much/JJ
#   in/IN
#   the/DT
#   balance/NN
#   ,/,
#   those/DT
#   of/IN
#   us/PRP
#   in/IN
#   public/JJ
#   office/NN
#   have/VBP
#   a/DT
#   duty/NN
#   to/TO
#   speak/VB
#   with/IN
#   candor/NN
#   ./.)
# (S
#   A/DT
#   sudden/JJ
#   withdrawal/NN
#   of/IN
#   our/PRP$
#   forces/NNS
#   from/IN
#   (Chunk Iraq/NNP)
#   would/MD
#   abandon/VB
#   our/PRP$
#   (Chunk Iraqi/NNP)
#   allies/NNS
#   to/TO
#   death/NN
#   and/CC
#   prison/NN
#   ,/,
#   would/MD
#   put/VB
#   men/NNS
#   like/IN
#   bin/NN
#   (Chunk Laden/NNP)
#   and/CC
#   (Chunk Zarqawi/NNP)
#   in/IN
#   charge/NN
#   of/IN
#   a/DT
#   strategic/JJ
#   country/NN
#   ,/,
#   and/CC
#   show/VBP
#   that/IN
#   a/DT
#   pledge/NN
#   from/IN
#   (Chunk America/NNP)
#   means/VBZ
#   little/JJ
#   ./.)
# (S
#   Members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   ,/,
#   however/RB
#   we/PRP
#   feel/VBP
#   about/IN
#   the/DT
#   decisions/NNS
#   and/CC
#   debates/NNS
#   of/IN
#   the/DT
#   past/NN
#   ,/,
#   our/PRP$
#   nation/NN
#   has/VBZ
#   only/RB
#   one/CD
#   option/NN
#   :/:
#   We/PRP
#   must/MD
#   keep/VB
#   our/PRP$
#   word/NN
#   ,/,
#   defeat/VB
#   our/PRP$
#   enemies/NNS
#   ,/,
#   and/CC
#   stand/VBP
#   behind/IN
#   the/DT
#   American/JJ
#   military/NN
#   in/IN
#   this/DT
#   vital/JJ
#   mission/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Laura/NNP Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/IN
#   she/PRP
#   (Chunk is/VBZ introduced/VBN Tuesday/NNP evening/NN)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   during/IN
#   the/DT
#   (Chunk State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   (Chunk United/NNP)
#   States/NNPS
#   (Chunk Capitol/NNP)
#   in/IN
#   (Chunk Washington/NNP)
#   ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP)
#   Our/PRP$
#   men/NNS
#   and/CC
#   women/NNS
#   in/IN
#   uniform/JJ
#   are/VBP
#   making/VBG
#   sacrifices/NNS
#   --/:
#   and/CC
#   showing/VBG
#   a/DT
#   sense/NN
#   of/IN
#   duty/NN
#   stronger/JJR
#   than/IN
#   all/DT
#   fear/NN
#   ./.)
# (S
#   They/PRP
#   know/VBP
#   what/WP
#   it/PRP
#   's/VBZ
#   like/IN
#   to/TO
#   fight/VB
#   house/NN
#   to/TO
#   house/NN
#   in/IN
#   a/DT
#   maze/NN
#   of/IN
#   streets/NNS
#   ,/,
#   to/TO
#   wear/VB
#   heavy/JJ
#   gear/NN
#   in/IN
#   the/DT
#   desert/NN
#   heat/NN
#   ,/,
#   to/TO
#   see/VB
#   a/DT
#   comrade/NN
#   killed/VBN
#   by/IN
#   a/DT
#   roadside/NN
#   bomb/NN
#   ./.)
# (S
#   And/CC
#   those/DT
#   who/WP
#   know/VBP
#   the/DT
#   costs/NNS
#   also/RB
#   know/VBP
#   the/DT
#   stakes/NNS
#   ./.)
# (S
#   Marine/JJ
#   (Chunk Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   was/VBD
#   killed/VBN
#   last/JJ
#   month/NN
#   fighting/VBG
#   in/IN
#   (Chunk Fallujah/NNP)
#   ./.)
# (S
#   He/PRP
#   left/VBD
#   behind/RP
#   a/DT
#   letter/NN
#   to/TO
#   his/PRP$
#   family/NN
#   ,/,
#   but/CC
#   his/PRP$
#   words/NNS
#   could/MD
#   just/RB
#   as/RB
#   well/RB
#   be/VB
#   addressed/VBN
#   to/TO
#   every/DT
#   (Chunk American/NNP)
#   ./.)
# (S
#   Here/RB
#   is/VBZ
#   what/WP
#   (Chunk Dan/NNP)
#   wrote/VBD
#   :/:
#   ``/``
#   I/PRP
#   know/VBP
#   what/WP
#   honor/NN
#   is/VBZ
#   ./.)
# (S
#   .../:
#   It/PRP
#   has/VBZ
#   been/VBN
#   an/DT
#   honor/NN
#   to/TO
#   protect/VB
#   and/CC
#   serve/VB
#   all/DT
#   of/IN
#   you/PRP
#   ./.)
# (S
#   I/PRP
#   faced/VBD
#   death/NN
#   with/IN
#   the/DT
#   secure/NN
#   knowledge/NN
#   that/IN
#   you/PRP
#   would/MD
#   not/RB
#   have/VB
#   to/TO
#   .../:
#   ./.)
# (S Never/RB falter/NN !/.)
# (S
#   Do/VBP
#   n't/RB
#   hesitate/VB
#   to/TO
#   honor/VB
#   and/CC
#   support/VB
#   those/DT
#   of/IN
#   us/PRP
#   who/WP
#   have/VBP
#   the/DT
#   honor/NN
#   of/IN
#   protecting/VBG
#   that/DT
#   which/WDT
#   is/VBZ
#   worth/JJ
#   protecting/VBG
#   ./.
#   ''/'')
# (S
#   (Chunk Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   's/POS
#   wife/NN
#   ,/,
#   (Chunk Lisa/NNP)
#   ,/,
#   and/CC
#   his/PRP$
#   mom/NN
#   and/CC
#   dad/NN
#   ,/,
#   (Chunk Sara/NNP Jo/NNP)
#   and/CC
#   (Chunk Bud/NNP)
#   ,/,
#   are/VBP
#   with/IN
#   us/PRP
#   this/DT
#   evening/NN
#   ./.)
# (S (Chunk Welcome/NNP) ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   nation/NN
#   is/VBZ
#   grateful/JJ
#   to/TO
#   the/DT
#   fallen/VBN
#   ,/,
#   who/WP
#   live/VBP
#   in/IN
#   the/DT
#   memory/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   grateful/JJ
#   to/TO
#   all/DT
#   who/WP
#   volunteer/VBP
#   to/TO
#   wear/VB
#   our/PRP$
#   nation/NN
#   's/POS
#   uniform/NN
#   --/:
#   and/CC
#   as/IN
#   we/PRP
#   honor/VBP
#   our/PRP$
#   brave/NN
#   troops/NNS
#   ,/,
#   let/VB
#   us/PRP
#   never/RB
#   forget/VBP
#   the/DT
#   sacrifices/NNS
#   of/IN
#   (Chunk America/NNP)
#   's/POS
#   military/JJ
#   families/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   offensive/JJ
#   against/IN
#   terror/NN
#   involves/VBZ
#   more/JJR
#   than/IN
#   military/JJ
#   action/NN
#   ./.)
# (S
#   Ultimately/RB
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   defeat/VB
#   the/DT
#   terrorists/NNS
#   is/VBZ
#   to/TO
#   defeat/VB
#   their/PRP$
#   dark/JJ
#   vision/NN
#   of/IN
#   hatred/VBN
#   and/CC
#   fear/VBN
#   by/IN
#   offering/VBG
#   the/DT
#   hopeful/JJ
#   alternative/NN
#   of/IN
#   political/JJ
#   freedom/NN
#   and/CC
#   peaceful/JJ
#   change/NN
#   ./.)
# (S
#   So/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   of/IN
#   (Chunk America/NNP)
#   supports/NNS
#   democratic/JJ
#   reform/NN
#   across/IN
#   the/DT
#   broader/JJR
#   (Chunk Middle/NNP East/NNP)
#   ./.)
# (S
#   Elections/NNS
#   are/VBP
#   vital/JJ
#   ,/,
#   but/CC
#   they/PRP
#   are/VBP
#   only/RB
#   the/DT
#   beginning/NN
#   ./.)
# (S
#   Raising/VBG
#   up/RP
#   a/DT
#   democracy/NN
#   requires/VBZ
#   the/DT
#   rule/NN
#   of/IN
#   law/NN
#   ,/,
#   and/CC
#   protection/NN
#   of/IN
#   minorities/NNS
#   ,/,
#   and/CC
#   strong/JJ
#   ,/,
#   accountable/JJ
#   institutions/NNS
#   that/IN
#   last/JJ
#   longer/JJR
#   than/IN
#   a/DT
#   single/JJ
#   vote/NN
#   ./.)
# (S
#   The/DT
#   great/JJ
#   people/NNS
#   of/IN
#   (Chunk Egypt/NNP)
#   have/VBP
#   voted/VBN
#   in/IN
#   a/DT
#   multi-party/JJ
#   presidential/JJ
#   election/NN
#   --/:
#   and/CC
#   now/RB
#   their/PRP$
#   government/NN
#   should/MD
#   open/VB
#   paths/NNS
#   of/IN
#   peaceful/JJ
#   opposition/NN
#   that/WDT
#   will/MD
#   reduce/VB
#   the/DT
#   appeal/NN
#   of/IN
#   radicalism/NN
#   ./.)
# (S
#   The/DT
#   Palestinian/JJ
#   people/NNS
#   have/VBP
#   voted/VBN
#   in/IN
#   elections/NNS
#   ./.)
# (S
#   And/CC
#   now/RB
#   the/DT
#   leaders/NNS
#   of/IN
#   (Chunk Hamas/NNP)
#   must/MD
#   (Chunk recognize/VB Israel/NNP)
#   ,/,
#   disarm/NN
#   ,/,
#   reject/JJ
#   terrorism/NN
#   ,/,
#   and/CC
#   work/NN
#   for/IN
#   lasting/VBG
#   peace/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Saudi/NNP Arabia/NNP)
#   has/VBZ
#   taken/VBN
#   the/DT
#   first/JJ
#   steps/NNS
#   of/IN
#   reform/NN
#   --/:
#   now/RB
#   it/PRP
#   can/MD
#   offer/VB
#   its/PRP$
#   people/NNS
#   a/DT
#   better/JJR
#   future/NN
#   by/IN
#   pressing/VBG
#   forward/RB
#   with/IN
#   those/DT
#   efforts/NNS
#   ./.)
# (S
#   Democracies/NNS
#   in/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP)
#   will/MD
#   not/RB
#   look/VB
#   like/IN
#   our/PRP$
#   own/JJ
#   ,/,
#   because/IN
#   they/PRP
#   will/MD
#   reflect/VB
#   the/DT
#   traditions/NNS
#   of/IN
#   their/PRP$
#   own/JJ
#   citizens/NNS
#   ./.)
# (S
#   Yet/RB
#   liberty/NN
#   is/VBZ
#   the/DT
#   future/NN
#   of/IN
#   every/DT
#   nation/NN
#   in/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP)
#   ,/,
#   because/IN
#   liberty/NN
#   is/VBZ
#   the/DT
#   right/NN
#   and/CC
#   hope/NN
#   of/IN
#   all/DT
#   humanity/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   waves/VBZ
#   toward/IN
#   the/DT
#   upper/JJ
#   visitors/NNS
#   gallery/NN
#   of/IN
#   the/DT
#   (Chunk House/NNP Chamber/NNP)
#   following/VBG
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (Chunk Union/NNP)
#   remarks/NNS
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   at/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   (Chunk Capitol/NNP)
#   ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP)
#   The/DT
#   same/JJ
#   is/VBZ
#   true/JJ
#   of/IN
#   (Chunk Iran/NNP)
#   ,/,
#   a/DT
#   nation/NN
#   now/RB
#   held/VBN
#   hostage/NN
#   by/IN
#   a/DT
#   small/JJ
#   clerical/JJ
#   elite/NN
#   that/WDT
#   is/VBZ
#   isolating/VBG
#   and/CC
#   repressing/VBG
#   its/PRP$
#   people/NNS
#   ./.)
# (S
#   The/DT
#   regime/NN
#   in/IN
#   that/DT
#   country/NN
#   sponsors/NNS
#   terrorists/NNS
#   in/IN
#   the/DT
#   Palestinian/JJ
#   territories/NNS
#   and/CC
#   in/IN
#   (Chunk Lebanon/NNP)
#   --/:
#   and/CC
#   that/DT
#   must/MD
#   come/VB
#   to/TO
#   an/DT
#   end/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   The/DT
#   Iranian/JJ
#   government/NN
#   is/VBZ
#   defying/VBG
#   the/DT
#   world/NN
#   with/IN
#   its/PRP$
#   nuclear/JJ
#   ambitions/NNS
#   ,/,
#   and/CC
#   the/DT
#   nations/NNS
#   of/IN
#   the/DT
#   world/NN
#   must/MD
#   not/RB
#   permit/VB
#   the/DT
#   Iranian/JJ
#   regime/NN
#   to/TO
#   gain/VB
#   nuclear/JJ
#   weapons/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   rally/VB
#   the/DT
#   world/NN
#   to/TO
#   confront/VB
#   these/DT
#   threats/NNS
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   ,/,
#   let/VB
#   me/PRP
#   speak/VB
#   directly/RB
#   to/TO
#   the/DT
#   citizens/NNS
#   of/IN
#   (Chunk Iran/NNP)
#   :/:
#   (Chunk America/NNP)
#   respects/VBZ
#   you/PRP
#   ,/,
#   and/CC
#   we/PRP
#   respect/VBP
#   your/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   respect/VBP
#   your/PRP$
#   right/NN
#   to/TO
#   choose/VB
#   your/PRP$
#   own/JJ
#   future/NN
#   and/CC
#   win/VB
#   your/PRP$
#   own/JJ
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   nation/NN
#   hopes/VBZ
#   one/CD
#   day/NN
#   to/TO
#   be/VB
#   the/DT
#   closest/JJS
#   of/IN
#   friends/NNS
#   with/IN
#   a/DT
#   free/JJ
#   and/CC
#   democratic/JJ
#   (Chunk Iran/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   To/TO
#   overcome/VB
#   dangers/NNS
#   in/IN
#   our/PRP$
#   world/NN
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   take/VB
#   the/DT
#   offensive/JJ
#   by/IN
#   encouraging/VBG
#   economic/JJ
#   progress/NN
#   ,/,
#   and/CC
#   fighting/VBG
#   disease/NN
#   ,/,
#   and/CC
#   spreading/VBG
#   hope/NN
#   in/IN
#   hopeless/JJ
#   lands/NNS
#   ./.)
# (S
#   (Chunk Isolationism/NNP)
#   would/MD
#   not/RB
#   only/RB
#   tie/VB
#   our/PRP$
#   hands/NNS
#   in/IN
#   fighting/VBG
#   enemies/NNS
#   ,/,
#   it/PRP
#   would/MD
#   keep/VB
#   us/PRP
#   from/IN
#   helping/VBG
#   our/PRP$
#   friends/NNS
#   in/IN
#   desperate/JJ
#   need/NN
#   ./.)
# (S
#   We/PRP
#   show/VBP
#   compassion/JJ
#   abroad/RB
#   because/IN
#   Americans/NNPS
#   believe/VBP
#   in/IN
#   the/DT
#   (Chunk God-given/NNP dignity/NN)
#   and/CC
#   worth/NN
#   of/IN
#   a/DT
#   villager/NN
#   with/IN
#   (Chunk HIV/AIDS/NNP)
#   ,/,
#   or/CC
#   an/DT
#   infant/NN
#   with/IN
#   malaria/NNS
#   ,/,
#   or/CC
#   a/DT
#   refugee/JJ
#   fleeing/NN
#   genocide/NN
#   ,/,
#   or/CC
#   a/DT
#   young/JJ
#   girl/NN
#   sold/VBN
#   into/IN
#   slavery/NN
#   ./.)
# (S
#   We/PRP
#   also/RB
#   show/VBP
#   compassion/NN
#   abroad/RB
#   because/IN
#   regions/NNS
#   overwhelmed/VBN
#   by/IN
#   poverty/NN
#   ,/,
#   corruption/NN
#   ,/,
#   and/CC
#   despair/NN
#   are/VBP
#   sources/NNS
#   of/IN
#   terrorism/NN
#   ,/,
#   and/CC
#   organized/VBD
#   crime/NN
#   ,/,
#   and/CC
#   human/JJ
#   trafficking/NN
#   ,/,
#   and/CC
#   the/DT
#   drug/NN
#   trade/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   have/VBP
#   taken/VBN
#   unprecedented/JJ
#   action/NN
#   to/TO
#   (Chunk fight/VB AIDS/NNP)
#   and/CC
#   malaria/NNS
#   ,/,
#   expand/VBP
#   the/DT
#   education/NN
#   of/IN
#   girls/NNS
#   ,/,
#   and/CC
#   reward/RB
#   developing/VBG
#   nations/NNS
#   that/WDT
#   are/VBP
#   moving/VBG
#   forward/RB
#   with/IN
#   economic/JJ
#   and/CC
#   political/JJ
#   reform/NN
#   ./.)
# (S
#   For/IN
#   people/NNS
#   everywhere/RB
#   ,/,
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   is/VBZ
#   a/DT
#   partner/NN
#   for/IN
#   a/DT
#   better/JJR
#   life/NN
#   ./.)
# (S
#   Short-changing/VBG
#   these/DT
#   efforts/NNS
#   would/MD
#   increase/VB
#   the/DT
#   suffering/NN
#   and/CC
#   chaos/NN
#   of/IN
#   our/PRP$
#   world/NN
#   ,/,
#   undercut/JJ
#   our/PRP$
#   long-term/JJ
#   security/NN
#   ,/,
#   and/CC
#   dull/VB
#   the/DT
#   conscience/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   to/TO
#   serve/VB
#   the/DT
#   interests/NNS
#   of/IN
#   (Chunk America/NNP)
#   by/IN
#   showing/VBG
#   the/DT
#   compassion/NN
#   of/IN
#   (Chunk America/NNP)
#   ./.)
# (S
#   Our/PRP$
#   country/NN
#   must/MD
#   also/RB
#   remain/VB
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terrorism/NN
#   here/RB
#   at/IN
#   home/NN
#   ./.)
# (S
#   The/DT
#   enemy/NN
#   has/VBZ
#   not/RB
#   lost/VBN
#   the/DT
#   desire/NN
#   or/CC
#   capability/NN
#   to/TO
#   attack/VB
#   us/PRP
#   ./.)
# (S
#   Fortunately/RB
#   ,/,
#   this/DT
#   nation/NN
#   has/VBZ
#   superb/VBN
#   professionals/NNS
#   in/IN
#   law/NN
#   enforcement/NN
#   ,/,
#   intelligence/NN
#   ,/,
#   the/DT
#   military/JJ
#   ,/,
#   and/CC
#   homeland/VBP
#   security/NN
#   ./.)
# (S
#   These/DT
#   men/NNS
#   and/CC
#   women/NNS
#   are/VBP
#   dedicating/VBG
#   their/PRP$
#   lives/NNS
#   ,/,
#   protecting/VBG
#   us/PRP
#   all/DT
#   ,/,
#   and/CC
#   they/PRP
#   deserve/VBP
#   our/PRP$
#   support/NN
#   and/CC
#   our/PRP$
#   thanks/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   They/PRP
#   also/RB
#   deserve/VBP
#   the/DT
#   same/JJ
#   tools/NNS
#   they/PRP
#   already/RB
#   use/VBP
#   to/TO
#   fight/VB
#   drug/NN
#   trafficking/NN
#   and/CC
#   organized/VBN
#   crime/NN
#   --/:
#   so/RB
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   reauthorize/VB
#   the/DT
#   (Chunk Patriot/NNP Act/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   It/PRP
#   is/VBZ
#   said/VBD
#   that/IN
#   prior/JJ
#   to/TO
#   the/DT
#   attacks/NNS
#   of/IN
#   (Chunk September/NNP)
#   the/DT
#   11th/CD
#   ,/,
#   our/PRP$
#   government/NN
#   failed/VBD
#   to/TO
#   connect/VB
#   the/DT
#   dots/NNS
#   of/IN
#   the/DT
#   conspiracy/NN
#   ./.)
# (S
#   We/PRP
#   now/RB
#   know/VBP
#   that/IN
#   two/CD
#   of/IN
#   the/DT
#   hijackers/NNS
#   in/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   placed/VBD
#   telephone/NN
#   calls/NNS
#   to/TO
#   (Chunk al/VB Qaeda/NNP)
#   operatives/VBZ
#   overseas/RB
#   ./.)
# (S
#   But/CC
#   we/PRP
#   did/VBD
#   not/RB
#   know/VB
#   about/IN
#   their/PRP$
#   plans/NNS
#   until/IN
#   it/PRP
#   was/VBD
#   too/RB
#   late/JJ
#   ./.)
# (S
#   So/RB
#   to/TO
#   prevent/VB
#   another/DT
#   attack/NN
#   --/:
#   based/VBN
#   on/IN
#   authority/NN
#   given/VBN
#   to/TO
#   me/PRP
#   by/IN
#   the/DT
#   (Chunk Constitution/NNP)
#   and/CC
#   by/IN
#   statute/NN
#   --/:
#   I/PRP
#   have/VBP
#   authorized/VBN
#   a/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   to/TO
#   aggressively/RB
#   pursue/VB
#   the/DT
#   international/JJ
#   communications/NNS
#   of/IN
#   suspected/JJ
#   al/JJ
#   (Chunk Qaeda/NNP)
#   operatives/NNS
#   and/CC
#   affiliates/NNS
#   to/TO
#   and/CC
#   from/IN
#   (Chunk America/NNP)
#   ./.)
# (S
#   Previous/JJ
#   Presidents/NNS
#   have/VBP
#   used/VBN
#   the/DT
#   same/JJ
#   constitutional/JJ
#   authority/NN
#   I/PRP
#   have/VBP
#   ,/,
#   and/CC
#   federal/JJ
#   courts/NNS
#   have/VBP
#   approved/VBN
#   the/DT
#   use/NN
#   of/IN
#   that/DT
#   authority/NN
#   ./.)
# (S
#   Appropriate/JJ
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   have/VBP
#   been/VBN
#   kept/VBN
#   informed/VBN
#   ./.)
# (S
#   The/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   has/VBZ
#   helped/VBN
#   prevent/VB
#   terrorist/JJ
#   attacks/NNS
#   ./.)
# (S
#   It/PRP
#   remains/VBZ
#   essential/JJ
#   to/TO
#   the/DT
#   security/NN
#   of/IN
#   (Chunk America/NNP)
#   ./.)
# (S
#   If/IN
#   there/EX
#   are/VBP
#   people/NNS
#   inside/IN
#   our/PRP$
#   country/NN
#   who/WP
#   are/VBP
#   talking/VBG
#   with/IN
#   al/NN
#   (Chunk Qaeda/NNP)
#   ,/,
#   we/PRP
#   want/VBP
#   to/TO
#   know/VB
#   about/IN
#   it/PRP
#   ,/,
#   because/IN
#   we/PRP
#   will/MD
#   not/RB
#   sit/VB
#   back/RB
#   and/CC
#   wait/NN
#   to/TO
#   be/VB
#   hit/VBN
#   again/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   In/IN
#   all/PDT
#   these/DT
#   areas/NNS
#   --/:
#   from/IN
#   the/DT
#   disruption/NN
#   of/IN
#   terror/NN
#   networks/NNS
#   ,/,
#   to/TO
#   victory/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   ,/,
#   to/TO
#   the/DT
#   spread/NN
#   of/IN
#   freedom/NN
#   and/CC
#   hope/NN
#   in/IN
#   troubled/JJ
#   regions/NNS
#   --/:
#   we/PRP
#   need/VBP
#   the/DT
#   support/NN
#   of/IN
#   our/PRP$
#   friends/NNS
#   and/CC
#   allies/NNS
#   ./.)
# (S
#   To/TO
#   draw/VB
#   that/DT
#   support/NN
#   ,/,
#   we/PRP
#   must/MD
#   always/RB
#   be/VB
#   clear/JJ
#   in/IN
#   our/PRP$
#   principles/NNS
#   and/CC
#   willing/JJ
#   to/TO
#   act/VB
#   ./.)
# (S
#   The/DT
#   only/JJ
#   alternative/NN
#   to/TO
#   American/JJ
#   leadership/NN
#   is/VBZ
#   a/DT
#   dramatically/RB
#   more/RBR
#   dangerous/JJ
#   and/CC
#   anxious/JJ
#   world/NN
#   ./.)
# (S
#   Yet/CC
#   we/PRP
#   also/RB
#   choose/VBP
#   to/TO
#   lead/VB
#   because/IN
#   it/PRP
#   is/VBZ
#   a/DT
#   privilege/NN
#   to/TO
#   serve/VB
#   the/DT
#   values/NNS
#   that/WDT
#   gave/VBD
#   us/PRP
#   birth/NN
#   ./.)
# (S
#   American/JJ
#   leaders/NNS
#   --/:
#   from/IN
#   (Chunk Roosevelt/NNP)
#   to/TO
#   (Chunk Truman/NNP)
#   to/TO
#   (Chunk Kennedy/NNP)
#   to/TO
#   (Chunk Reagan/NNP)
#   --/:
#   rejected/VBD
#   isolation/NN
#   and/CC
#   retreat/NN
#   ,/,
#   because/IN
#   they/PRP
#   knew/VBD
#   that/IN
#   (Chunk America/NNP)
#   is/VBZ
#   always/RB
#   more/RBR
#   secure/JJ
#   when/WRB
#   freedom/NN
#   is/VBZ
#   on/IN
#   the/DT
#   march/NN
#   ./.)
# (S
#   Our/PRP$
#   own/JJ
#   generation/NN
#   is/VBZ
#   in/IN
#   a/DT
#   long/JJ
#   war/NN
#   against/IN
#   a/DT
#   determined/JJ
#   enemy/NN
#   --/:
#   a/DT
#   war/NN
#   that/WDT
#   will/MD
#   be/VB
#   fought/VBN
#   by/IN
#   Presidents/NNS
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   who/WP
#   will/MD
#   need/VB
#   steady/JJ
#   bipartisan/JJ
#   support/NN
#   from/IN
#   the/DT
#   (Chunk Congress/NNP)
#   ./.)
# (S And/CC tonight/NN I/PRP ask/VBP for/IN yours/NNS ./.)
# (S
#   Together/RB
#   ,/,
#   let/VB
#   us/PRP
#   protect/VB
#   our/PRP$
#   country/NN
#   ,/,
#   support/VB
#   the/DT
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   defend/VBP
#   us/PRP
#   ,/,
#   and/CC
#   lead/VB
#   this/DT
#   world/NN
#   toward/IN
#   freedom/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Here/RB
#   at/IN
#   home/NN
#   ,/,
#   (Chunk America/NNP)
#   also/RB
#   has/VBZ
#   a/DT
#   great/JJ
#   opportunity/NN
#   :/:
#   We/PRP
#   will/MD
#   build/VB
#   the/DT
#   prosperity/NN
#   of/IN
#   our/PRP$
#   country/NN
#   by/IN
#   strengthening/VBG
#   our/PRP$
#   economic/JJ
#   leadership/NN
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   Our/PRP$
#   economy/NN
#   is/VBZ
#   healthy/JJ
#   and/CC
#   vigorous/JJ
#   ,/,
#   and/CC
#   growing/VBG
#   faster/RBR
#   than/IN
#   other/JJ
#   major/JJ
#   industrialized/VBN
#   nations/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   two-and-a-half/JJ
#   years/NNS
#   ,/,
#   (Chunk America/NNP)
#   has/VBZ
#   created/VBN
#   4.6/CD
#   million/CD
#   new/JJ
#   jobs/NNS
#   --/:
#   more/JJR
#   than/IN
#   (Chunk Japan/NNP)
#   and/CC
#   the/DT
#   (Chunk European/NNP Union/NNP)
#   combined/VBD
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Even/RB
#   in/IN
#   the/DT
#   face/NN
#   of/IN
#   higher/JJR
#   energy/NN
#   prices/NNS
#   and/CC
#   natural/JJ
#   disasters/NNS
#   ,/,
#   the/DT
#   American/JJ
#   people/NNS
#   have/VBP
#   turned/VBN
#   in/IN
#   an/DT
#   economic/JJ
#   performance/NN
#   that/WDT
#   is/VBZ
#   the/DT
#   envy/NN
#   of/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   The/DT
#   American/JJ
#   economy/NN
#   is/VBZ
#   preeminent/JJ
#   ,/,
#   but/CC
#   we/PRP
#   can/MD
#   not/RB
#   afford/VB
#   to/TO
#   be/VB
#   complacent/JJ
#   ./.)
# (S
#   In/IN
#   a/DT
#   dynamic/JJ
#   world/NN
#   economy/NN
#   ,/,
#   we/PRP
#   are/VBP
#   seeing/VBG
#   new/JJ
#   competitors/NNS
#   ,/,
#   like/IN
#   (Chunk China/NNP)
#   and/CC
#   (Chunk India/NNP)
#   ,/,
#   and/CC
#   this/DT
#   creates/VBZ
#   uncertainty/NN
#   ,/,
#   which/WDT
#   makes/VBZ
#   it/PRP
#   easier/JJR
#   to/TO
#   feed/VB
#   people/NNS
#   's/POS
#   fears/NNS
#   ./.)
# (S
#   So/IN
#   we/PRP
#   're/VBP
#   seeing/VBG
#   some/DT
#   old/JJ
#   temptations/NNS
#   return/NN
#   ./.)
# (S
#   Protectionists/NNS
#   want/VBP
#   to/TO
#   escape/VB
#   competition/NN
#   ,/,
#   pretending/VBG
#   that/IN
#   we/PRP
#   can/MD
#   keep/VB
#   our/PRP$
#   high/JJ
#   standard/NN
#   of/IN
#   living/NN
#   while/IN
#   walling/VBG
#   off/RP
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Others/NNS
#   say/VBP
#   that/IN
#   the/DT
#   government/NN
#   needs/VBZ
#   to/TO
#   take/VB
#   a/DT
#   larger/JJR
#   role/NN
#   in/IN
#   directing/VBG
#   the/DT
#   economy/NN
#   ,/,
#   centralizing/VBG
#   more/JJR
#   power/NN
#   in/IN
#   (Chunk Washington/NNP)
#   and/CC
#   increasing/VBG
#   taxes/NNS
#   ./.)
# (S
#   We/PRP
#   hear/VBP
#   claims/NNS
#   that/IN
#   immigrants/NNS
#   are/VBP
#   somehow/RB
#   bad/JJ
#   for/IN
#   the/DT
#   economy/NN
#   --/:
#   even/RB
#   though/IN
#   this/DT
#   economy/NN
#   could/MD
#   not/RB
#   function/VB
#   without/IN
#   them/PRP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   All/PDT
#   these/DT
#   are/VBP
#   forms/NNS
#   of/IN
#   economic/JJ
#   retreat/NN
#   ,/,
#   and/CC
#   they/PRP
#   lead/VBP
#   in/IN
#   the/DT
#   same/JJ
#   direction/NN
#   --/:
#   toward/IN
#   a/DT
#   stagnant/JJ
#   and/CC
#   second-rate/JJ
#   economy/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   I/PRP
#   will/MD
#   set/VB
#   out/RP
#   a/DT
#   better/JJR
#   path/NN
#   :/:
#   an/DT
#   agenda/NN
#   for/IN
#   a/DT
#   nation/NN
#   that/WDT
#   competes/VBZ
#   with/IN
#   confidence/NN
#   ;/:
#   an/DT
#   agenda/NN
#   that/WDT
#   will/MD
#   raise/VB
#   standards/NNS
#   of/IN
#   living/NN
#   and/CC
#   generate/VB
#   new/JJ
#   jobs/NNS
#   ./.)
# (S
#   Americans/NNPS
#   should/MD
#   not/RB
#   fear/VB
#   our/PRP$
#   economic/JJ
#   future/NN
#   ,/,
#   because/IN
#   we/PRP
#   intend/VBP
#   to/TO
#   shape/VB
#   it/PRP
#   ./.)
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   begins/NNS
#   with/IN
#   keeping/VBG
#   our/PRP$
#   economy/NN
#   growing/VBG
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   economy/NN
#   grows/VBZ
#   when/WRB
#   Americans/NNPS
#   have/VBP
#   more/JJR
#   of/IN
#   their/PRP$
#   own/JJ
#   money/NN
#   to/TO
#   spend/VB
#   ,/,
#   save/VB
#   ,/,
#   and/CC
#   invest/JJS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   five/CD
#   years/NNS
#   ,/,
#   the/DT
#   tax/NN
#   relief/NN
#   you/PRP
#   passed/VBN
#   has/VBZ
#   left/VBN
#   $/$
#   880/CD
#   billion/CD
#   in/IN
#   the/DT
#   hands/NNS
#   of/IN
#   American/JJ
#   workers/NNS
#   ,/,
#   investors/NNS
#   ,/,
#   small/JJ
#   businesses/NNS
#   ,/,
#   and/CC
#   families/NNS
#   --/:
#   and/CC
#   they/PRP
#   have/VBP
#   used/VBN
#   it/PRP
#   to/TO
#   help/VB
#   produce/VB
#   more/JJR
#   than/IN
#   four/CD
#   years/NNS
#   of/IN
#   uninterrupted/JJ
#   economic/JJ
#   growth/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   the/DT
#   tax/NN
#   relief/NN
#   is/VBZ
#   set/VBN
#   to/TO
#   expire/VB
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   years/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   do/VBP
#   nothing/NN
#   ,/,
#   (Chunk American/NNP)
#   families/NNS
#   will/MD
#   face/VB
#   a/DT
#   massive/JJ
#   tax/NN
#   increase/NN
#   they/PRP
#   do/VBP
#   not/RB
#   expect/VB
#   and/CC
#   will/MD
#   not/RB
#   welcome/VB
#   ./.)
# (S
#   Because/IN
#   (Chunk America/NNP)
#   needs/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   temporary/JJ
#   expansion/NN
#   ,/,
#   we/PRP
#   need/VBP
#   more/JJR
#   than/IN
#   temporary/JJ
#   tax/NN
#   relief/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   the/DT
#   (Chunk Congress/NNP)
#   to/TO
#   act/VB
#   responsibly/RB
#   ,/,
#   and/CC
#   make/VB
#   the/DT
#   tax/NN
#   cuts/NNS
#   permanent/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   be/VB
#   good/JJ
#   stewards/NNS
#   of/IN
#   tax/NN
#   dollars/NNS
#   ./.)
# (S
#   Every/DT
#   year/NN
#   of/IN
#   my/PRP$
#   presidency/NN
#   ,/,
#   we/PRP
#   've/VBP
#   reduced/VBN
#   the/DT
#   growth/NN
#   of/IN
#   non-security/JJ
#   discretionary/JJ
#   spending/NN
#   ,/,
#   and/CC
#   last/JJ
#   year/NN
#   you/PRP
#   passed/VBD
#   bills/NNS
#   that/IN
#   cut/VBD
#   this/DT
#   spending/NN
#   ./.)
# (S
#   This/DT
#   year/NN
#   my/PRP$
#   budget/NN
#   will/MD
#   cut/VB
#   it/PRP
#   again/RB
#   ,/,
#   and/CC
#   reduce/VB
#   or/CC
#   eliminate/VB
#   more/JJR
#   than/IN
#   140/CD
#   programs/NNS
#   that/WDT
#   are/VBP
#   performing/VBG
#   poorly/RB
#   or/CC
#   not/RB
#   fulfilling/JJ
#   essential/JJ
#   priorities/NNS
#   ./.)
# (S
#   By/IN
#   passing/VBG
#   these/DT
#   reforms/NNS
#   ,/,
#   we/PRP
#   will/MD
#   save/VB
#   the/DT
#   (Chunk American/NNP taxpayer/NN)
#   another/DT
#   $/$
#   14/CD
#   billion/CD
#   next/JJ
#   year/NN
#   ,/,
#   and/CC
#   stay/VB
#   on/IN
#   track/NN
#   to/TO
#   cut/VB
#   the/DT
#   deficit/NN
#   in/IN
#   half/NN
#   by/IN
#   2009/CD
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   I/PRP
#   am/VBP
#   pleased/JJ
#   that/IN
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   are/VBP
#   working/VBG
#   on/IN
#   earmark/NN
#   reform/NN
#   ,/,
#   because/IN
#   the/DT
#   federal/JJ
#   budget/NN
#   has/VBZ
#   too/RB
#   many/JJ
#   special/JJ
#   interest/NN
#   projects/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   can/MD
#   tackle/VB
#   this/DT
#   problem/NN
#   together/RB
#   ,/,
#   if/IN
#   you/PRP
#   pass/VBP
#   the/DT
#   line-item/JJ
#   veto/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
#   must/MD
#   also/RB
#   confront/VB
#   the/DT
#   larger/JJR
#   challenge/NN
#   of/IN
#   mandatory/JJ
#   spending/NN
#   ,/,
#   or/CC
#   entitlements/NNS
#   ./.)
# (S
#   This/DT
#   year/NN
#   ,/,
#   the/DT
#   first/JJ
#   of/IN
#   about/RB
#   78/CD
#   million/CD
#   baby/NN
#   boomers/NNS
#   turn/VBP
#   60/CD
#   ,/,
#   including/VBG
#   two/CD
#   of/IN
#   my/PRP$
#   (Chunk Dad/NNP)
#   's/POS
#   favorite/JJ
#   people/NNS
#   --/:
#   me/PRP
#   and/CC
#   (Chunk President/NNP Clinton/NNP)
#   ./.)
# (S (/( (Chunk Laughter/NNP) ./. )/))
# (S
#   This/DT
#   milestone/NN
#   is/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   personal/JJ
#   crisis/NN
#   --/:
#   (/(
#   laughter/NN
#   )/)
#   --/:
#   it/PRP
#   is/VBZ
#   a/DT
#   national/JJ
#   challenge/NN
#   ./.)
# (S
#   The/DT
#   retirement/NN
#   of/IN
#   the/DT
#   baby/NN
#   boom/NN
#   generation/NN
#   will/MD
#   put/VB
#   unprecedented/JJ
#   strains/NNS
#   on/IN
#   the/DT
#   federal/JJ
#   government/NN
#   ./.)
# (S
#   By/IN
#   2030/CD
#   ,/,
#   spending/VBG
#   for/IN
#   (Chunk Social/NNP Security/NNP)
#   ,/,
#   (Chunk Medicare/NNP)
#   and/CC
#   (Chunk Medicaid/NNP)
#   alone/RB
#   will/MD
#   be/VB
#   almost/RB
#   60/CD
#   percent/NN
#   of/IN
#   the/DT
#   entire/JJ
#   federal/JJ
#   budget/NN
#   ./.)
# (S
#   And/CC
#   that/DT
#   will/MD
#   present/VB
#   future/JJ
#   Congresses/NNS
#   with/IN
#   impossible/JJ
#   choices/NNS
#   --/:
#   staggering/VBG
#   tax/NN
#   increases/NNS
#   ,/,
#   immense/JJ
#   deficits/NNS
#   ,/,
#   or/CC
#   deep/JJ
#   cuts/NNS
#   in/IN
#   every/DT
#   category/NN
#   of/IN
#   spending/NN
#   ./.)
# (S
#   (Chunk Congress/NNP)
#   did/VBD
#   not/RB
#   act/VB
#   last/JJ
#   year/NN
#   on/IN
#   my/PRP$
#   proposal/NN
#   to/TO
#   (Chunk save/VB Social/NNP Security/NNP)
#   --/:
#   (/(
#   applause/NN
#   )/)
#   --/:
#   yet/RB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   entitlements/NNS
#   is/VBZ
#   a/DT
#   problem/NN
#   that/WDT
#   is/VBZ
#   not/RB
#   going/VBG
#   away/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   And/CC
#   every/DT
#   year/NN
#   we/PRP
#   fail/VBP
#   to/TO
#   act/VB
#   ,/,
#   the/DT
#   situation/NN
#   gets/VBZ
#   worse/JJR
#   ./.)
# (S
#   So/RB
#   tonight/JJ
#   ,/,
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   join/VB
#   me/PRP
#   in/IN
#   creating/VBG
#   a/DT
#   commission/NN
#   to/TO
#   examine/VB
#   the/DT
#   full/JJ
#   impact/NN
#   of/IN
#   baby/NN
#   boom/NN
#   retirements/NNS
#   on/IN
#   (Chunk Social/NNP Security/NNP)
#   ,/,
#   (Chunk Medicare/NNP)
#   ,/,
#   and/CC
#   (Chunk Medicaid/NNP)
#   ./.)
# (S
#   This/DT
#   commission/NN
#   should/MD
#   include/VB
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   and/CC
#   offer/VBP
#   bipartisan/JJ
#   solutions/NNS
#   ./.)
# (S
#   We/PRP
#   need/VBP
#   to/TO
#   put/VB
#   aside/RP
#   partisan/JJ
#   politics/NNS
#   and/CC
#   work/NN
#   together/RB
#   and/CC
#   get/VB
#   this/DT
#   problem/NN
#   solved/VBD
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   open/VB
#   more/JJR
#   markets/NNS
#   for/IN
#   all/DT
#   that/DT
#   Americans/NNPS
#   make/VBP
#   and/CC
#   grow/VB
#   ./.)
# (S
#   One/CD
#   out/NN
#   of/IN
#   every/DT
#   five/CD
#   factory/NN
#   jobs/NNS
#   in/IN
#   (Chunk America/NNP)
#   is/VBZ
#   related/VBN
#   to/TO
#   global/JJ
#   trade/NN
#   ,/,
#   and/CC
#   we/PRP
#   want/VBP
#   people/NNS
#   everywhere/RB
#   to/TO
#   (Chunk buy/VB American/NNP)
#   ./.)
# (S
#   With/IN
#   open/JJ
#   markets/NNS
#   and/CC
#   a/DT
#   level/JJ
#   playing/NN
#   field/NN
#   ,/,
#   no/DT
#   one/NN
#   can/MD
#   out-produce/VB
#   or/CC
#   out-compete/VB
#   the/DT
#   American/JJ
#   worker/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   an/DT
#   immigration/NN
#   system/NN
#   that/WDT
#   upholds/VBZ
#   our/PRP$
#   laws/NNS
#   ,/,
#   reflects/VBZ
#   our/PRP$
#   values/NNS
#   ,/,
#   and/CC
#   serves/VBZ
#   the/DT
#   interests/NNS
#   of/IN
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Our/PRP$
#   nation/NN
#   needs/VBZ
#   orderly/JJ
#   and/CC
#   secure/JJ
#   borders/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   To/TO
#   meet/VB
#   this/DT
#   goal/NN
#   ,/,
#   we/PRP
#   must/MD
#   have/VB
#   stronger/JJR
#   immigration/NN
#   enforcement/NN
#   and/CC
#   border/NN
#   protection/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   must/MD
#   have/VB
#   a/DT
#   rational/JJ
#   ,/,
#   humane/JJ
#   guest/JJS
#   worker/NN
#   program/NN
#   that/WDT
#   rejects/VBZ
#   amnesty/JJ
#   ,/,
#   allows/VBZ
#   temporary/JJ
#   jobs/NNS
#   for/IN
#   people/NNS
#   who/WP
#   seek/VBP
#   them/PRP
#   legally/RB
#   ,/,
#   and/CC
#   reduces/NNS
#   smuggling/VBG
#   and/CC
#   crime/NN
#   at/IN
#   the/DT
#   border/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   affordable/JJ
#   health/NN
#   care/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   government/NN
#   has/VBZ
#   a/DT
#   responsibility/NN
#   to/TO
#   provide/VB
#   health/NN
#   care/NN
#   for/IN
#   the/DT
#   poor/JJ
#   and/CC
#   the/DT
#   elderly/JJ
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   meeting/VBG
#   that/IN
#   responsibility/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   For/IN
#   all/DT
#   Americans/NNPS
#   --/:
#   for/IN
#   all/DT
#   Americans/NNPS
#   ,/,
#   we/PRP
#   must/MD
#   confront/VB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   care/NN
#   ,/,
#   strengthen/VB
#   the/DT
#   doctor-patient/JJ
#   relationship/NN
#   ,/,
#   and/CC
#   help/NN
#   people/NNS
#   afford/VBP
#   the/DT
#   insurance/NN
#   coverage/NN
#   they/PRP
#   need/VBP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   make/VB
#   wider/JJR
#   use/NN
#   of/IN
#   electronic/JJ
#   records/NNS
#   and/CC
#   other/JJ
#   health/NN
#   information/NN
#   technology/NN
#   ,/,
#   to/TO
#   help/VB
#   control/VB
#   costs/NNS
#   and/CC
#   reduce/VB
#   dangerous/JJ
#   medical/JJ
#   errors/NNS
#   ./.)
# (S
#   We/PRP
#   will/MD
#   strengthen/VB
#   health/NN
#   savings/NNS
#   accounts/NNS
#   --/:
#   making/VBG
#   sure/JJ
#   individuals/NNS
#   and/CC
#   small/JJ
#   business/NN
#   employees/NNS
#   can/MD
#   buy/VB
#   insurance/NN
#   with/IN
#   the/DT
#   same/JJ
#   advantages/VBZ
#   that/IN
#   people/NNS
#   working/VBG
#   for/IN
#   big/JJ
#   businesses/NNS
#   now/RB
#   get/VBP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
# ...
#   ,/,
#   which/WDT
#   is/VBZ
#   raising/VBG
#   standards/NNS
#   and/CC
#   lifting/VBG
#   test/NN
#   scores/NNS
#   across/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   I/PRP
#   propose/VBP
#   to/TO
#   train/VB
#   70,000/CD
#   high/JJ
#   school/NN
#   teachers/NNS
#   to/TO
#   lead/VB
#   advanced-placement/JJ
#   courses/NNS
#   in/IN
#   math/NN
#   and/CC
#   science/NN
#   ,/,
#   bring/VBG
#   30,000/CD
#   math/NN
#   and/CC
#   science/NN
#   professionals/NNS
#   to/TO
#   teach/VB
#   in/IN
#   classrooms/NNS
#   ,/,
#   and/CC
#   give/VB
#   early/JJ
#   help/NN
#   to/TO
#   students/NNS
#   who/WP
#   struggle/VBP
#   with/IN
#   math/NN
#   ,/,
#   so/IN
#   they/PRP
#   have/VBP
#   a/DT
#   better/JJR
#   chance/NN
#   at/IN
#   good/JJ
#   ,/,
#   high-wage/JJ
#   jobs/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   ensure/VB
#   that/IN
#   (Chunk America/NNP)
#   's/POS
#   children/NNS
#   succeed/VB
#   in/IN
#   life/NN
#   ,/,
#   they/PRP
#   will/MD
#   ensure/VB
#   that/IN
#   (Chunk America/NNP)
#   succeeds/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Preparing/VBG
#   our/PRP$
#   nation/NN
#   to/TO
#   compete/VB
#   in/IN
#   the/DT
#   world/NN
#   is/VBZ
#   a/DT
#   goal/NN
#   that/IN
#   all/DT
#   of/IN
#   us/PRP
#   can/MD
#   share/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   you/PRP
#   to/TO
#   support/VB
#   the/DT
#   American/JJ
#   (Chunk Competitiveness/NNP Initiative/NNP)
#   ,/,
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   show/VB
#   the/DT
#   world/NN
#   what/WP
#   the/DT
#   American/JJ
#   people/NNS
#   can/MD
#   achieve/VB
#   ./.)
# (S
#   (Chunk America/NNP)
#   is/VBZ
#   a/DT
#   great/JJ
#   force/NN
#   for/IN
#   freedom/NN
#   and/CC
#   prosperity/NN
#   ./.)
# (S
#   Yet/RB
#   our/PRP$
#   greatness/NN
#   is/VBZ
#   not/RB
#   measured/VBN
#   in/IN
#   power/NN
#   or/CC
#   luxuries/NNS
#   ,/,
#   but/CC
#   by/IN
#   who/WP
#   we/PRP
#   are/VBP
#   and/CC
#   how/WRB
#   we/PRP
#   treat/VBP
#   one/CD
#   another/DT
#   ./.)
# (S
#   So/IN
#   we/PRP
#   strive/VBP
#   to/TO
#   be/VB
#   a/DT
#   compassionate/NN
#   ,/,
#   decent/NN
#   ,/,
#   hopeful/JJ
#   society/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   (Chunk America/NNP)
#   has/VBZ
#   become/VBN
#   a/DT
#   more/RBR
#   hopeful/JJ
#   nation/NN
#   ./.)
# (S
#   Violent/JJ
#   crime/NN
#   rates/NNS
#   have/VBP
#   fallen/VBN
#   to/TO
#   their/PRP$
#   lowest/JJS
#   levels/NNS
#   since/IN
#   the/DT
#   1970s/CD
#   ./.)
# (S
#   Welfare/NN
#   cases/NNS
#   have/VBP
#   dropped/VBN
#   by/IN
#   more/JJR
#   than/IN
#   half/NN
#   over/IN
#   the/DT
#   past/JJ
#   decade/NN
#   ./.)
# (S
#   Drug/NN
#   use/NN
#   among/IN
#   youth/NN
#   is/VBZ
#   down/RB
#   19/CD
#   percent/NN
#   since/IN
#   2001/CD
#   ./.)
# (S
#   There/EX
#   are/VBP
#   fewer/JJR
#   abortions/NNS
#   in/IN
#   (Chunk America/NNP)
#   than/IN
#   at/IN
#   any/DT
#   point/NN
#   in/IN
#   the/DT
#   last/JJ
#   three/CD
#   decades/NNS
#   ,/,
#   and/CC
#   the/DT
#   number/NN
#   of/IN
#   children/NNS
#   born/VBN
#   to/TO
#   teenage/VB
#   mothers/NNS
#   has/VBZ
#   been/VBN
#   falling/VBG
#   for/IN
#   a/DT
#   dozen/NN
#   years/NNS
#   in/IN
#   a/DT
#   row/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   These/DT
#   gains/NNS
#   are/VBP
#   evidence/NN
#   of/IN
#   a/DT
#   quiet/JJ
#   transformation/NN
#   --/:
#   a/DT
#   revolution/NN
#   of/IN
#   conscience/NN
#   ,/,
#   in/IN
#   which/WDT
#   a/DT
#   rising/VBG
#   generation/NN
#   is/VBZ
#   finding/VBG
#   that/IN
#   a/DT
#   life/NN
#   of/IN
#   personal/JJ
#   responsibility/NN
#   is/VBZ
#   a/DT
#   life/NN
#   of/IN
#   fulfillment/NN
#   ./.)
# (S (Chunk Government/NNP) has/VBZ played/VBN a/DT role/NN ./.)
# (S
#   (Chunk Wise/NNP)
#   policies/NNS
#   ,/,
#   such/JJ
#   as/IN
#   welfare/NN
#   reform/NN
#   and/CC
#   drug/NN
#   education/NN
#   and/CC
#   support/NN
#   for/IN
#   abstinence/NN
#   and/CC
#   adoption/NN
#   have/VBP
#   made/VBN
#   a/DT
#   difference/NN
#   in/IN
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   And/CC
#   everyone/NN
#   here/RB
#   tonight/RB
#   ,/,
#   (Chunk Democrat/NNP)
#   and/CC
#   (Chunk Republican/NNP)
#   ,/,
#   has/VBZ
#   a/DT
#   right/NN
#   to/TO
#   be/VB
#   proud/JJ
#   of/IN
#   this/DT
#   record/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   many/JJ
#   Americans/NNPS
#   ,/,
#   especially/RB
#   parents/NNS
#   ,/,
#   still/RB
#   have/VBP
#   deep/JJ
#   concerns/NNS
#   about/IN
#   the/DT
#   direction/NN
#   of/IN
#   our/PRP$
#   culture/NN
#   ,/,
#   and/CC
#   the/DT
#   health/NN
#   of/IN
#   our/PRP$
#   most/JJS
#   basic/JJ
#   institutions/NNS
#   ./.)
# (S
#   They/PRP
#   're/VBP
#   concerned/VBN
#   about/IN
#   unethical/JJ
#   conduct/NN
#   by/IN
#   public/JJ
#   officials/NNS
#   ,/,
#   and/CC
#   discouraged/VBN
#   by/IN
#   activist/NN
#   courts/NNS
#   that/WDT
#   try/VBP
#   to/TO
#   redefine/VB
#   marriage/NN
#   ./.)
# (S
#   They/PRP
#   worry/VBP
#   about/IN
#   children/NNS
#   in/IN
#   our/PRP$
#   society/NN
#   who/WP
#   need/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ,/,
#   and/CC
#   about/IN
#   fellow/JJ
#   citizens/NNS
#   still/RB
#   displaced/VBN
#   by/IN
#   natural/JJ
#   disaster/NN
#   ,/,
#   and/CC
#   about/IN
#   suffering/VBG
#   caused/VBN
#   by/IN
#   treatable/JJ
#   diseases/NNS
#   ./.)
# (S
#   As/IN
#   we/PRP
#   look/VBP
#   at/IN
#   these/DT
#   challenges/NNS
#   ,/,
#   we/PRP
#   must/MD
#   never/RB
#   give/VB
#   in/IN
#   to/TO
#   the/DT
#   belief/NN
#   that/IN
#   (Chunk America/NNP)
#   is/VBZ
#   in/IN
#   decline/NN
#   ,/,
#   or/CC
#   that/IN
#   our/PRP$
#   culture/NN
#   is/VBZ
#   doomed/VBN
#   to/TO
#   unravel/VB
#   ./.)
# (S
#   The/DT
#   American/JJ
#   people/NNS
#   know/VBP
#   better/JJR
#   than/IN
#   that/DT
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   proven/VBN
#   the/DT
#   pessimists/NNS
#   wrong/JJ
#   before/RB
#   --/:
#   and/CC
#   we/PRP
#   will/MD
#   do/VB
#   it/PRP
#   again/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   depends/VBZ
#   on/IN
#   courts/NNS
#   that/IN
#   deliver/VBP
#   equal/JJ
#   justice/NN
#   under/IN
#   the/DT
#   law/NN
#   ./.)
# (S
#   The/DT
#   (Chunk Supreme/NNP Court/NNP)
#   now/RB
#   has/VBZ
#   two/CD
#   superb/JJ
#   new/JJ
#   members/NNS
#   --/:
#   new/JJ
#   members/NNS
#   on/IN
#   its/PRP$
#   bench/NN
#   :/:
#   Chief/JJ
#   (Chunk Justice/NNP John/NNP Roberts/NNP)
#   and/CC
#   (Chunk Justice/NNP Sam/NNP Alito/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   I/PRP
#   thank/VBD
#   the/DT
#   (Chunk Senate/NNP)
#   for/IN
#   confirming/VBG
#   both/DT
#   of/IN
#   them/PRP
#   ./.)
# (S
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   nominate/VB
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   understand/VBP
#   that/IN
#   judges/NNS
#   must/MD
#   be/VB
#   servants/NNS
#   of/IN
#   the/DT
#   law/NN
#   ,/,
#   and/CC
#   not/RB
#   legislate/VB
#   from/IN
#   the/DT
#   bench/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Today/NN
#   marks/VBZ
#   the/DT
#   official/JJ
#   retirement/NN
#   of/IN
#   a/DT
#   very/RB
#   special/JJ
#   (Chunk American/NNP)
#   ./.)
# (S
#   For/IN
#   24/CD
#   years/NNS
#   of/IN
#   faithful/JJ
#   service/NN
#   to/TO
#   our/PRP$
#   nation/NN
#   ,/,
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   is/VBZ
#   grateful/JJ
#   to/TO
#   (Chunk Justice/NNP Sandra/NNP Day/NNP O'Connor/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   has/VBZ
#   institutions/NNS
#   of/IN
#   science/NN
#   and/CC
#   medicine/NN
#   that/WDT
#   do/VBP
#   not/RB
#   cut/VB
#   ethical/JJ
#   corners/NNS
#   ,/,
#   and/CC
#   that/IN
#   recognize/VBP
#   the/DT
#   matchless/NN
#   value/NN
#   of/IN
#   every/DT
#   life/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   pass/VB
#   legislation/NN
#   to/TO
#   prohibit/VB
#   the/DT
#   most/RBS
#   egregious/JJ
#   abuses/NNS
#   of/IN
#   medical/JJ
#   research/NN
#   :/:
#   human/JJ
#   cloning/VBG
#   in/IN
#   all/DT
#   its/PRP$
#   forms/NNS
#   ,/,
#   creating/VBG
#   or/CC
#   implanting/VBG
#   embryos/NN
#   for/IN
#   experiments/NNS
#   ,/,
#   creating/VBG
#   human-animal/JJ
#   hybrids/NNS
#   ,/,
#   and/CC
#   buying/NN
#   ,/,
#   selling/NN
#   ,/,
#   or/CC
#   patenting/VBG
#   human/JJ
#   embryos/NN
#   ./.)
# (S
#   (Chunk Human/NNP life/NN)
#   is/VBZ
#   a/DT
#   gift/NN
#   from/IN
#   our/PRP$
#   (Chunk Creator/NNP)
#   --/:
#   and/CC
#   that/IN
#   gift/NN
#   should/MD
#   never/RB
#   be/VB
#   discarded/VBN
#   ,/,
#   devalued/VBD
#   or/CC
#   put/VB
#   up/RP
#   for/IN
#   sale/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   expects/VBZ
#   elected/VBN
#   officials/NNS
#   to/TO
#   uphold/VB
#   the/DT
#   public/JJ
#   trust/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Honorable/JJ
#   people/NNS
#   in/IN
#   both/DT
#   parties/NNS
#   are/VBP
#   working/VBG
#   on/IN
#   reforms/NNS
#   to/TO
#   strengthen/VB
#   the/DT
#   ethical/JJ
#   standards/NNS
#   of/IN
#   (Chunk Washington/NNP)
#   --/:
#   I/PRP
#   support/VBP
#   your/PRP$
#   efforts/NNS
#   ./.)
# (S
#   Each/DT
#   of/IN
#   us/PRP
#   has/VBZ
#   made/VBN
#   a/DT
#   pledge/NN
#   to/TO
#   be/VB
#   worthy/JJ
#   of/IN
#   public/JJ
#   responsibility/NN
#   --/:
#   and/CC
#   that/DT
#   is/VBZ
#   a/DT
#   pledge/NN
#   we/PRP
#   must/MD
#   never/RB
#   forget/VB
#   ,/,
#   never/RB
#   dismiss/NN
#   ,/,
#   and/CC
#   never/RB
#   betray/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   As/IN
#   we/PRP
#   renew/VBP
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   institutions/NNS
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   show/VBP
#   the/DT
#   character/NN
#   of/IN
#   (Chunk America/NNP)
#   in/IN
#   our/PRP$
#   compassion/NN
#   and/CC
#   care/NN
#   for/IN
#   one/CD
#   another/DT
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   gives/VBZ
#   special/JJ
#   attention/NN
#   to/TO
#   children/NNS
#   who/WP
#   lack/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ./.)
# (S
#   Through/IN
#   the/DT
#   (Chunk Helping/NNP America/NNP)
#   's/POS
#   (Chunk Youth/NNP Initiative/NNP)
#   ,/,
#   we/PRP
#   are/VBP
#   encouraging/VBG
#   caring/VBG
#   adults/NNS
#   to/TO
#   get/VB
#   involved/VBN
#   in/IN
#   the/DT
#   life/NN
#   of/IN
#   a/DT
#   child/NN
#   --/:
#   and/CC
#   this/DT
#   good/JJ
#   work/NN
#   is/VBZ
#   being/VBG
#   led/VBN
#   by/IN
#   our/PRP$
#   (Chunk First/NNP Lady/NNP)
#   ,/,
#   (Chunk Laura/NNP Bush/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   This/DT
#   year/NN
#   we/PRP
#   will/MD
#   add/VB
#   resources/NNS
#   to/TO
#   encourage/VB
#   young/JJ
#   people/NNS
#   to/TO
#   stay/VB
#   in/IN
#   school/NN
#   ,/,
#   so/RB
#   more/JJR
#   of/IN
#   (Chunk America/NNP)
#   's/POS
#   youth/NN
#   can/MD
#   raise/VB
#   their/PRP$
#   sights/NNS
#   and/CC
#   achieve/VBP
#   their/PRP$
#   dreams/NNS
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   comes/VBZ
#   to/TO
#   the/DT
#   aid/NN
#   of/IN
#   fellow/JJ
#   citizens/NNS
#   in/IN
#   times/NNS
#   of/IN
#   suffering/NN
#   and/CC
#   emergency/NN
#   --/:
#   and/CC
#   stays/NNS
#   at/IN
#   it/PRP
#   until/IN
#   they/PRP
#   're/VBP
#   back/RB
#   on/IN
#   their/PRP$
#   feet/NNS
#   ./.)
# (S
#   So/RB
#   far/RB
#   the/DT
#   federal/JJ
#   government/NN
#   has/VBZ
#   committed/VBN
#   $/$
#   85/CD
#   billion/CD
#   to/TO
#   the/DT
#   people/NNS
#   of/IN
#   the/DT
#   (Chunk Gulf/NNP Coast/NNP)
#   and/CC
#   (Chunk New/NNP Orleans/NNP)
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   removing/VBG
#   debris/NN
#   and/CC
#   repairing/NN
#   highways/NNS
#   and/CC
#   rebuilding/VBG
#   stronger/JJR
#   levees/NNS
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   providing/VBG
#   business/NN
#   loans/NNS
#   and/CC
#   housing/NN
#   assistance/NN
#   ./.)
# (S
#   Yet/RB
#   as/IN
#   we/PRP
#   meet/VBP
#   these/DT
#   immediate/JJ
#   needs/NNS
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   address/VB
#   deeper/JJR
#   challenges/NNS
#   that/WDT
#   existed/VBD
#   before/IN
#   the/DT
#   storm/NN
#   arrived/VBD
#   ./.)
# (S
#   In/IN
#   (Chunk New/NNP Orleans/NNP)
#   and/CC
#   in/IN
#   other/JJ
#   places/NNS
#   ,/,
#   many/JJ
#   of/IN
#   our/PRP$
#   fellow/JJ
#   citizens/NNS
#   have/VBP
#   felt/VBN
#   excluded/VBN
#   from/IN
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   The/DT
#   answer/NN
#   is/VBZ
#   not/RB
#   only/RB
#   temporary/JJ
#   relief/NN
#   ,/,
#   but/CC
#   schools/NNS
#   that/WDT
#   teach/VBP
#   every/DT
#   child/NN
#   ,/,
#   and/CC
#   job/NN
#   skills/NNS
#   that/IN
#   bring/VBG
#   upward/JJ
#   mobility/NN
#   ,/,
#   and/CC
#   more/JJR
#   opportunities/NNS
#   to/TO
#   own/VB
#   a/DT
#   home/NN
#   and/CC
#   start/VB
#   a/DT
#   business/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   recover/VBP
#   from/IN
#   a/DT
#   disaster/NN
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   work/NN
#   for/IN
#   the/DT
#   day/NN
#   when/WRB
#   all/DT
#   Americans/NNPS
#   are/VBP
#   protected/VBN
#   by/IN
#   justice/NN
#   ,/,
#   equal/JJ
#   in/IN
#   hope/NN
#   ,/,
#   and/CC
#   rich/JJ
#   in/IN
#   opportunity/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   acts/NNS
#   boldly/RB
#   to/TO
#   fight/VB
#   diseases/NNS
#   like/IN
#   (Chunk HIV/AIDS/NNP)
#   ,/,
#   which/WDT
#   can/MD
#   be/VB
#   prevented/VBN
#   ,/,
#   and/CC
#   treated/VBD
#   ,/,
#   and/CC
#   defeated/VBD
#   ./.)
# (S
#   More/JJR
#   than/IN
#   a/DT
#   million/CD
#   Americans/NNPS
#   live/VBP
#   with/IN
#   (Chunk HIV/NNP)
#   ,/,
#   and/CC
#   half/NN
#   of/IN
#   all/DT
#   (Chunk AIDS/NNP)
#   cases/NNS
#   occur/VBP
#   among/IN
#   African/JJ
#   Americans/NNPS
#   ./.)
# (S
#   I/PRP
#   (Chunk ask/VBP Congress/NNP)
#   to/TO
#   reform/VB
#   and/CC
#   reauthorize/VB
#   the/DT
#   (Chunk Ryan/NNP White/NNP Act/NNP)
#   ,/,
#   and/CC
#   provide/VB
#   new/JJ
#   funding/NN
#   to/TO
#   states/NNS
#   ,/,
#   so/IN
#   we/PRP
#   end/VBP
#   the/DT
#   waiting/NN
#   lists/NNS
#   for/IN
#   (Chunk AIDS/NNP)
#   medicines/NNS
#   in/IN
#   (Chunk America/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   also/RB
#   lead/VB
#   a/DT
#   nationwide/JJ
#   effort/NN
#   ,/,
#   working/VBG
#   closely/RB
#   with/IN
#   African/JJ
#   American/JJ
#   churches/NNS
#   and/CC
#   faith-based/JJ
#   groups/NNS
#   ,/,
#   to/TO
#   deliver/VB
#   rapid/JJ
#   (Chunk HIV/NNP)
#   tests/NNS
#   to/TO
#   millions/NNS
#   ,/,
#   end/VBP
#   the/DT
#   stigma/NN
#   of/IN
#   (Chunk AIDS/NNP)
#   ,/,
#   and/CC
#   come/VB
#   closer/JJR
#   to/TO
#   the/DT
#   day/NN
#   when/WRB
#   there/EX
#   are/VBP
#   no/DT
#   new/JJ
#   infections/NNS
#   in/IN
#   (Chunk America/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   've/VBP
#   been/VBN
#   called/VBN
#   to/TO
#   leadership/NN
#   in/IN
#   a/DT
#   period/NN
#   of/IN
#   consequence/NN
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   entered/VBN
#   a/DT
#   great/JJ
#   ideological/JJ
#   conflict/NN
#   we/PRP
#   did/VBD
#   nothing/NN
#   to/TO
#   invite/VB
#   ./.)
# (S
#   We/PRP
#   see/VBP
#   great/JJ
#   changes/NNS
#   in/IN
#   science/NN
#   and/CC
#   commerce/NN
#   that/WDT
#   will/MD
#   influence/VB
#   all/DT
#   our/PRP$
#   lives/NNS
#   ./.)
# (S
#   Sometimes/RB
#   it/PRP
#   can/MD
#   seem/VB
#   that/DT
#   history/NN
#   is/VBZ
#   turning/VBG
#   in/IN
#   a/DT
#   wide/JJ
#   arc/NN
#   ,/,
#   toward/IN
#   an/DT
#   unknown/JJ
#   shore/NN
#   ./.)
# (S
#   Yet/CC
#   the/DT
#   destination/NN
#   of/IN
#   history/NN
#   is/VBZ
#   determined/VBN
#   by/IN
#   human/JJ
#   action/NN
#   ,/,
#   and/CC
#   every/DT
#   great/JJ
#   movement/NN
#   of/IN
#   history/NN
#   comes/VBZ
#   to/TO
#   a/DT
#   point/NN
#   of/IN
#   choosing/NN
#   ./.)
# (S
#   (Chunk Lincoln/NNP)
#   could/MD
#   have/VB
#   accepted/VBN
#   peace/NN
#   at/IN
#   the/DT
#   cost/NN
#   of/IN
#   disunity/NN
#   and/CC
#   continued/JJ
#   slavery/NN
#   ./.)
# (S
#   (Chunk Martin/NNP Luther/NNP King/NNP)
#   could/MD
#   have/VB
#   stopped/VBN
#   at/IN
#   (Chunk Birmingham/NNP)
#   or/CC
#   at/IN
#   (Chunk Selma/NNP)
#   ,/,
#   and/CC
#   achieved/VBD
#   only/RB
#   half/PDT
#   a/DT
#   victory/NN
#   over/IN
#   segregation/NN
#   ./.)
# (S
#   The/DT
#   (Chunk United/NNP)
#   States/NNPS
#   could/MD
#   have/VB
#   accepted/VBN
#   the/DT
#   permanent/JJ
#   division/NN
#   of/IN
#   (Chunk Europe/NNP)
#   ,/,
#   and/CC
#   been/VBN
#   complicit/NNS
#   in/IN
#   the/DT
#   oppression/NN
#   of/IN
#   others/NNS
#   ./.)
# (S
#   Today/NN
#   ,/,
#   having/VBG
#   come/VBN
#   far/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   historical/JJ
#   journey/NN
#   ,/,
#   we/PRP
#   must/MD
#   decide/VB
#   :/:
#   Will/MD
#   we/PRP
#   turn/VB
#   back/RP
#   ,/,
#   or/CC
#   finish/VB
#   well/RB
#   ?/.)
# (S
#   Before/IN
#   history/NN
#   is/VBZ
#   written/VBN
#   down/RP
#   in/IN
#   books/NNS
#   ,/,
#   it/PRP
#   is/VBZ
#   written/VBN
#   in/IN
#   courage/NN
#   ./.)
# (S
#   Like/IN
#   Americans/NNPS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   will/MD
#   show/VB
#   that/DT
#   courage/NN
#   and/CC
#   we/PRP
#   will/MD
#   finish/VB
#   well/RB
#   ./.)
# (S We/PRP will/MD lead/VB freedom/NN 's/POS advance/NN ./.)
# (S
#   We/PRP
#   will/MD
#   compete/VB
#   and/CC
#   excel/VB
#   in/IN
#   the/DT
#   global/JJ
#   economy/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   renew/VB
#   the/DT
#   defining/VBG
#   moral/JJ
#   commitments/NNS
#   of/IN
#   this/DT
#   land/NN
#   ./.)
# (S
#   And/CC
#   so/RB
#   we/PRP
#   move/VBP
#   forward/RB
#   --/:
#   optimistic/JJ
#   about/IN
#   our/PRP$
#   country/NN
#   ,/,
#   faithful/JJ
#   to/TO
#   its/PRP$
#   cause/NN
#   ,/,
#   and/CC
#   confident/NN
#   of/IN
#   the/DT
#   victories/NNS
#   to/TO
#   come/VB
#   ./.)
# (S (Chunk May/NNP God/NNP bless/NN) (Chunk America/NNP) ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))

# %%
# 1st install ghostscript  ( pip install ghostscript)

# Now we create a grammar from Noun phrase and mention tags we want in our chunks phrase within the curly braces or {dict}

new = "The big cat ate the little mouse who was after fresh cheese"
new_token = nltk.pos_tag(word_tokenize(new))     # 1st word tokenize , then pos_tag
new_token

grammar_np = r"NP: {<DT>?<JJ>*<NN>}"

chunk_parser = nltk.RegexpParser(grammar_np)   # Here created Regular expression matching string

chunk_result = chunk_parser.parse(new_token)   # now parse our Noun phrase string to it.  
chunk_result
# Out:
# Tree('S', [Tree('NP', [('The', 'DT'), ('big', 'JJ'), ('cat', 'NN')]), ('ate', 'VBD'), Tree('NP', [('the', 'DT'), ('little', 'JJ'), ('mouse', 'NN')]), ('who', 'WP'), ('was', 'VBD'), ('after', 'IN'), Tree('NP', [('fresh', 'JJ'), ('cheese', 'NN')])])

# %% [markdown]
# ## Chinking :

# %% [markdown]
# ##### chinking -- removal of something from group.

# %%
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer       # PunktSentenceTokenizer : is Unsupervise ML tokenizer  

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_token = PunktSentenceTokenizer(train_text)
tokenized = custom_token.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            chunkGram = r"""Chink : {<.*>+}
                                    }<VB.?|IN|DT|TO>+{"""
            
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            
#             chunked.draw()
            
            print(chunked)
            
#             print(tagged)
    
    except Exception as e:
        print(str(e))
        
process_content()
# Out:
# (S
#   (Chink PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP 'S/POS ADDRESS/NNP)
#   BEFORE/IN
#   (Chink A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chink THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chink
#     THE/NNP
#     UNION/NNP
#     January/NNP
#     31/CD
#     ,/,
#     2006/CD
#     THE/NNP
#     PRESIDENT/NNP
#     :/:
#     Thank/NNP
#     you/PRP)
#   all/DT
#   (Chink ./.))
# (S
#   (Chink
#     Mr./NNP
#     Speaker/NNP
#     ,/,
#     Vice/NNP
#     President/NNP
#     Cheney/NNP
#     ,/,
#     members/NNS)
#   of/IN
#   (Chink Congress/NNP ,/, members/NNS)
#   of/IN
#   the/DT
#   (Chink
#     Supreme/NNP
#     Court/NNP
#     and/CC
#     diplomatic/JJ
#     corps/NN
#     ,/,
#     distinguished/JJ
#     guests/NNS
#     ,/,
#     and/CC
#     fellow/JJ
#     citizens/NNS
#     :/:)
#   Today/VB
#   (Chink our/PRP$ nation/NN)
#   lost/VBD
#   a/DT
#   beloved/VBN
#   (Chink ,/, graceful/JJ ,/, courageous/JJ woman/NN who/WP)
#   called/VBD
#   (Chink America/NNP)
#   to/TO
#   (Chink its/PRP$ founding/NN ideals/NNS and/CC)
#   carried/VBD
#   on/IN
#   a/DT
#   (Chink noble/JJ dream/NN ./.))
# (S
#   (Chink Tonight/NN we/PRP)
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   (Chink hope/NN)
#   of/IN
#   a/DT
#   (Chink glad/JJ reunion/NN)
#   with/IN
#   the/DT
#   (Chink husband/NN who/WP)
#   was/VBD
#   taken/VBN
#   (Chink so/RB long/RB ago/RB ,/, and/CC we/PRP)
#   are/VBP
#   (Chink grateful/JJ)
#   for/IN
#   the/DT
#   (Chink good/JJ life/NN)
#   of/IN
#   (Chink Coretta/NNP Scott/NNP King/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink President/NNP George/NNP W./NNP Bush/NNP)
#   reacts/VBZ
#   to/TO
#   applause/VB
#   during/IN
#   (Chink his/PRP$ State/NNP)
#   of/IN
#   the/DT
#   (Chink Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chink Capitol/NNP ,/, Tuesday/NNP ,/, Jan/NNP ./.))
# (S (Chink 31/CD ,/, 2006/CD ./.))
# (S
#   (Chink White/NNP House/NNP photo/NN)
#   by/IN
#   (Chink Eric/NNP DraperEvery/NNP time/NN I/PRP)
#   'm/VBP
#   (Chink invited/JJ)
#   to/TO
#   this/DT
#   (Chink rostrum/NN ,/, I/PRP)
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   (Chink privilege/NN ,/, and/CC mindful/NN)
#   of/IN
#   the/DT
#   (Chink history/NN we/PRP)
#   've/VBP
#   seen/VBN
#   (Chink together/RB ./.))
# (S
#   (Chink We/PRP)
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   (Chink Capitol/NNP dome/NN)
#   in/IN
#   (Chink moments/NNS)
#   of/IN
#   (Chink
#     national/JJ
#     mourning/NN
#     and/CC
#     national/JJ
#     achievement/NN
#     ./.))
# (S
#   (Chink We/PRP)
#   have/VBP
#   served/VBN
#   (Chink America/NNP)
#   through/IN
#   (Chink one/CD)
#   of/IN
#   the/DT
#   (Chink most/RBS consequential/JJ periods/NNS)
#   of/IN
#   (Chink our/PRP$ history/NN --/: and/CC it/PRP)
#   has/VBZ
#   been/VBN
#   (Chink my/PRP$ honor/NN)
#   to/TO
#   serve/VB
#   with/IN
#   (Chink you/PRP ./.))
# (S
#   In/IN
#   a/DT
#   (Chink system/NN)
#   of/IN
#   (Chink
#     two/CD
#     parties/NNS
#     ,/,
#     two/CD
#     chambers/NNS
#     ,/,
#     and/CC
#     two/CD
#     elected/JJ
#     branches/NNS
#     ,/,
#     there/EX
#     will/MD
#     always/RB)
#   be/VB
#   (Chink differences/NNS and/CC debate/NN ./.))
# (S
#   (Chink But/CC even/RB tough/JJ debates/NNS can/MD)
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   (Chink
#     civil/JJ
#     tone/NN
#     ,/,
#     and/CC
#     our/PRP$
#     differences/NNS
#     can/MD
#     not/RB)
#   be/VB
#   allowed/VBN
#   to/TO
#   harden/VB
#   into/IN
#   (Chink anger/NN ./.))
# (S
#   To/TO
#   confront/VB
#   the/DT
#   (Chink great/JJ issues/NNS)
#   before/IN
#   (Chink us/PRP ,/, we/PRP must/MD)
#   act/VB
#   in/IN
#   a/DT
#   (Chink spirit/NN)
#   of/IN
#   (Chink goodwill/NN and/CC respect/NN)
#   for/IN
#   (Chink one/CD)
#   another/DT
#   (Chink --/: and/CC I/PRP will/MD)
#   do/VB
#   (Chink my/PRP$ part/NN ./.))
# (S
#   (Chink Tonight/NNP)
#   the/DT
#   (Chink state/NN)
#   of/IN
#   (Chink our/PRP$ Union/NNP)
#   is/VBZ
#   (Chink strong/JJ --/: and/CC together/RB we/PRP will/MD)
#   make/VB
#   (Chink it/PRP stronger/JJR ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   In/IN
#   this/DT
#   (Chink decisive/JJ year/NN ,/, you/PRP and/CC I/PRP will/MD)
#   make/VB
#   (Chink choices/NNS that/WDT)
#   determine/VBP
#   both/DT
#   the/DT
#   (Chink future/NN and/CC)
#   the/DT
#   (Chink character/NN)
#   of/IN
#   (Chink our/PRP$ country/NN ./.))
# (S
#   (Chink We/PRP will/MD)
#   choose/VB
#   to/TO
#   act/VB
#   (Chink confidently/RB)
#   in/IN
#   pursuing/VBG
#   the/DT
#   (Chink enemies/NNS)
#   of/IN
#   (Chink freedom/NN --/: or/CC retreat/NN)
#   from/IN
#   (Chink our/PRP$ duties/NNS)
#   in/IN
#   the/DT
#   (Chink hope/NN)
#   of/IN
#   an/DT
#   (Chink easier/JJR life/NN ./.))
# (S
#   (Chink We/PRP will/MD)
#   choose/VB
#   to/TO
#   build/VB
#   (Chink our/PRP$ prosperity/NN)
#   by/IN
#   leading/VBG
#   the/DT
#   (Chink world/NN economy/NN --/: or/CC)
#   shut/VB
#   (Chink ourselves/PRP off/RP)
#   from/IN
#   (Chink trade/NN and/CC opportunity/NN ./.))
# (S
#   In/IN
#   a/DT
#   (Chink complex/JJ and/CC challenging/JJ time/NN ,/,)
#   the/DT
#   (Chink road/NN)
#   of/IN
#   (Chink isolationism/NN and/CC protectionism/NN may/MD)
#   seem/VB
#   (Chink broad/JJ and/CC inviting/NN --/: yet/CC it/PRP)
#   ends/VBZ
#   in/IN
#   (Chink danger/NN and/CC decline/NN ./.))
# (S
#   The/DT
#   (Chink only/JJ way/NN)
#   to/TO
#   protect/VB
#   (Chink our/PRP$ people/NNS ,/,)
#   the/DT
#   (Chink only/JJ way/NN)
#   to/TO
#   secure/VB
#   the/DT
#   (Chink peace/NN ,/,)
#   the/DT
#   (Chink only/JJ way/NN)
#   to/TO
#   control/VB
#   (Chink our/PRP$ destiny/NN)
#   is/VBZ
#   by/IN
#   (Chink our/PRP$ leadership/NN --/:)
#   so/IN
#   the/DT
#   (Chink United/NNP States/NNPS)
#   of/IN
#   (Chink America/NNP will/MD)
#   continue/VB
#   to/TO
#   lead/VB
#   (Chink ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Abroad/RB ,/, our/PRP$ nation/NN)
#   is/VBZ
#   committed/VBN
#   to/TO
#   an/DT
#   (Chink historic/JJ ,/, long-term/JJ goal/NN --/: we/PRP)
#   seek/VBP
#   the/DT
#   (Chink end/NN)
#   of/IN
#   (Chink tyranny/NN)
#   in/IN
#   (Chink our/PRP$ world/NN ./.))
# (S
#   Some/DT
#   dismiss/VBP
#   that/DT
#   (Chink goal/NN)
#   as/IN
#   (Chink misguided/JJ idealism/NN ./.))
# (S
#   In/IN
#   (Chink reality/NN ,/,)
#   the/DT
#   (Chink future/JJ security/NN)
#   of/IN
#   (Chink America/NNP)
#   depends/VBZ
#   on/IN
#   (Chink it/PRP ./.))
# (S
#   On/IN
#   (Chink September/NNP)
#   the/DT
#   (Chink 11th/CD ,/, 2001/CD ,/, we/PRP)
#   found/VBD
#   that/IN
#   (Chink problems/NNS)
#   originating/VBG
#   in/IN
#   a/DT
#   (Chink
#     failed/JJ
#     and/CC
#     oppressive/JJ
#     state/NN
#     7,000/CD
#     miles/NNS
#     away/RB
#     could/MD)
#   bring/VB
#   (Chink murder/NN and/CC destruction/NN)
#   to/TO
#   (Chink our/PRP$ country/NN ./.))
# (S
#   (Chink Dictatorships/NNP shelter/NN terrorists/NNS ,/, and/CC)
#   feed/VB
#   (Chink
#     resentment/NN
#     and/CC
#     radicalism/NN
#     ,/,
#     and/CC
#     seek/JJ
#     weapons/NNS)
#   of/IN
#   (Chink mass/NN destruction/NN ./.))
# (S
#   (Chink Democracies/NNS)
#   replace/VB
#   (Chink resentment/NN)
#   with/IN
#   (Chink hope/NN ,/,)
#   respect/VB
#   the/DT
#   (Chink rights/NNS)
#   of/IN
#   (Chink
#     their/PRP$
#     citizens/NNS
#     and/CC
#     their/PRP$
#     neighbors/NNS
#     ,/,
#     and/CC)
#   join/VB
#   the/DT
#   (Chink fight/NN)
#   against/IN
#   (Chink terror/NN ./.))
# (S
#   Every/DT
#   (Chink step/NN)
#   toward/IN
#   (Chink freedom/NN)
#   in/IN
#   the/DT
#   (Chink world/NN)
#   makes/VBZ
#   (Chink our/PRP$ country/NN safer/NN --/:)
#   so/IN
#   (Chink we/PRP will/MD)
#   act/VB
#   (Chink boldly/RB)
#   in/IN
#   (Chink freedom/NN 's/POS cause/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Far/RB)
#   from/IN
#   being/VBG
#   a/DT
#   (Chink hopeless/NN dream/NN ,/,)
#   the/DT
#   (Chink advance/NN)
#   of/IN
#   (Chink freedom/NN)
#   is/VBZ
#   the/DT
#   (Chink great/JJ story/NN)
#   of/IN
#   (Chink our/PRP$ time/NN ./.))
# (S
#   In/IN
#   (Chink 1945/CD ,/, there/EX)
#   were/VBD
#   (Chink about/RB two/CD dozen/NN lonely/RB)
#   democracies/VBZ
#   in/IN
#   the/DT
#   (Chink world/NN ./.))
# (S (Chink Today/NN ,/, there/EX) are/VBP (Chink 122/CD ./.))
# (S
#   (Chink And/CC we/PRP)
#   're/VBP
#   writing/VBG
#   a/DT
#   (Chink new/JJ chapter/NN)
#   in/IN
#   the/DT
#   (Chink story/NN)
#   of/IN
#   (Chink self-government/JJ --/:)
#   with/IN
#   (Chink women/NNS)
#   lining/VBG
#   (Chink up/RP)
#   to/TO
#   vote/VB
#   in/IN
#   (Chink Afghanistan/NNP ,/, and/CC millions/NNS)
#   of/IN
#   (Chink Iraqis/NNP)
#   marking/VBG
#   (Chink their/PRP$ liberty/NN)
#   with/IN
#   (Chink purple/JJ ink/NN ,/, and/CC men/NNS and/CC women/NNS)
#   from/IN
#   (Chink Lebanon/NNP)
#   to/TO
#   (Chink Egypt/NNP)
#   debating/VBG
#   the/DT
#   (Chink rights/NNS)
#   of/IN
#   (Chink individuals/NNS and/CC)
#   the/DT
#   (Chink necessity/NN)
#   of/IN
#   (Chink freedom/NN ./.))
# (S
#   At/IN
#   the/DT
#   (Chink start/NN)
#   of/IN
#   (Chink 2006/CD ,/, more/JJR)
#   than/IN
#   (Chink half/PDT)
#   the/DT
#   (Chink people/NNS)
#   of/IN
#   (Chink our/PRP$ world/NN)
#   live/VBP
#   in/IN
#   (Chink democratic/JJ nations/NNS ./.))
# (S
#   (Chink And/CC we/PRP)
#   do/VBP
#   (Chink not/RB)
#   forget/VB
#   the/DT
#   (Chink other/JJ half/NN --/:)
#   in/IN
#   (Chink places/NNS)
#   like/IN
#   (Chink
#     Syria/NNP
#     and/CC
#     Burma/NNP
#     ,/,
#     Zimbabwe/NNP
#     ,/,
#     North/NNP
#     Korea/NNP
#     ,/,
#     and/CC
#     Iran/NNP
#     --/:)
#   because/IN
#   the/DT
#   (Chink demands/NNS)
#   of/IN
#   (Chink justice/NN ,/, and/CC)
#   the/DT
#   (Chink peace/NN)
#   of/IN
#   this/DT
#   (Chink world/NN ,/,)
#   require/VBP
#   (Chink their/PRP$ freedom/NN ,/, as/RB well/RB ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink President/NNP George/NNP W./NNP Bush/NNP)
#   delivers/VBZ
#   (Chink his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chink Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chink Capitol/NNP ,/, Tuesday/NNP ,/, Jan/NNP ./.))
# (S (Chink 31/CD ,/, 2006/CD ./.))
# (S
#   (Chink White/NNP House/NNP photo/NN)
#   by/IN
#   (Chink Eric/NNP Draper/NNP No/NNP one/NN can/MD)
#   deny/VB
#   the/DT
#   (Chink success/NN)
#   of/IN
#   (Chink freedom/NN ,/, but/CC)
#   some/DT
#   (Chink men/NNS)
#   rage/VB
#   (Chink and/CC)
#   fight/VB
#   against/IN
#   (Chink it/PRP ./.))
# (S
#   (Chink And/CC one/CD)
#   of/IN
#   the/DT
#   (Chink main/JJ sources/NNS)
#   of/IN
#   (Chink reaction/NN and/CC opposition/NN)
#   is/VBZ
#   (Chink radical/JJ Islam/NNP --/:)
#   the/DT
#   (Chink perversion/NN)
#   by/IN
#   a/DT
#   (Chink few/JJ)
#   of/IN
#   a/DT
#   (Chink noble/JJ faith/NN)
#   into/IN
#   an/DT
#   (Chink ideology/NN)
#   of/IN
#   (Chink terror/NN and/CC death/NN ./.))
# (S
#   (Chink Terrorists/NNS)
#   like/IN
#   (Chink bin/NN Laden/NNP)
#   are/VBP
#   (Chink serious/JJ)
#   about/IN
#   (Chink mass/NN murder/NN --/: and/CC)
#   all/DT
#   of/IN
#   (Chink us/PRP must/MD)
#   take/VB
#   (Chink their/PRP$ declared/JJ intentions/NNS seriously/RB ./.))
# (S
#   (Chink They/PRP)
#   seek/VBP
#   to/TO
#   impose/VB
#   a/DT
#   (Chink heartless/NN system/NN)
#   of/IN
#   (Chink totalitarian/JJ control/NN)
#   throughout/IN
#   the/DT
#   (Chink Middle/NNP East/NNP ,/, and/CC arm/NN themselves/PRP)
#   with/IN
#   (Chink weapons/NNS)
#   of/IN
#   (Chink mass/NN murder/NN ./.))
# (S
#   (Chink Their/PRP$ aim/NN)
#   is/VBZ
#   to/TO
#   seize/VB
#   (Chink power/NN)
#   in/IN
#   (Chink Iraq/NNP ,/, and/CC)
#   use/VB
#   (Chink it/PRP)
#   as/IN
#   a/DT
#   (Chink safe/JJ haven/NN)
#   to/TO
#   launch/VB
#   (Chink attacks/NNS)
#   against/IN
#   (Chink America/NNP and/CC)
#   the/DT
#   (Chink world/NN ./.))
# (S
#   Lacking/VBG
#   the/DT
#   (Chink military/JJ strength/NN)
#   to/TO
#   challenge/VB
#   (Chink us/PRP directly/RB ,/,)
#   the/DT
#   (Chink terrorists/NNS)
#   have/VBP
#   chosen/VBN
#   the/DT
#   (Chink weapon/NN)
#   of/IN
#   (Chink fear/NN ./.))
# (S
#   (Chink When/WRB they/PRP)
#   murder/VBP
#   (Chink children/NNS)
#   at/IN
#   a/DT
#   (Chink school/NN)
#   in/IN
#   (Chink Beslan/NNP ,/, or/CC)
#   blow/VB
#   (Chink up/RP commuters/NNS)
#   in/IN
#   (Chink London/NNP ,/, or/CC)
#   behead/VB
#   a/DT
#   (Chink bound/NN captive/NN ,/,)
#   the/DT
#   (Chink terrorists/NNS)
#   hope/VBP
#   these/DT
#   (Chink horrors/NNS will/MD)
#   break/VB
#   (Chink our/PRP$ will/MD ,/,)
#   allowing/VBG
#   the/DT
#   (Chink violent/NN)
#   to/TO
#   inherit/VB
#   the/DT
#   (Chink Earth/NNP ./.))
# (S
#   (Chink But/CC they/PRP)
#   have/VBP
#   miscalculated/VBN
#   (Chink :/: We/PRP)
#   love/VBP
#   (Chink our/PRP$ freedom/NN ,/, and/CC we/PRP will/MD)
#   fight/VB
#   to/TO
#   keep/VB
#   (Chink it/PRP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   In/IN
#   a/DT
#   (Chink time/NN)
#   of/IN
#   testing/VBG
#   (Chink ,/, we/PRP can/MD not/RB)
#   find/VB
#   (Chink security/NN)
#   by/IN
#   abandoning/VBG
#   (Chink our/PRP$ commitments/NNS and/CC)
#   retreating/VBG
#   within/IN
#   (Chink our/PRP$ borders/NNS ./.))
# (S
#   If/IN
#   (Chink we/PRP)
#   were/VBD
#   to/TO
#   leave/VB
#   these/DT
#   (Chink
#     vicious/JJ
#     attackers/NNS
#     alone/RB
#     ,/,
#     they/PRP
#     would/MD
#     not/RB)
#   leave/VB
#   (Chink us/PRP alone/RB ./.))
# (S
#   (Chink They/PRP would/MD simply/RB)
#   move/VB
#   the/DT
#   (Chink battlefield/NN)
#   to/TO
#   (Chink our/PRP$ own/JJ shores/NNS ./.))
# (S
#   (Chink There/EX)
#   is/VBZ
#   no/DT
#   (Chink peace/NN)
#   in/IN
#   (Chink retreat/NN ./.))
# (S
#   (Chink And/CC there/EX)
#   is/VBZ
#   no/DT
#   (Chink honor/NN)
#   in/IN
#   (Chink retreat/NN ./.))
# (S
#   By/IN
#   allowing/VBG
#   (Chink radical/JJ Islam/NNP)
#   to/TO
#   work/VB
#   (Chink its/PRP$ will/MD --/:)
#   by/IN
#   leaving/VBG
#   an/DT
#   (Chink assaulted/JJ world/NN)
#   to/TO
#   fend/VB
#   for/IN
#   (Chink itself/PRP --/: we/PRP would/MD)
#   signal/VB
#   to/TO
#   (Chink all/PDT)
#   that/IN
#   (Chink we/PRP)
#   no/DT
#   (Chink longer/RBR)
#   believe/VBP
#   in/IN
#   (Chink our/PRP$ own/JJ ideals/NNS ,/, or/CC even/RB)
#   in/IN
#   (Chink our/PRP$ own/JJ courage/NN ./.))
# (S
#   (Chink
#     But/CC
#     our/PRP$
#     enemies/NNS
#     and/CC
#     our/PRP$
#     friends/NNS
#     can/MD)
#   be/VB
#   (Chink certain/JJ :/:)
#   The/DT
#   (Chink United/NNP States/NNPS will/MD not/RB)
#   retreat/VB
#   from/IN
#   the/DT
#   (Chink world/NN ,/, and/CC we/PRP will/MD never/RB)
#   surrender/VB
#   to/TO
#   evil/VB
#   (Chink ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink America/NNP)
#   rejects/VBZ
#   the/DT
#   (Chink false/JJ comfort/NN)
#   of/IN
#   (Chink isolationism/NN ./.))
# (S
#   (Chink We/PRP)
#   are/VBP
#   the/DT
#   (Chink nation/NN)
#   that/IN
#   saved/VBD
#   (Chink liberty/NN)
#   in/IN
#   (Chink Europe/NNP ,/, and/CC)
#   liberated/VBD
#   (Chink death/NN camps/NNS ,/, and/CC)
#   helped/VBD
#   raise/VB
#   (Chink up/RP democracies/NNS ,/, and/CC)
#   faced/VBD
#   down/IN
#   an/DT
#   (Chink evil/JJ empire/NN ./.))
# (S
#   (Chink Once/RB again/RB ,/, we/PRP)
#   accept/VBP
#   the/DT
#   (Chink call/NN)
#   of/IN
#   (Chink history/NN)
#   to/TO
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   (Chink and/CC)
#   move/VB
#   this/DT
#   (Chink world/NN)
#   toward/IN
#   (Chink peace/NN ./.))
# (S
#   (Chink We/PRP)
#   remain/VBP
#   on/IN
#   the/DT
#   (Chink offensive/JJ)
#   against/IN
#   (Chink terror/NN networks/NNS ./.))
# (S
#   (Chink We/PRP)
#   have/VBP
#   killed/VBN
#   (Chink or/CC)
#   captured/VBN
#   (Chink many/JJ)
#   of/IN
#   (Chink their/PRP$ leaders/NNS --/: and/CC)
#   for/IN
#   the/DT
#   (Chink others/NNS ,/, their/PRP$ day/NN will/MD)
#   come/VB
#   (Chink ./.))
# (S
#   (Chink President/NNP George/NNP W./NNP Bush/NNP)
#   greets/VBZ
#   (Chink members/NNS)
#   of/IN
#   (Chink Congress/NNP)
#   after/IN
#   (Chink his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chink Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chink Capitol/NNP ,/, Tuesday/NNP ,/, Jan/NNP ./.))
# (S (Chink 31/CD ,/, 2006/CD ./.))
# (S
#   (Chink White/NNP House/NNP photo/NN)
#   by/IN
#   (Chink Eric/NNP Draper/NNP We/PRP)
#   remain/VBP
#   on/IN
#   the/DT
#   (Chink offensive/JJ)
#   in/IN
#   (Chink Afghanistan/NNP ,/, where/WRB)
#   a/DT
#   (Chink fine/JJ President/NNP and/CC)
#   a/DT
#   (Chink National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   (Chink terror/NN)
#   while/IN
#   building/VBG
#   the/DT
#   (Chink institutions/NNS)
#   of/IN
#   a/DT
#   (Chink new/JJ democracy/NN ./.))
# (S
#   (Chink We/PRP)
#   're/VBP
#   on/IN
#   the/DT
#   (Chink offensive/JJ)
#   in/IN
#   (Chink Iraq/NNP ,/,)
#   with/IN
#   a/DT
#   (Chink clear/JJ plan/NN)
#   for/IN
#   (Chink victory/NN ./.))
# (S
#   (Chink First/RB ,/, we/PRP)
#   're/VBP
#   helping/VBG
#   (Chink Iraqis/NNP)
#   build/VB
#   an/DT
#   (Chink inclusive/JJ government/NN ,/,)
#   so/IN
#   that/DT
#   (Chink old/JJ resentments/NNS will/MD)
#   be/VB
#   eased/VBN
#   (Chink and/CC)
#   the/DT
#   (Chink insurgency/NN will/MD)
#   be/VB
#   marginalized/VBN
#   (Chink ./.))
# (S
#   (Chink Second/JJ ,/, we/PRP)
#   're/VBP
#   continuing/VBG
#   (Chink reconstruction/NN efforts/NNS ,/, and/CC)
#   helping/VBG
#   the/DT
#   (Chink Iraqi/NNP government/NN)
#   to/TO
#   fight/VB
#   (Chink corruption/NN and/CC)
#   build/VB
#   a/DT
#   (Chink modern/JJ economy/NN ,/,)
#   so/IN
#   all/DT
#   (Chink Iraqis/NNP can/MD)
#   experience/VB
#   the/DT
#   (Chink benefits/NNS)
#   of/IN
#   (Chink freedom/NN ./.))
# (S
#   (Chink And/CC ,/, third/JJ ,/, we/PRP)
#   're/VBP
#   striking/VBG
#   (Chink terrorist/JJ targets/NNS)
#   while/IN
#   (Chink we/PRP)
#   train/VBP
#   (Chink Iraqi/JJ forces/NNS that/WDT)
#   are/VBP
#   (Chink increasingly/RB capable/JJ)
#   of/IN
#   defeating/VBG
#   the/DT
#   (Chink enemy/NN ./.))
# (S
#   (Chink Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   (Chink their/PRP$ courage/NN)
#   every/DT
#   (Chink day/NN ,/, and/CC we/PRP)
#   are/VBP
#   (Chink proud/JJ)
#   to/TO
#   be/VB
#   (Chink their/PRP$ allies/NNS)
#   in/IN
#   the/DT
#   (Chink cause/NN)
#   of/IN
#   (Chink freedom/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Our/PRP$ work/NN)
#   in/IN
#   (Chink Iraq/NNP)
#   is/VBZ
#   (Chink difficult/JJ)
#   because/IN
#   (Chink our/PRP$ enemy/NN)
#   is/VBZ
#   (Chink brutal/JJ ./.))
# (S
#   (Chink But/CC)
#   that/DT
#   (Chink brutality/NN)
#   has/VBZ
#   (Chink not/RB)
#   stopped/VBN
#   the/DT
#   (Chink dramatic/JJ progress/NN)
#   of/IN
#   a/DT
#   (Chink new/JJ democracy/NN ./.))
# (S
#   In/IN
#   (Chink less/JJR)
#   than/IN
#   (Chink three/CD years/NNS ,/,)
#   the/DT
#   (Chink nation/NN)
#   has/VBZ
#   gone/VBN
#   from/IN
#   (Chink dictatorship/NN)
#   to/TO
#   (Chink liberation/NN ,/,)
#   to/TO
#   sovereignty/VB
#   (Chink ,/,)
#   to/TO
#   a/DT
#   (Chink constitution/NN ,/,)
#   to/TO
#   (Chink national/JJ elections/NNS ./.))
# (S
#   At/IN
#   the/DT
#   (Chink same/JJ time/NN ,/, our/PRP$ coalition/NN)
#   has/VBZ
#   been/VBN
#   relentless/VBN
#   in/IN
#   shutting/VBG
#   (Chink off/RP terrorist/JJ infiltration/NN ,/,)
#   clearing/VBG
#   (Chink out/RP insurgent/JJ strongholds/NNS ,/, and/CC)
#   turning/VBG
#   (Chink over/RP territory/NN)
#   to/TO
#   (Chink Iraqi/NNP security/NN forces/NNS ./.))
# (S
#   (Chink I/PRP)
#   am/VBP
#   (Chink confident/JJ)
#   in/IN
#   (Chink our/PRP$ plan/NN)
#   for/IN
#   (Chink victory/NN ;/: I/PRP)
#   am/VBP
#   (Chink confident/JJ)
#   in/IN
#   the/DT
#   (Chink will/MD)
#   of/IN
#   the/DT
#   (Chink Iraqi/NNP people/NNS ;/: I/PRP)
#   am/VBP
#   (Chink confident/JJ)
#   in/IN
#   the/DT
#   (Chink skill/NN and/CC spirit/NN)
#   of/IN
#   (Chink our/PRP$ military/JJ ./.))
# (S
#   (Chink Fellow/NNP citizens/NNS ,/, we/PRP)
#   are/VBP
#   in/IN
#   this/DT
#   (Chink fight/NN)
#   to/TO
#   win/VB
#   (Chink ,/, and/CC we/PRP)
#   are/VBP
#   winning/VBG
#   (Chink ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   The/DT
#   (Chink road/NN)
#   of/IN
#   (Chink victory/NN)
#   is/VBZ
#   the/DT
#   (Chink road/NN that/WDT will/MD)
#   take/VB
#   (Chink our/PRP$ troops/NNS home/NN ./.))
# (S
#   As/IN
#   (Chink we/PRP)
#   make/VBP
#   (Chink progress/NN)
#   on/IN
#   the/DT
#   (Chink ground/NN ,/, and/CC Iraqi/NNP forces/NNS increasingly/RB)
#   take/VBP
#   the/DT
#   (Chink lead/NN ,/, we/PRP should/MD)
#   be/VB
#   (Chink able/JJ)
#   to/TO
#   (Chink further/JJ)
#   decrease/VB
#   (Chink our/PRP$ troop/NN levels/NNS --/: but/CC)
#   those/DT
#   (Chink decisions/NNS will/MD)
#   be/VB
#   made/VBN
#   by/IN
#   (Chink our/PRP$ military/JJ commanders/NNS ,/, not/RB)
#   by/IN
#   (Chink politicians/NNS)
#   in/IN
#   (Chink Washington/NNP ,/, D.C/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Our/PRP$ coalition/NN)
#   has/VBZ
#   learned/VBN
#   from/IN
#   (Chink our/PRP$ experience/NN)
#   in/IN
#   (Chink Iraq/NNP ./.))
# (S
#   (Chink We/PRP)
#   've/VBP
#   adjusted/VBN
#   (Chink our/PRP$ military/JJ tactics/NNS and/CC)
#   changed/VBD
#   (Chink our/PRP$ approach/NN)
#   to/TO
#   (Chink reconstruction/NN ./.))
# (S
#   Along/IN
#   the/DT
#   (Chink way/NN ,/, we/PRP)
#   have/VBP
#   benefitted/VBN
#   from/IN
#   (Chink responsible/JJ criticism/NN and/CC counsel/NN)
#   offered/VBN
#   by/IN
#   (Chink members/NNS)
#   of/IN
#   (Chink Congress/NNP)
#   of/IN
#   both/DT
#   (Chink parties/NNS ./.))
# (S
#   In/IN
#   the/DT
#   coming/VBG
#   (Chink year/NN ,/, I/PRP will/MD)
#   continue/VB
#   to/TO
#   reach/VB
#   (Chink out/RP and/CC)
#   seek/VB
#   (Chink your/PRP$ good/JJ advice/NN ./.))
# (S
#   (Chink Yet/RB ,/, there/EX)
#   is/VBZ
#   a/DT
#   (Chink difference/NN)
#   between/IN
#   (Chink responsible/JJ criticism/NN that/WDT)
#   aims/VBZ
#   for/IN
#   (Chink success/NN ,/, and/CC defeatism/NN that/WDT)
#   refuses/VBZ
#   to/TO
#   acknowledge/VB
#   (Chink anything/NN but/CC failure/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Hindsight/NNP alone/RB)
#   is/VBZ
#   (Chink not/RB wisdom/JJ ,/, and/CC second-guessing/NN)
#   is/VBZ
#   (Chink not/RB)
#   a/DT
#   (Chink strategy/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   With/IN
#   (Chink so/RB much/JJ)
#   in/IN
#   the/DT
#   (Chink balance/NN ,/,)
#   those/DT
#   of/IN
#   (Chink us/PRP)
#   in/IN
#   (Chink public/JJ office/NN)
#   have/VBP
#   a/DT
#   (Chink duty/NN)
#   to/TO
#   speak/VB
#   with/IN
#   (Chink candor/NN ./.))
# (S
#   A/DT
#   (Chink sudden/JJ withdrawal/NN)
#   of/IN
#   (Chink our/PRP$ forces/NNS)
#   from/IN
#   (Chink Iraq/NNP would/MD)
#   abandon/VB
#   (Chink our/PRP$ Iraqi/NNP allies/NNS)
#   to/TO
#   (Chink death/NN and/CC prison/NN ,/, would/MD)
#   put/VB
#   (Chink men/NNS)
#   like/IN
#   (Chink bin/NN Laden/NNP and/CC Zarqawi/NNP)
#   in/IN
#   (Chink charge/NN)
#   of/IN
#   a/DT
#   (Chink strategic/JJ country/NN ,/, and/CC)
#   show/VBP
#   that/IN
#   a/DT
#   (Chink pledge/NN)
#   from/IN
#   (Chink America/NNP)
#   means/VBZ
#   (Chink little/JJ ./.))
# (S
#   (Chink Members/NNS)
#   of/IN
#   (Chink Congress/NNP ,/, however/RB we/PRP)
#   feel/VBP
#   about/IN
#   the/DT
#   (Chink decisions/NNS and/CC debates/NNS)
#   of/IN
#   the/DT
#   (Chink past/NN ,/, our/PRP$ nation/NN)
#   has/VBZ
#   (Chink only/RB one/CD option/NN :/: We/PRP must/MD)
#   keep/VB
#   (Chink our/PRP$ word/NN ,/,)
#   defeat/VB
#   (Chink our/PRP$ enemies/NNS ,/, and/CC)
#   stand/VBP
#   behind/IN
#   the/DT
#   (Chink American/JJ military/NN)
#   in/IN
#   this/DT
#   (Chink vital/JJ mission/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Laura/NNP Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/IN
#   (Chink she/PRP)
#   is/VBZ
#   introduced/VBN
#   (Chink Tuesday/NNP evening/NN ,/, Jan/NNP ./.))
# (S
#   (Chink 31/CD ,/, 2006/CD)
#   during/IN
#   the/DT
#   (Chink State/NNP)
#   of/IN
#   the/DT
#   (Chink Union/NNP Address/NNP)
#   at/IN
#   (Chink United/NNP States/NNPS Capitol/NNP)
#   in/IN
#   (Chink Washington/NNP ./.))
# (S
#   (Chink White/NNP House/NNP photo/NN)
#   by/IN
#   (Chink Eric/NNP Draper/NNP Our/PRP$ men/NNS and/CC women/NNS)
#   in/IN
#   (Chink uniform/JJ)
#   are/VBP
#   making/VBG
#   (Chink sacrifices/NNS --/: and/CC)
#   showing/VBG
#   a/DT
#   (Chink sense/NN)
#   of/IN
#   (Chink duty/NN stronger/JJR)
#   than/IN
#   all/DT
#   (Chink fear/NN ./.))
# (S
#   (Chink They/PRP)
#   know/VBP
#   (Chink what/WP it/PRP)
#   's/VBZ
#   like/IN
#   to/TO
#   fight/VB
#   (Chink house/NN)
#   to/TO
#   (Chink house/NN)
#   in/IN
#   a/DT
#   (Chink maze/NN)
#   of/IN
#   (Chink streets/NNS ,/,)
#   to/TO
#   wear/VB
#   (Chink heavy/JJ gear/NN)
#   in/IN
#   the/DT
#   (Chink desert/NN heat/NN ,/,)
#   to/TO
#   see/VB
#   a/DT
#   (Chink comrade/NN)
#   killed/VBN
#   by/IN
#   a/DT
#   (Chink roadside/NN bomb/NN ./.))
# (S
#   (Chink And/CC)
#   those/DT
#   (Chink who/WP)
#   know/VBP
#   the/DT
#   (Chink costs/NNS also/RB)
#   know/VBP
#   the/DT
#   (Chink stakes/NNS ./.))
# (S
#   (Chink Marine/JJ Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   was/VBD
#   killed/VBN
#   (Chink last/JJ month/NN)
#   fighting/VBG
#   in/IN
#   (Chink Fallujah/NNP ./.))
# (S
#   (Chink He/PRP)
#   left/VBD
#   (Chink behind/RP)
#   a/DT
#   (Chink letter/NN)
#   to/TO
#   (Chink
#     his/PRP$
#     family/NN
#     ,/,
#     but/CC
#     his/PRP$
#     words/NNS
#     could/MD
#     just/RB
#     as/RB
#     well/RB)
#   be/VB
#   addressed/VBN
#   to/TO
#   every/DT
#   (Chink American/NNP ./.))
# (S
#   (Chink Here/RB)
#   is/VBZ
#   (Chink what/WP Dan/NNP)
#   wrote/VBD
#   (Chink :/: ``/`` I/PRP)
#   know/VBP
#   (Chink what/WP honor/NN)
#   is/VBZ
#   (Chink ./.))
# (S
#   (Chink .../: It/PRP)
#   has/VBZ
#   been/VBN
#   an/DT
#   (Chink honor/NN)
#   to/TO
#   protect/VB
#   (Chink and/CC)
#   serve/VB
#   all/DT
#   of/IN
#   (Chink you/PRP ./.))
# (S
#   (Chink I/PRP)
#   faced/VBD
#   (Chink death/NN)
#   with/IN
#   the/DT
#   (Chink secure/NN knowledge/NN)
#   that/IN
#   (Chink you/PRP would/MD not/RB)
#   have/VB
#   to/TO
#   (Chink .../: ./.))
# (S (Chink Never/RB falter/NN !/.))
# (S
#   Do/VBP
#   (Chink n't/RB)
#   hesitate/VB
#   to/TO
#   honor/VB
#   (Chink and/CC)
#   support/VB
#   those/DT
#   of/IN
#   (Chink us/PRP who/WP)
#   have/VBP
#   the/DT
#   (Chink honor/NN)
#   of/IN
#   protecting/VBG
#   that/DT
#   (Chink which/WDT)
#   is/VBZ
#   (Chink worth/JJ)
#   protecting/VBG
#   (Chink ./. ''/''))
# (S
#   (Chink
#     Staff/NNP
#     Sergeant/NNP
#     Dan/NNP
#     Clay/NNP
#     's/POS
#     wife/NN
#     ,/,
#     Lisa/NNP
#     ,/,
#     and/CC
#     his/PRP$
#     mom/NN
#     and/CC
#     dad/NN
#     ,/,
#     Sara/NNP
#     Jo/NNP
#     and/CC
#     Bud/NNP
#     ,/,)
#   are/VBP
#   with/IN
#   (Chink us/PRP)
#   this/DT
#   (Chink evening/NN ./.))
# (S (Chink Welcome/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Our/PRP$ nation/NN)
#   is/VBZ
#   (Chink grateful/JJ)
#   to/TO
#   the/DT
#   fallen/VBN
#   (Chink ,/, who/WP)
#   live/VBP
#   in/IN
#   the/DT
#   (Chink memory/NN)
#   of/IN
#   (Chink our/PRP$ country/NN ./.))
# (S
#   (Chink We/PRP)
#   're/VBP
#   (Chink grateful/JJ)
#   to/TO
#   all/DT
#   (Chink who/WP)
#   volunteer/VBP
#   to/TO
#   wear/VB
#   (Chink our/PRP$ nation/NN 's/POS uniform/NN --/: and/CC)
#   as/IN
#   (Chink we/PRP)
#   honor/VBP
#   (Chink our/PRP$ brave/NN troops/NNS ,/,)
#   let/VB
#   (Chink us/PRP never/RB)
#   forget/VBP
#   the/DT
#   (Chink sacrifices/NNS)
#   of/IN
#   (Chink America/NNP 's/POS military/JJ families/NNS ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Our/PRP$ offensive/JJ)
#   against/IN
#   (Chink terror/NN)
#   involves/VBZ
#   (Chink more/JJR)
#   than/IN
#   (Chink military/JJ action/NN ./.))
# (S
#   (Chink Ultimately/RB ,/,)
#   the/DT
#   (Chink only/JJ way/NN)
#   to/TO
#   defeat/VB
#   the/DT
#   (Chink terrorists/NNS)
#   is/VBZ
#   to/TO
#   defeat/VB
#   (Chink their/PRP$ dark/JJ vision/NN)
#   of/IN
#   hatred/VBN
#   (Chink and/CC)
#   fear/VBN
#   by/IN
#   offering/VBG
#   the/DT
#   (Chink hopeful/JJ alternative/NN)
#   of/IN
#   (Chink political/JJ freedom/NN and/CC peaceful/JJ change/NN ./.))
# (S
#   So/IN
#   the/DT
#   (Chink United/NNP States/NNPS)
#   of/IN
#   (Chink America/NNP supports/NNS democratic/JJ reform/NN)
#   across/IN
#   the/DT
#   (Chink broader/JJR Middle/NNP East/NNP ./.))
# (S
#   (Chink Elections/NNS)
#   are/VBP
#   (Chink vital/JJ ,/, but/CC they/PRP)
#   are/VBP
#   (Chink only/RB)
#   the/DT
#   (Chink beginning/NN ./.))
# (S
#   Raising/VBG
#   (Chink up/RP)
#   a/DT
#   (Chink democracy/NN)
#   requires/VBZ
#   the/DT
#   (Chink rule/NN)
#   of/IN
#   (Chink law/NN ,/, and/CC protection/NN)
#   of/IN
#   (Chink
#     minorities/NNS
#     ,/,
#     and/CC
#     strong/JJ
#     ,/,
#     accountable/JJ
#     institutions/NNS)
#   that/IN
#   (Chink last/JJ longer/JJR)
#   than/IN
#   a/DT
#   (Chink single/JJ vote/NN ./.))
# (S
#   The/DT
#   (Chink great/JJ people/NNS)
#   of/IN
#   (Chink Egypt/NNP)
#   have/VBP
#   voted/VBN
#   in/IN
#   a/DT
#   (Chink
#     multi-party/JJ
#     presidential/JJ
#     election/NN
#     --/:
#     and/CC
#     now/RB
#     their/PRP$
#     government/NN
#     should/MD)
#   open/VB
#   (Chink paths/NNS)
#   of/IN
#   (Chink peaceful/JJ opposition/NN that/WDT will/MD)
#   reduce/VB
#   the/DT
#   (Chink appeal/NN)
#   of/IN
#   (Chink radicalism/NN ./.))
# (S
#   The/DT
#   (Chink Palestinian/JJ people/NNS)
#   have/VBP
#   voted/VBN
#   in/IN
#   (Chink elections/NNS ./.))
# (S
#   (Chink And/CC now/RB)
#   the/DT
#   (Chink leaders/NNS)
#   of/IN
#   (Chink Hamas/NNP must/MD)
#   recognize/VB
#   (Chink
#     Israel/NNP
#     ,/,
#     disarm/NN
#     ,/,
#     reject/JJ
#     terrorism/NN
#     ,/,
#     and/CC
#     work/NN)
#   for/IN
#   lasting/VBG
#   (Chink peace/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Saudi/NNP Arabia/NNP)
#   has/VBZ
#   taken/VBN
#   the/DT
#   (Chink first/JJ steps/NNS)
#   of/IN
#   (Chink reform/NN --/: now/RB it/PRP can/MD)
#   offer/VB
#   (Chink its/PRP$ people/NNS)
#   a/DT
#   (Chink better/JJR future/NN)
#   by/IN
#   pressing/VBG
#   (Chink forward/RB)
#   with/IN
#   those/DT
#   (Chink efforts/NNS ./.))
# (S
#   (Chink Democracies/NNS)
#   in/IN
#   the/DT
#   (Chink Middle/NNP East/NNP will/MD not/RB)
#   look/VB
#   like/IN
#   (Chink our/PRP$ own/JJ ,/,)
#   because/IN
#   (Chink they/PRP will/MD)
#   reflect/VB
#   the/DT
#   (Chink traditions/NNS)
#   of/IN
#   (Chink their/PRP$ own/JJ citizens/NNS ./.))
# (S
#   (Chink Yet/RB liberty/NN)
#   is/VBZ
#   the/DT
#   (Chink future/NN)
#   of/IN
#   every/DT
#   (Chink nation/NN)
#   in/IN
#   the/DT
#   (Chink Middle/NNP East/NNP ,/,)
#   because/IN
#   (Chink liberty/NN)
#   is/VBZ
#   the/DT
#   (Chink right/NN and/CC hope/NN)
#   of/IN
#   all/DT
#   (Chink humanity/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink President/NNP George/NNP W./NNP Bush/NNP)
#   waves/VBZ
#   toward/IN
#   the/DT
#   (Chink upper/JJ visitors/NNS gallery/NN)
#   of/IN
#   the/DT
#   (Chink House/NNP Chamber/NNP)
#   following/VBG
#   (Chink his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chink Union/NNP remarks/NNS Tuesday/NNP ,/, Jan/NNP ./.))
# (S
#   (Chink 31/CD ,/, 2006/CD)
#   at/IN
#   the/DT
#   (Chink United/NNP States/NNPS Capitol/NNP ./.))
# (S
#   (Chink White/NNP House/NNP photo/NN)
#   by/IN
#   (Chink Eric/NNP Draper/NNP)
#   The/DT
#   (Chink same/JJ)
#   is/VBZ
#   (Chink true/JJ)
#   of/IN
#   (Chink Iran/NNP ,/,)
#   a/DT
#   (Chink nation/NN now/RB)
#   held/VBN
#   (Chink hostage/NN)
#   by/IN
#   a/DT
#   (Chink small/JJ clerical/JJ elite/NN that/WDT)
#   is/VBZ
#   isolating/VBG
#   (Chink and/CC)
#   repressing/VBG
#   (Chink its/PRP$ people/NNS ./.))
# (S
#   The/DT
#   (Chink regime/NN)
#   in/IN
#   that/DT
#   (Chink country/NN sponsors/NNS terrorists/NNS)
#   in/IN
#   the/DT
#   (Chink Palestinian/JJ territories/NNS and/CC)
#   in/IN
#   (Chink Lebanon/NNP --/: and/CC)
#   that/DT
#   (Chink must/MD)
#   come/VB
#   to/TO
#   an/DT
#   (Chink end/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   The/DT
#   (Chink Iranian/JJ government/NN)
#   is/VBZ
#   defying/VBG
#   the/DT
#   (Chink world/NN)
#   with/IN
#   (Chink its/PRP$ nuclear/JJ ambitions/NNS ,/, and/CC)
#   the/DT
#   (Chink nations/NNS)
#   of/IN
#   the/DT
#   (Chink world/NN must/MD not/RB)
#   permit/VB
#   the/DT
#   (Chink Iranian/JJ regime/NN)
#   to/TO
#   gain/VB
#   (Chink nuclear/JJ weapons/NNS ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink America/NNP will/MD)
#   continue/VB
#   to/TO
#   rally/VB
#   the/DT
#   (Chink world/NN)
#   to/TO
#   confront/VB
#   these/DT
#   (Chink threats/NNS ./.))
# (S
#   (Chink Tonight/NNP ,/,)
#   let/VB
#   (Chink me/PRP)
#   speak/VB
#   (Chink directly/RB)
#   to/TO
#   the/DT
#   (Chink citizens/NNS)
#   of/IN
#   (Chink Iran/NNP :/: America/NNP)
#   respects/VBZ
#   (Chink you/PRP ,/, and/CC we/PRP)
#   respect/VBP
#   (Chink your/PRP$ country/NN ./.))
# (S
#   (Chink We/PRP)
#   respect/VBP
#   (Chink your/PRP$ right/NN)
#   to/TO
#   choose/VB
#   (Chink your/PRP$ own/JJ future/NN and/CC)
#   win/VB
#   (Chink your/PRP$ own/JJ freedom/NN ./.))
# (S
#   (Chink And/CC our/PRP$ nation/NN)
#   hopes/VBZ
#   (Chink one/CD day/NN)
#   to/TO
#   be/VB
#   the/DT
#   (Chink closest/JJS)
#   of/IN
#   (Chink friends/NNS)
#   with/IN
#   a/DT
#   (Chink free/JJ and/CC democratic/JJ Iran/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   To/TO
#   overcome/VB
#   (Chink dangers/NNS)
#   in/IN
#   (Chink our/PRP$ world/NN ,/, we/PRP must/MD also/RB)
#   take/VB
#   the/DT
#   (Chink offensive/JJ)
#   by/IN
#   encouraging/VBG
#   (Chink economic/JJ progress/NN ,/, and/CC)
#   fighting/VBG
#   (Chink disease/NN ,/, and/CC)
#   spreading/VBG
#   (Chink hope/NN)
#   in/IN
#   (Chink hopeless/JJ lands/NNS ./.))
# (S
#   (Chink Isolationism/NNP would/MD not/RB only/RB)
#   tie/VB
#   (Chink our/PRP$ hands/NNS)
#   in/IN
#   fighting/VBG
#   (Chink enemies/NNS ,/, it/PRP would/MD)
#   keep/VB
#   (Chink us/PRP)
#   from/IN
#   helping/VBG
#   (Chink our/PRP$ friends/NNS)
#   in/IN
#   (Chink desperate/JJ need/NN ./.))
# (S
#   (Chink We/PRP)
#   show/VBP
#   (Chink compassion/JJ abroad/RB)
#   because/IN
#   (Chink Americans/NNPS)
#   believe/VBP
#   in/IN
#   the/DT
#   (Chink God-given/NNP dignity/NN and/CC worth/NN)
#   of/IN
#   a/DT
#   (Chink villager/NN)
#   with/IN
#   (Chink HIV/AIDS/NNP ,/, or/CC)
#   an/DT
#   (Chink infant/NN)
#   with/IN
#   (Chink malaria/NNS ,/, or/CC)
#   a/DT
#   (Chink refugee/JJ fleeing/NN genocide/NN ,/, or/CC)
#   a/DT
#   (Chink young/JJ girl/NN)
#   sold/VBN
#   into/IN
#   (Chink slavery/NN ./.))
# (S
#   (Chink We/PRP also/RB)
#   show/VBP
#   (Chink compassion/NN abroad/RB)
#   because/IN
#   (Chink regions/NNS)
#   overwhelmed/VBN
#   by/IN
#   (Chink poverty/NN ,/, corruption/NN ,/, and/CC despair/NN)
#   are/VBP
#   (Chink sources/NNS)
#   of/IN
#   (Chink terrorism/NN ,/, and/CC)
#   organized/VBD
#   (Chink crime/NN ,/, and/CC human/JJ trafficking/NN ,/, and/CC)
#   the/DT
#   (Chink drug/NN trade/NN ./.))
# (S
#   In/IN
#   (Chink recent/JJ years/NNS ,/, you/PRP and/CC I/PRP)
#   have/VBP
#   taken/VBN
#   (Chink unprecedented/JJ action/NN)
#   to/TO
#   fight/VB
#   (Chink AIDS/NNP and/CC malaria/NNS ,/,)
#   expand/VBP
#   the/DT
#   (Chink education/NN)
#   of/IN
#   (Chink girls/NNS ,/, and/CC reward/RB)
#   developing/VBG
#   (Chink nations/NNS that/WDT)
#   are/VBP
#   moving/VBG
#   (Chink forward/RB)
#   with/IN
#   (Chink economic/JJ and/CC political/JJ reform/NN ./.))
# (S
#   For/IN
#   (Chink people/NNS everywhere/RB ,/,)
#   the/DT
#   (Chink United/NNP States/NNPS)
#   is/VBZ
#   a/DT
#   (Chink partner/NN)
#   for/IN
#   a/DT
#   (Chink better/JJR life/NN ./.))
# (S
#   Short-changing/VBG
#   these/DT
#   (Chink efforts/NNS would/MD)
#   increase/VB
#   the/DT
#   (Chink suffering/NN and/CC chaos/NN)
#   of/IN
#   (Chink
#     our/PRP$
#     world/NN
#     ,/,
#     undercut/JJ
#     our/PRP$
#     long-term/JJ
#     security/NN
#     ,/,
#     and/CC)
#   dull/VB
#   the/DT
#   (Chink conscience/NN)
#   of/IN
#   (Chink our/PRP$ country/NN ./.))
# (S
#   (Chink I/PRP)
#   urge/VBP
#   (Chink members/NNS)
#   of/IN
#   (Chink Congress/NNP)
#   to/TO
#   serve/VB
#   the/DT
#   (Chink interests/NNS)
#   of/IN
#   (Chink America/NNP)
#   by/IN
#   showing/VBG
#   the/DT
#   (Chink compassion/NN)
#   of/IN
#   (Chink America/NNP ./.))
# (S
#   (Chink Our/PRP$ country/NN must/MD also/RB)
#   remain/VB
#   on/IN
#   the/DT
#   (Chink offensive/JJ)
#   against/IN
#   (Chink terrorism/NN here/RB)
#   at/IN
#   (Chink home/NN ./.))
# (S
#   The/DT
#   (Chink enemy/NN)
#   has/VBZ
#   (Chink not/RB)
#   lost/VBN
#   the/DT
#   (Chink desire/NN or/CC capability/NN)
#   to/TO
#   attack/VB
#   (Chink us/PRP ./.))
# (S
#   (Chink Fortunately/RB ,/,)
#   this/DT
#   (Chink nation/NN)
#   has/VBZ
#   superb/VBN
#   (Chink professionals/NNS)
#   in/IN
#   (Chink law/NN enforcement/NN ,/, intelligence/NN ,/,)
#   the/DT
#   (Chink military/JJ ,/, and/CC)
#   homeland/VBP
#   (Chink security/NN ./.))
# (S
#   These/DT
#   (Chink men/NNS and/CC women/NNS)
#   are/VBP
#   dedicating/VBG
#   (Chink their/PRP$ lives/NNS ,/,)
#   protecting/VBG
#   (Chink us/PRP)
#   all/DT
#   (Chink ,/, and/CC they/PRP)
#   deserve/VBP
#   (Chink our/PRP$ support/NN and/CC our/PRP$ thanks/NNS ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink They/PRP also/RB)
#   deserve/VBP
#   the/DT
#   (Chink same/JJ tools/NNS they/PRP already/RB)
#   use/VBP
#   to/TO
#   fight/VB
#   (Chink drug/NN trafficking/NN and/CC)
#   organized/VBN
#   (Chink crime/NN --/: so/RB I/PRP)
#   ask/VBP
#   (Chink you/PRP)
#   to/TO
#   reauthorize/VB
#   the/DT
#   (Chink Patriot/NNP Act/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink It/PRP)
#   is/VBZ
#   said/VBD
#   that/IN
#   (Chink prior/JJ)
#   to/TO
#   the/DT
#   (Chink attacks/NNS)
#   of/IN
#   (Chink September/NNP)
#   the/DT
#   (Chink 11th/CD ,/, our/PRP$ government/NN)
#   failed/VBD
#   to/TO
#   connect/VB
#   the/DT
#   (Chink dots/NNS)
#   of/IN
#   the/DT
#   (Chink conspiracy/NN ./.))
# (S
#   (Chink We/PRP now/RB)
#   know/VBP
#   that/IN
#   (Chink two/CD)
#   of/IN
#   the/DT
#   (Chink hijackers/NNS)
#   in/IN
#   the/DT
#   (Chink United/NNP States/NNPS)
#   placed/VBD
#   (Chink telephone/NN calls/NNS)
#   to/TO
#   al/VB
#   (Chink Qaeda/NNP)
#   operatives/VBZ
#   (Chink overseas/RB ./.))
# (S
#   (Chink But/CC we/PRP)
#   did/VBD
#   (Chink not/RB)
#   know/VB
#   about/IN
#   (Chink their/PRP$ plans/NNS)
#   until/IN
#   (Chink it/PRP)
#   was/VBD
#   (Chink too/RB late/JJ ./.))
# (S
#   (Chink So/RB)
#   to/TO
#   prevent/VB
#   another/DT
#   (Chink attack/NN --/:)
#   based/VBN
#   on/IN
#   (Chink authority/NN)
#   given/VBN
#   to/TO
#   (Chink me/PRP)
#   by/IN
#   the/DT
#   (Chink Constitution/NNP and/CC)
#   by/IN
#   (Chink statute/NN --/: I/PRP)
#   have/VBP
#   authorized/VBN
#   a/DT
#   (Chink terrorist/JJ surveillance/NN program/NN)
#   to/TO
#   (Chink aggressively/RB)
#   pursue/VB
#   the/DT
#   (Chink international/JJ communications/NNS)
#   of/IN
#   (Chink
#     suspected/JJ
#     al/JJ
#     Qaeda/NNP
#     operatives/NNS
#     and/CC
#     affiliates/NNS)
#   to/TO
#   (Chink and/CC)
#   from/IN
#   (Chink America/NNP ./.))
# (S
#   (Chink Previous/JJ Presidents/NNS)
#   have/VBP
#   used/VBN
#   the/DT
#   (Chink same/JJ constitutional/JJ authority/NN I/PRP)
#   have/VBP
#   (Chink ,/, and/CC federal/JJ courts/NNS)
#   have/VBP
#   approved/VBN
#   the/DT
#   (Chink use/NN)
#   of/IN
#   that/DT
#   (Chink authority/NN ./.))
# (S
#   (Chink Appropriate/JJ members/NNS)
#   of/IN
#   (Chink Congress/NNP)
#   have/VBP
#   been/VBN
#   kept/VBN
#   informed/VBN
#   (Chink ./.))
# (S
#   The/DT
#   (Chink terrorist/JJ surveillance/NN program/NN)
#   has/VBZ
#   helped/VBN
#   prevent/VB
#   (Chink terrorist/JJ attacks/NNS ./.))
# (S
#   (Chink It/PRP)
#   remains/VBZ
#   (Chink essential/JJ)
#   to/TO
#   the/DT
#   (Chink security/NN)
#   of/IN
#   (Chink America/NNP ./.))
# (S
#   If/IN
#   (Chink there/EX)
#   are/VBP
#   (Chink people/NNS)
#   inside/IN
#   (Chink our/PRP$ country/NN who/WP)
#   are/VBP
#   talking/VBG
#   with/IN
#   (Chink al/NN Qaeda/NNP ,/, we/PRP)
#   want/VBP
#   to/TO
#   know/VB
#   about/IN
#   (Chink it/PRP ,/,)
#   because/IN
#   (Chink we/PRP will/MD not/RB)
#   sit/VB
#   (Chink back/RB and/CC wait/NN)
#   to/TO
#   be/VB
#   hit/VBN
#   (Chink again/RB ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   In/IN
#   (Chink all/PDT)
#   these/DT
#   (Chink areas/NNS --/:)
#   from/IN
#   the/DT
#   (Chink disruption/NN)
#   of/IN
#   (Chink terror/NN networks/NNS ,/,)
#   to/TO
#   (Chink victory/NN)
#   in/IN
#   (Chink Iraq/NNP ,/,)
#   to/TO
#   the/DT
#   (Chink spread/NN)
#   of/IN
#   (Chink freedom/NN and/CC hope/NN)
#   in/IN
#   (Chink troubled/JJ regions/NNS --/: we/PRP)
#   need/VBP
#   the/DT
#   (Chink support/NN)
#   of/IN
#   (Chink our/PRP$ friends/NNS and/CC allies/NNS ./.))
# (S
#   To/TO
#   draw/VB
#   that/DT
#   (Chink support/NN ,/, we/PRP must/MD always/RB)
#   be/VB
#   (Chink clear/JJ)
#   in/IN
#   (Chink our/PRP$ principles/NNS and/CC willing/JJ)
#   to/TO
#   act/VB
#   (Chink ./.))
# (S
#   The/DT
#   (Chink only/JJ alternative/NN)
#   to/TO
#   (Chink American/JJ leadership/NN)
#   is/VBZ
#   a/DT
#   (Chink
#     dramatically/RB
#     more/RBR
#     dangerous/JJ
#     and/CC
#     anxious/JJ
#     world/NN
#     ./.))
# (S
#   (Chink Yet/CC we/PRP also/RB)
#   choose/VBP
#   to/TO
#   lead/VB
#   because/IN
#   (Chink it/PRP)
#   is/VBZ
#   a/DT
#   (Chink privilege/NN)
#   to/TO
#   serve/VB
#   the/DT
#   (Chink values/NNS that/WDT)
#   gave/VBD
#   (Chink us/PRP birth/NN ./.))
# (S
#   (Chink American/JJ leaders/NNS --/:)
#   from/IN
#   (Chink Roosevelt/NNP)
#   to/TO
#   (Chink Truman/NNP)
#   to/TO
#   (Chink Kennedy/NNP)
#   to/TO
#   (Chink Reagan/NNP --/:)
#   rejected/VBD
#   (Chink isolation/NN and/CC retreat/NN ,/,)
#   because/IN
#   (Chink they/PRP)
#   knew/VBD
#   that/IN
#   (Chink America/NNP)
#   is/VBZ
#   (Chink always/RB more/RBR secure/JJ when/WRB freedom/NN)
#   is/VBZ
#   on/IN
#   the/DT
#   (Chink march/NN ./.))
# (S
#   (Chink Our/PRP$ own/JJ generation/NN)
#   is/VBZ
#   in/IN
#   a/DT
#   (Chink long/JJ war/NN)
#   against/IN
#   a/DT
#   (Chink determined/JJ enemy/NN --/:)
#   a/DT
#   (Chink war/NN that/WDT will/MD)
#   be/VB
#   fought/VBN
#   by/IN
#   (Chink Presidents/NNS)
#   of/IN
#   both/DT
#   (Chink parties/NNS ,/, who/WP will/MD)
#   need/VB
#   (Chink steady/JJ bipartisan/JJ support/NN)
#   from/IN
#   the/DT
#   (Chink Congress/NNP ./.))
# (S
#   (Chink And/CC tonight/NN I/PRP)
#   ask/VBP
#   for/IN
#   (Chink yours/NNS ./.))
# (S
#   (Chink Together/RB ,/,)
#   let/VB
#   (Chink us/PRP)
#   protect/VB
#   (Chink our/PRP$ country/NN ,/,)
#   support/VB
#   the/DT
#   (Chink men/NNS and/CC women/NNS who/WP)
#   defend/VBP
#   (Chink us/PRP ,/, and/CC)
#   lead/VB
#   this/DT
#   (Chink world/NN)
#   toward/IN
#   (Chink freedom/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Here/RB)
#   at/IN
#   (Chink home/NN ,/, America/NNP also/RB)
#   has/VBZ
#   a/DT
#   (Chink great/JJ opportunity/NN :/: We/PRP will/MD)
#   build/VB
#   the/DT
#   (Chink prosperity/NN)
#   of/IN
#   (Chink our/PRP$ country/NN)
#   by/IN
#   strengthening/VBG
#   (Chink our/PRP$ economic/JJ leadership/NN)
#   in/IN
#   the/DT
#   (Chink world/NN ./.))
# (S
#   (Chink Our/PRP$ economy/NN)
#   is/VBZ
#   (Chink healthy/JJ and/CC vigorous/JJ ,/, and/CC)
#   growing/VBG
#   (Chink faster/RBR)
#   than/IN
#   (Chink other/JJ major/JJ)
#   industrialized/VBN
#   (Chink nations/NNS ./.))
# (S
#   In/IN
#   the/DT
#   (Chink last/JJ two-and-a-half/JJ years/NNS ,/, America/NNP)
#   has/VBZ
#   created/VBN
#   (Chink 4.6/CD million/CD new/JJ jobs/NNS --/: more/JJR)
#   than/IN
#   (Chink Japan/NNP and/CC)
#   the/DT
#   (Chink European/NNP Union/NNP)
#   combined/VBD
#   (Chink ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Even/RB)
#   in/IN
#   the/DT
#   (Chink face/NN)
#   of/IN
#   (Chink
#     higher/JJR
#     energy/NN
#     prices/NNS
#     and/CC
#     natural/JJ
#     disasters/NNS
#     ,/,)
#   the/DT
#   (Chink American/JJ people/NNS)
#   have/VBP
#   turned/VBN
#   in/IN
#   an/DT
#   (Chink economic/JJ performance/NN that/WDT)
#   is/VBZ
#   the/DT
#   (Chink envy/NN)
#   of/IN
#   the/DT
#   (Chink world/NN ./.))
# (S
#   The/DT
#   (Chink American/JJ economy/NN)
#   is/VBZ
#   (Chink preeminent/JJ ,/, but/CC we/PRP can/MD not/RB)
#   afford/VB
#   to/TO
#   be/VB
#   (Chink complacent/JJ ./.))
# (S
#   In/IN
#   a/DT
#   (Chink dynamic/JJ world/NN economy/NN ,/, we/PRP)
#   are/VBP
#   seeing/VBG
#   (Chink new/JJ competitors/NNS ,/,)
#   like/IN
#   (Chink China/NNP and/CC India/NNP ,/, and/CC)
#   this/DT
#   creates/VBZ
#   (Chink uncertainty/NN ,/, which/WDT)
#   makes/VBZ
#   (Chink it/PRP easier/JJR)
#   to/TO
#   feed/VB
#   (Chink people/NNS 's/POS fears/NNS ./.))
# (S
#   So/IN
#   (Chink we/PRP)
#   're/VBP
#   seeing/VBG
#   some/DT
#   (Chink old/JJ temptations/NNS return/NN ./.))
# (S
#   (Chink Protectionists/NNS)
#   want/VBP
#   to/TO
#   escape/VB
#   (Chink competition/NN ,/,)
#   pretending/VBG
#   that/IN
#   (Chink we/PRP can/MD)
#   keep/VB
#   (Chink our/PRP$ high/JJ standard/NN)
#   of/IN
#   (Chink living/NN)
#   while/IN
#   walling/VBG
#   (Chink off/RP our/PRP$ economy/NN ./.))
# (S
#   (Chink Others/NNS)
#   say/VBP
#   that/IN
#   the/DT
#   (Chink government/NN)
#   needs/VBZ
#   to/TO
#   take/VB
#   a/DT
#   (Chink larger/JJR role/NN)
#   in/IN
#   directing/VBG
#   the/DT
#   (Chink economy/NN ,/,)
#   centralizing/VBG
#   (Chink more/JJR power/NN)
#   in/IN
#   (Chink Washington/NNP and/CC)
#   increasing/VBG
#   (Chink taxes/NNS ./.))
# (S
#   (Chink We/PRP)
#   hear/VBP
#   (Chink claims/NNS)
#   that/IN
#   (Chink immigrants/NNS)
#   are/VBP
#   (Chink somehow/RB bad/JJ)
#   for/IN
#   the/DT
#   (Chink economy/NN --/: even/RB)
#   though/IN
#   this/DT
#   (Chink economy/NN could/MD not/RB)
#   function/VB
#   without/IN
#   (Chink them/PRP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink All/PDT)
#   these/DT
#   are/VBP
#   (Chink forms/NNS)
#   of/IN
#   (Chink economic/JJ retreat/NN ,/, and/CC they/PRP)
#   lead/VBP
#   in/IN
#   the/DT
#   (Chink same/JJ direction/NN --/:)
#   toward/IN
#   a/DT
#   (Chink stagnant/JJ and/CC second-rate/JJ economy/NN ./.))
# (S
#   (Chink Tonight/NNP I/PRP will/MD)
#   set/VB
#   (Chink out/RP)
#   a/DT
#   (Chink better/JJR path/NN :/:)
#   an/DT
#   (Chink agenda/NN)
#   for/IN
#   a/DT
#   (Chink nation/NN that/WDT)
#   competes/VBZ
#   with/IN
#   (Chink confidence/NN ;/:)
#   an/DT
#   (Chink agenda/NN that/WDT will/MD)
#   raise/VB
#   (Chink standards/NNS)
#   of/IN
#   (Chink living/NN and/CC)
#   generate/VB
#   (Chink new/JJ jobs/NNS ./.))
# (S
#   (Chink Americans/NNPS should/MD not/RB)
#   fear/VB
#   (Chink our/PRP$ economic/JJ future/NN ,/,)
#   because/IN
#   (Chink we/PRP)
#   intend/VBP
#   to/TO
#   shape/VB
#   (Chink it/PRP ./.))
# (S
#   Keeping/VBG
#   (Chink America/NNP competitive/JJ begins/NNS)
#   with/IN
#   keeping/VBG
#   (Chink our/PRP$ economy/NN)
#   growing/VBG
#   (Chink ./.))
# (S
#   (Chink And/CC our/PRP$ economy/NN)
#   grows/VBZ
#   (Chink when/WRB Americans/NNPS)
#   have/VBP
#   (Chink more/JJR)
#   of/IN
#   (Chink their/PRP$ own/JJ money/NN)
#   to/TO
#   spend/VB
#   (Chink ,/,)
#   save/VB
#   (Chink ,/, and/CC invest/JJS ./.))
# (S
#   In/IN
#   the/DT
#   (Chink last/JJ five/CD years/NNS ,/,)
#   the/DT
#   (Chink tax/NN relief/NN you/PRP)
#   passed/VBN
#   has/VBZ
#   left/VBN
#   (Chink $/$ 880/CD billion/CD)
#   in/IN
#   the/DT
#   (Chink hands/NNS)
#   of/IN
#   (Chink
#     American/JJ
#     workers/NNS
#     ,/,
#     investors/NNS
#     ,/,
#     small/JJ
#     businesses/NNS
#     ,/,
#     and/CC
#     families/NNS
#     --/:
#     and/CC
#     they/PRP)
#   have/VBP
#   used/VBN
#   (Chink it/PRP)
#   to/TO
#   help/VB
#   produce/VB
#   (Chink more/JJR)
#   than/IN
#   (Chink four/CD years/NNS)
#   of/IN
#   (Chink uninterrupted/JJ economic/JJ growth/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Yet/RB)
#   the/DT
#   (Chink tax/NN relief/NN)
#   is/VBZ
#   set/VBN
#   to/TO
#   expire/VB
#   in/IN
#   the/DT
#   (Chink next/JJ few/JJ years/NNS ./.))
# (S
#   If/IN
#   (Chink we/PRP)
#   do/VBP
#   (Chink nothing/NN ,/, American/NNP families/NNS will/MD)
#   face/VB
#   a/DT
#   (Chink massive/JJ tax/NN increase/NN they/PRP)
#   do/VBP
#   (Chink not/RB)
#   expect/VB
#   (Chink and/CC will/MD not/RB)
#   welcome/VB
#   (Chink ./.))
# (S
#   Because/IN
#   (Chink America/NNP)
#   needs/VBZ
#   (Chink more/JJR)
#   than/IN
#   a/DT
#   (Chink temporary/JJ expansion/NN ,/, we/PRP)
#   need/VBP
#   (Chink more/JJR)
#   than/IN
#   (Chink temporary/JJ tax/NN relief/NN ./.))
# (S
#   (Chink I/PRP)
#   urge/VBP
#   the/DT
#   (Chink Congress/NNP)
#   to/TO
#   act/VB
#   (Chink responsibly/RB ,/, and/CC)
#   make/VB
#   the/DT
#   (Chink tax/NN cuts/NNS permanent/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   Keeping/VBG
#   (Chink America/NNP competitive/JJ)
#   requires/VBZ
#   (Chink us/PRP)
#   to/TO
#   be/VB
#   (Chink good/JJ stewards/NNS)
#   of/IN
#   (Chink tax/NN dollars/NNS ./.))
# (S
#   Every/DT
#   (Chink year/NN)
#   of/IN
#   (Chink my/PRP$ presidency/NN ,/, we/PRP)
#   've/VBP
#   reduced/VBN
#   the/DT
#   (Chink growth/NN)
#   of/IN
#   (Chink
#     non-security/JJ
#     discretionary/JJ
#     spending/NN
#     ,/,
#     and/CC
#     last/JJ
#     year/NN
#     you/PRP)
#   passed/VBD
#   (Chink bills/NNS)
#   that/IN
#   cut/VBD
#   this/DT
#   (Chink spending/NN ./.))
# (S
#   This/DT
#   (Chink year/NN my/PRP$ budget/NN will/MD)
#   cut/VB
#   (Chink it/PRP again/RB ,/, and/CC)
#   reduce/VB
#   (Chink or/CC)
#   eliminate/VB
#   (Chink more/JJR)
#   than/IN
#   (Chink 140/CD programs/NNS that/WDT)
#   are/VBP
#   performing/VBG
#   (Chink
#     poorly/RB
#     or/CC
#     not/RB
#     fulfilling/JJ
#     essential/JJ
#     priorities/NNS
#     ./.))
# (S
#   By/IN
#   passing/VBG
#   these/DT
#   (Chink reforms/NNS ,/, we/PRP will/MD)
#   save/VB
#   the/DT
#   (Chink American/NNP taxpayer/NN)
#   another/DT
#   (Chink $/$ 14/CD billion/CD next/JJ year/NN ,/, and/CC)
#   stay/VB
#   on/IN
#   (Chink track/NN)
#   to/TO
#   cut/VB
#   the/DT
#   (Chink deficit/NN)
#   in/IN
#   (Chink half/NN)
#   by/IN
#   (Chink 2009/CD ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink I/PRP)
#   am/VBP
#   (Chink pleased/JJ)
#   that/IN
#   (Chink members/NNS)
#   of/IN
#   (Chink Congress/NNP)
#   are/VBP
#   working/VBG
#   on/IN
#   (Chink earmark/NN reform/NN ,/,)
#   because/IN
#   the/DT
#   (Chink federal/JJ budget/NN)
#   has/VBZ
#   (Chink too/RB many/JJ special/JJ interest/NN projects/NNS ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink And/CC we/PRP can/MD)
#   tackle/VB
#   this/DT
#   (Chink problem/NN together/RB ,/,)
#   if/IN
#   (Chink you/PRP)
#   pass/VBP
#   the/DT
#   (Chink line-item/JJ veto/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink We/PRP must/MD also/RB)
#   confront/VB
#   the/DT
#   (Chink larger/JJR challenge/NN)
#   of/IN
#   (Chink mandatory/JJ spending/NN ,/, or/CC entitlements/NNS ./.))
# (S
#   This/DT
#   (Chink year/NN ,/,)
#   the/DT
#   (Chink first/JJ)
#   of/IN
#   (Chink about/RB 78/CD million/CD baby/NN boomers/NNS)
#   turn/VBP
#   (Chink 60/CD ,/,)
#   including/VBG
#   (Chink two/CD)
#   of/IN
#   (Chink
#     my/PRP$
#     Dad/NNP
#     's/POS
#     favorite/JJ
#     people/NNS
#     --/:
#     me/PRP
#     and/CC
#     President/NNP
#     Clinton/NNP
#     ./.))
# (S (Chink (/( Laughter/NNP ./. )/)))
# (S
#   This/DT
#   (Chink milestone/NN)
#   is/VBZ
#   (Chink more/JJR)
#   than/IN
#   a/DT
#   (Chink personal/JJ crisis/NN --/: (/( laughter/NN )/) --/: it/PRP)
#   is/VBZ
#   a/DT
#   (Chink national/JJ challenge/NN ./.))
# (S
#   The/DT
#   (Chink retirement/NN)
#   of/IN
#   the/DT
#   (Chink baby/NN boom/NN generation/NN will/MD)
#   put/VB
#   (Chink unprecedented/JJ strains/NNS)
#   on/IN
#   the/DT
#   (Chink federal/JJ government/NN ./.))
# (S
#   By/IN
#   (Chink 2030/CD ,/,)
#   spending/VBG
#   for/IN
#   (Chink
#     Social/NNP
#     Security/NNP
#     ,/,
#     Medicare/NNP
#     and/CC
#     Medicaid/NNP
#     alone/RB
#     will/MD)
#   be/VB
#   (Chink almost/RB 60/CD percent/NN)
#   of/IN
#   the/DT
#   (Chink entire/JJ federal/JJ budget/NN ./.))
# (S
#   (Chink And/CC)
#   that/DT
#   (Chink will/MD)
#   present/VB
#   (Chink future/JJ Congresses/NNS)
#   with/IN
#   (Chink impossible/JJ choices/NNS --/:)
# ...
#   (Chink power/NN or/CC luxuries/NNS ,/, but/CC)
#   by/IN
#   (Chink who/WP we/PRP)
#   are/VBP
#   (Chink and/CC how/WRB we/PRP)
#   treat/VBP
#   (Chink one/CD)
#   another/DT
#   (Chink ./.))
# (S
#   So/IN
#   (Chink we/PRP)
#   strive/VBP
#   to/TO
#   be/VB
#   a/DT
#   (Chink
#     compassionate/NN
#     ,/,
#     decent/NN
#     ,/,
#     hopeful/JJ
#     society/NN
#     ./.))
# (S
#   In/IN
#   (Chink recent/JJ years/NNS ,/, America/NNP)
#   has/VBZ
#   become/VBN
#   a/DT
#   (Chink more/RBR hopeful/JJ nation/NN ./.))
# (S
#   (Chink Violent/JJ crime/NN rates/NNS)
#   have/VBP
#   fallen/VBN
#   to/TO
#   (Chink their/PRP$ lowest/JJS levels/NNS)
#   since/IN
#   the/DT
#   (Chink 1970s/CD ./.))
# (S
#   (Chink Welfare/NN cases/NNS)
#   have/VBP
#   dropped/VBN
#   by/IN
#   (Chink more/JJR)
#   than/IN
#   (Chink half/NN)
#   over/IN
#   the/DT
#   (Chink past/JJ decade/NN ./.))
# (S
#   (Chink Drug/NN use/NN)
#   among/IN
#   (Chink youth/NN)
#   is/VBZ
#   (Chink down/RB 19/CD percent/NN)
#   since/IN
#   (Chink 2001/CD ./.))
# (S
#   (Chink There/EX)
#   are/VBP
#   (Chink fewer/JJR abortions/NNS)
#   in/IN
#   (Chink America/NNP)
#   than/IN
#   at/IN
#   any/DT
#   (Chink point/NN)
#   in/IN
#   the/DT
#   (Chink last/JJ three/CD decades/NNS ,/, and/CC)
#   the/DT
#   (Chink number/NN)
#   of/IN
#   (Chink children/NNS)
#   born/VBN
#   to/TO
#   teenage/VB
#   (Chink mothers/NNS)
#   has/VBZ
#   been/VBN
#   falling/VBG
#   for/IN
#   a/DT
#   (Chink dozen/NN years/NNS)
#   in/IN
#   a/DT
#   (Chink row/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   These/DT
#   (Chink gains/NNS)
#   are/VBP
#   (Chink evidence/NN)
#   of/IN
#   a/DT
#   (Chink quiet/JJ transformation/NN --/:)
#   a/DT
#   (Chink revolution/NN)
#   of/IN
#   (Chink conscience/NN ,/,)
#   in/IN
#   (Chink which/WDT)
#   a/DT
#   rising/VBG
#   (Chink generation/NN)
#   is/VBZ
#   finding/VBG
#   that/IN
#   a/DT
#   (Chink life/NN)
#   of/IN
#   (Chink personal/JJ responsibility/NN)
#   is/VBZ
#   a/DT
#   (Chink life/NN)
#   of/IN
#   (Chink fulfillment/NN ./.))
# (S
#   (Chink Government/NNP)
#   has/VBZ
#   played/VBN
#   a/DT
#   (Chink role/NN ./.))
# (S
#   (Chink Wise/NNP policies/NNS ,/, such/JJ)
#   as/IN
#   (Chink
#     welfare/NN
#     reform/NN
#     and/CC
#     drug/NN
#     education/NN
#     and/CC
#     support/NN)
#   for/IN
#   (Chink abstinence/NN and/CC adoption/NN)
#   have/VBP
#   made/VBN
#   a/DT
#   (Chink difference/NN)
#   in/IN
#   the/DT
#   (Chink character/NN)
#   of/IN
#   (Chink our/PRP$ country/NN ./.))
# (S
#   (Chink
#     And/CC
#     everyone/NN
#     here/RB
#     tonight/RB
#     ,/,
#     Democrat/NNP
#     and/CC
#     Republican/NNP
#     ,/,)
#   has/VBZ
#   a/DT
#   (Chink right/NN)
#   to/TO
#   be/VB
#   (Chink proud/JJ)
#   of/IN
#   this/DT
#   (Chink record/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink
#     Yet/RB
#     many/JJ
#     Americans/NNPS
#     ,/,
#     especially/RB
#     parents/NNS
#     ,/,
#     still/RB)
#   have/VBP
#   (Chink deep/JJ concerns/NNS)
#   about/IN
#   the/DT
#   (Chink direction/NN)
#   of/IN
#   (Chink our/PRP$ culture/NN ,/, and/CC)
#   the/DT
#   (Chink health/NN)
#   of/IN
#   (Chink our/PRP$ most/JJS basic/JJ institutions/NNS ./.))
# (S
#   (Chink They/PRP)
#   're/VBP
#   concerned/VBN
#   about/IN
#   (Chink unethical/JJ conduct/NN)
#   by/IN
#   (Chink public/JJ officials/NNS ,/, and/CC)
#   discouraged/VBN
#   by/IN
#   (Chink activist/NN courts/NNS that/WDT)
#   try/VBP
#   to/TO
#   redefine/VB
#   (Chink marriage/NN ./.))
# (S
#   (Chink They/PRP)
#   worry/VBP
#   about/IN
#   (Chink children/NNS)
#   in/IN
#   (Chink our/PRP$ society/NN who/WP)
#   need/VBP
#   (Chink direction/NN and/CC love/NN ,/, and/CC)
#   about/IN
#   (Chink fellow/JJ citizens/NNS still/RB)
#   displaced/VBN
#   by/IN
#   (Chink natural/JJ disaster/NN ,/, and/CC)
#   about/IN
#   suffering/VBG
#   caused/VBN
#   by/IN
#   (Chink treatable/JJ diseases/NNS ./.))
# (S
#   As/IN
#   (Chink we/PRP)
#   look/VBP
#   at/IN
#   these/DT
#   (Chink challenges/NNS ,/, we/PRP must/MD never/RB)
#   give/VB
#   in/IN
#   to/TO
#   the/DT
#   (Chink belief/NN)
#   that/IN
#   (Chink America/NNP)
#   is/VBZ
#   in/IN
#   (Chink decline/NN ,/, or/CC)
#   that/IN
#   (Chink our/PRP$ culture/NN)
#   is/VBZ
#   doomed/VBN
#   to/TO
#   unravel/VB
#   (Chink ./.))
# (S
#   The/DT
#   (Chink American/JJ people/NNS)
#   know/VBP
#   (Chink better/JJR)
#   than/IN
#   that/DT
#   (Chink ./.))
# (S
#   (Chink We/PRP)
#   have/VBP
#   proven/VBN
#   the/DT
#   (Chink
#     pessimists/NNS
#     wrong/JJ
#     before/RB
#     --/:
#     and/CC
#     we/PRP
#     will/MD)
#   do/VB
#   (Chink it/PRP again/RB ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   A/DT
#   (Chink hopeful/JJ society/NN)
#   depends/VBZ
#   on/IN
#   (Chink courts/NNS)
#   that/IN
#   deliver/VBP
#   (Chink equal/JJ justice/NN)
#   under/IN
#   the/DT
#   (Chink law/NN ./.))
# (S
#   The/DT
#   (Chink Supreme/NNP Court/NNP now/RB)
#   has/VBZ
#   (Chink two/CD superb/JJ new/JJ members/NNS --/: new/JJ members/NNS)
#   on/IN
#   (Chink
#     its/PRP$
#     bench/NN
#     :/:
#     Chief/JJ
#     Justice/NNP
#     John/NNP
#     Roberts/NNP
#     and/CC
#     Justice/NNP
#     Sam/NNP
#     Alito/NNP
#     ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink I/PRP)
#   thank/VBD
#   the/DT
#   (Chink Senate/NNP)
#   for/IN
#   confirming/VBG
#   both/DT
#   of/IN
#   (Chink them/PRP ./.))
# (S
#   (Chink I/PRP will/MD)
#   continue/VB
#   to/TO
#   nominate/VB
#   (Chink men/NNS and/CC women/NNS who/WP)
#   understand/VBP
#   that/IN
#   (Chink judges/NNS must/MD)
#   be/VB
#   (Chink servants/NNS)
#   of/IN
#   the/DT
#   (Chink law/NN ,/, and/CC not/RB)
#   legislate/VB
#   from/IN
#   the/DT
#   (Chink bench/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Today/NN)
#   marks/VBZ
#   the/DT
#   (Chink official/JJ retirement/NN)
#   of/IN
#   a/DT
#   (Chink very/RB special/JJ American/NNP ./.))
# (S
#   For/IN
#   (Chink 24/CD years/NNS)
#   of/IN
#   (Chink faithful/JJ service/NN)
#   to/TO
#   (Chink our/PRP$ nation/NN ,/,)
#   the/DT
#   (Chink United/NNP States/NNPS)
#   is/VBZ
#   (Chink grateful/JJ)
#   to/TO
#   (Chink Justice/NNP Sandra/NNP Day/NNP O'Connor/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   A/DT
#   (Chink hopeful/JJ society/NN)
#   has/VBZ
#   (Chink institutions/NNS)
#   of/IN
#   (Chink science/NN and/CC medicine/NN that/WDT)
#   do/VBP
#   (Chink not/RB)
#   cut/VB
#   (Chink ethical/JJ corners/NNS ,/, and/CC)
#   that/IN
#   recognize/VBP
#   the/DT
#   (Chink matchless/NN value/NN)
#   of/IN
#   every/DT
#   (Chink life/NN ./.))
# (S
#   (Chink Tonight/NNP I/PRP)
#   ask/VBP
#   (Chink you/PRP)
#   to/TO
#   pass/VB
#   (Chink legislation/NN)
#   to/TO
#   prohibit/VB
#   the/DT
#   (Chink most/RBS egregious/JJ abuses/NNS)
#   of/IN
#   (Chink medical/JJ research/NN :/: human/JJ)
#   cloning/VBG
#   in/IN
#   all/DT
#   (Chink its/PRP$ forms/NNS ,/,)
#   creating/VBG
#   (Chink or/CC)
#   implanting/VBG
#   (Chink embryos/NN)
#   for/IN
#   (Chink experiments/NNS ,/,)
#   creating/VBG
#   (Chink
#     human-animal/JJ
#     hybrids/NNS
#     ,/,
#     and/CC
#     buying/NN
#     ,/,
#     selling/NN
#     ,/,
#     or/CC)
#   patenting/VBG
#   (Chink human/JJ embryos/NN ./.))
# (S
#   (Chink Human/NNP life/NN)
#   is/VBZ
#   a/DT
#   (Chink gift/NN)
#   from/IN
#   (Chink our/PRP$ Creator/NNP --/: and/CC)
#   that/IN
#   (Chink gift/NN should/MD never/RB)
#   be/VB
#   discarded/VBN
#   (Chink ,/,)
#   devalued/VBD
#   (Chink or/CC)
#   put/VB
#   (Chink up/RP)
#   for/IN
#   (Chink sale/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   A/DT
#   (Chink hopeful/JJ society/NN)
#   expects/VBZ
#   elected/VBN
#   (Chink officials/NNS)
#   to/TO
#   uphold/VB
#   the/DT
#   (Chink public/JJ trust/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Honorable/JJ people/NNS)
#   in/IN
#   both/DT
#   (Chink parties/NNS)
#   are/VBP
#   working/VBG
#   on/IN
#   (Chink reforms/NNS)
#   to/TO
#   strengthen/VB
#   the/DT
#   (Chink ethical/JJ standards/NNS)
#   of/IN
#   (Chink Washington/NNP --/: I/PRP)
#   support/VBP
#   (Chink your/PRP$ efforts/NNS ./.))
# (S
#   Each/DT
#   of/IN
#   (Chink us/PRP)
#   has/VBZ
#   made/VBN
#   a/DT
#   (Chink pledge/NN)
#   to/TO
#   be/VB
#   (Chink worthy/JJ)
#   of/IN
#   (Chink public/JJ responsibility/NN --/: and/CC)
#   that/DT
#   is/VBZ
#   a/DT
#   (Chink pledge/NN we/PRP must/MD never/RB)
#   forget/VB
#   (Chink ,/, never/RB dismiss/NN ,/, and/CC never/RB betray/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   As/IN
#   (Chink we/PRP)
#   renew/VBP
#   the/DT
#   (Chink promise/NN)
#   of/IN
#   (Chink our/PRP$ institutions/NNS ,/,)
#   let/VB
#   (Chink us/PRP also/RB)
#   show/VBP
#   the/DT
#   (Chink character/NN)
#   of/IN
#   (Chink America/NNP)
#   in/IN
#   (Chink our/PRP$ compassion/NN and/CC care/NN)
#   for/IN
#   (Chink one/CD)
#   another/DT
#   (Chink ./.))
# (S
#   A/DT
#   (Chink hopeful/JJ society/NN)
#   gives/VBZ
#   (Chink special/JJ attention/NN)
#   to/TO
#   (Chink children/NNS who/WP)
#   lack/VBP
#   (Chink direction/NN and/CC love/NN ./.))
# (S
#   Through/IN
#   the/DT
#   (Chink
#     Helping/NNP
#     America/NNP
#     's/POS
#     Youth/NNP
#     Initiative/NNP
#     ,/,
#     we/PRP)
#   are/VBP
#   encouraging/VBG
#   caring/VBG
#   (Chink adults/NNS)
#   to/TO
#   get/VB
#   involved/VBN
#   in/IN
#   the/DT
#   (Chink life/NN)
#   of/IN
#   a/DT
#   (Chink child/NN --/: and/CC)
#   this/DT
#   (Chink good/JJ work/NN)
#   is/VBZ
#   being/VBG
#   led/VBN
#   by/IN
#   (Chink our/PRP$ First/NNP Lady/NNP ,/, Laura/NNP Bush/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   This/DT
#   (Chink year/NN we/PRP will/MD)
#   add/VB
#   (Chink resources/NNS)
#   to/TO
#   encourage/VB
#   (Chink young/JJ people/NNS)
#   to/TO
#   stay/VB
#   in/IN
#   (Chink school/NN ,/, so/RB more/JJR)
#   of/IN
#   (Chink America/NNP 's/POS youth/NN can/MD)
#   raise/VB
#   (Chink their/PRP$ sights/NNS and/CC)
#   achieve/VBP
#   (Chink their/PRP$ dreams/NNS ./.))
# (S
#   A/DT
#   (Chink hopeful/JJ society/NN)
#   comes/VBZ
#   to/TO
#   the/DT
#   (Chink aid/NN)
#   of/IN
#   (Chink fellow/JJ citizens/NNS)
#   in/IN
#   (Chink times/NNS)
#   of/IN
#   (Chink suffering/NN and/CC emergency/NN --/: and/CC stays/NNS)
#   at/IN
#   (Chink it/PRP)
#   until/IN
#   (Chink they/PRP)
#   're/VBP
#   (Chink back/RB)
#   on/IN
#   (Chink their/PRP$ feet/NNS ./.))
# (S
#   (Chink So/RB far/RB)
#   the/DT
#   (Chink federal/JJ government/NN)
#   has/VBZ
#   committed/VBN
#   (Chink $/$ 85/CD billion/CD)
#   to/TO
#   the/DT
#   (Chink people/NNS)
#   of/IN
#   the/DT
#   (Chink Gulf/NNP Coast/NNP and/CC New/NNP Orleans/NNP ./.))
# (S
#   (Chink We/PRP)
#   're/VBP
#   removing/VBG
#   (Chink debris/NN and/CC repairing/NN highways/NNS and/CC)
#   rebuilding/VBG
#   (Chink stronger/JJR levees/NNS ./.))
# (S
#   (Chink We/PRP)
#   're/VBP
#   providing/VBG
#   (Chink business/NN loans/NNS and/CC housing/NN assistance/NN ./.))
# (S
#   (Chink Yet/RB)
#   as/IN
#   (Chink we/PRP)
#   meet/VBP
#   these/DT
#   (Chink immediate/JJ needs/NNS ,/, we/PRP must/MD also/RB)
#   address/VB
#   (Chink deeper/JJR challenges/NNS that/WDT)
#   existed/VBD
#   before/IN
#   the/DT
#   (Chink storm/NN)
#   arrived/VBD
#   (Chink ./.))
# (S
#   In/IN
#   (Chink New/NNP Orleans/NNP and/CC)
#   in/IN
#   (Chink other/JJ places/NNS ,/, many/JJ)
#   of/IN
#   (Chink our/PRP$ fellow/JJ citizens/NNS)
#   have/VBP
#   felt/VBN
#   excluded/VBN
#   from/IN
#   the/DT
#   (Chink promise/NN)
#   of/IN
#   (Chink our/PRP$ country/NN ./.))
# (S
#   The/DT
#   (Chink answer/NN)
#   is/VBZ
#   (Chink
#     not/RB
#     only/RB
#     temporary/JJ
#     relief/NN
#     ,/,
#     but/CC
#     schools/NNS
#     that/WDT)
#   teach/VBP
#   every/DT
#   (Chink child/NN ,/, and/CC job/NN skills/NNS)
#   that/IN
#   bring/VBG
#   (Chink upward/JJ mobility/NN ,/, and/CC more/JJR opportunities/NNS)
#   to/TO
#   own/VB
#   a/DT
#   (Chink home/NN and/CC)
#   start/VB
#   a/DT
#   (Chink business/NN ./.))
# (S
#   As/IN
#   (Chink we/PRP)
#   recover/VBP
#   from/IN
#   a/DT
#   (Chink disaster/NN ,/,)
#   let/VB
#   (Chink us/PRP also/RB work/NN)
#   for/IN
#   the/DT
#   (Chink day/NN when/WRB)
#   all/DT
#   (Chink Americans/NNPS)
#   are/VBP
#   protected/VBN
#   by/IN
#   (Chink justice/NN ,/, equal/JJ)
#   in/IN
#   (Chink hope/NN ,/, and/CC rich/JJ)
#   in/IN
#   (Chink opportunity/NN ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   A/DT
#   (Chink hopeful/JJ society/NN acts/NNS boldly/RB)
#   to/TO
#   fight/VB
#   (Chink diseases/NNS)
#   like/IN
#   (Chink HIV/AIDS/NNP ,/, which/WDT can/MD)
#   be/VB
#   prevented/VBN
#   (Chink ,/, and/CC)
#   treated/VBD
#   (Chink ,/, and/CC)
#   defeated/VBD
#   (Chink ./.))
# (S
#   (Chink More/JJR)
#   than/IN
#   a/DT
#   (Chink million/CD Americans/NNPS)
#   live/VBP
#   with/IN
#   (Chink HIV/NNP ,/, and/CC half/NN)
#   of/IN
#   all/DT
#   (Chink AIDS/NNP cases/NNS)
#   occur/VBP
#   among/IN
#   (Chink African/JJ Americans/NNPS ./.))
# (S
#   (Chink I/PRP)
#   ask/VBP
#   (Chink Congress/NNP)
#   to/TO
#   reform/VB
#   (Chink and/CC)
#   reauthorize/VB
#   the/DT
#   (Chink Ryan/NNP White/NNP Act/NNP ,/, and/CC)
#   provide/VB
#   (Chink new/JJ funding/NN)
#   to/TO
#   (Chink states/NNS ,/,)
#   so/IN
#   (Chink we/PRP)
#   end/VBP
#   the/DT
#   (Chink waiting/NN lists/NNS)
#   for/IN
#   (Chink AIDS/NNP medicines/NNS)
#   in/IN
#   (Chink America/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink We/PRP will/MD also/RB)
#   lead/VB
#   a/DT
#   (Chink nationwide/JJ effort/NN ,/,)
#   working/VBG
#   (Chink closely/RB)
#   with/IN
#   (Chink
#     African/JJ
#     American/JJ
#     churches/NNS
#     and/CC
#     faith-based/JJ
#     groups/NNS
#     ,/,)
#   to/TO
#   deliver/VB
#   (Chink rapid/JJ HIV/NNP tests/NNS)
#   to/TO
#   (Chink millions/NNS ,/,)
#   end/VBP
#   the/DT
#   (Chink stigma/NN)
#   of/IN
#   (Chink AIDS/NNP ,/, and/CC)
#   come/VB
#   (Chink closer/JJR)
#   to/TO
#   the/DT
#   (Chink day/NN when/WRB there/EX)
#   are/VBP
#   no/DT
#   (Chink new/JJ infections/NNS)
#   in/IN
#   (Chink America/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))
# (S
#   (Chink Fellow/NNP citizens/NNS ,/, we/PRP)
#   've/VBP
#   been/VBN
#   called/VBN
#   to/TO
#   (Chink leadership/NN)
#   in/IN
#   a/DT
#   (Chink period/NN)
#   of/IN
#   (Chink consequence/NN ./.))
# (S
#   (Chink We/PRP)
#   've/VBP
#   entered/VBN
#   a/DT
#   (Chink great/JJ ideological/JJ conflict/NN we/PRP)
#   did/VBD
#   (Chink nothing/NN)
#   to/TO
#   invite/VB
#   (Chink ./.))
# (S
#   (Chink We/PRP)
#   see/VBP
#   (Chink great/JJ changes/NNS)
#   in/IN
#   (Chink science/NN and/CC commerce/NN that/WDT will/MD)
#   influence/VB
#   all/DT
#   (Chink our/PRP$ lives/NNS ./.))
# (S
#   (Chink Sometimes/RB it/PRP can/MD)
#   seem/VB
#   that/DT
#   (Chink history/NN)
#   is/VBZ
#   turning/VBG
#   in/IN
#   a/DT
#   (Chink wide/JJ arc/NN ,/,)
#   toward/IN
#   an/DT
#   (Chink unknown/JJ shore/NN ./.))
# (S
#   (Chink Yet/CC)
#   the/DT
#   (Chink destination/NN)
#   of/IN
#   (Chink history/NN)
#   is/VBZ
#   determined/VBN
#   by/IN
#   (Chink human/JJ action/NN ,/, and/CC)
#   every/DT
#   (Chink great/JJ movement/NN)
#   of/IN
#   (Chink history/NN)
#   comes/VBZ
#   to/TO
#   a/DT
#   (Chink point/NN)
#   of/IN
#   (Chink choosing/NN ./.))
# (S
#   (Chink Lincoln/NNP could/MD)
#   have/VB
#   accepted/VBN
#   (Chink peace/NN)
#   at/IN
#   the/DT
#   (Chink cost/NN)
#   of/IN
#   (Chink disunity/NN and/CC continued/JJ slavery/NN ./.))
# (S
#   (Chink Martin/NNP Luther/NNP King/NNP could/MD)
#   have/VB
#   stopped/VBN
#   at/IN
#   (Chink Birmingham/NNP or/CC)
#   at/IN
#   (Chink Selma/NNP ,/, and/CC)
#   achieved/VBD
#   (Chink only/RB half/PDT)
#   a/DT
#   (Chink victory/NN)
#   over/IN
#   (Chink segregation/NN ./.))
# (S
#   The/DT
#   (Chink United/NNP States/NNPS could/MD)
#   have/VB
#   accepted/VBN
#   the/DT
#   (Chink permanent/JJ division/NN)
#   of/IN
#   (Chink Europe/NNP ,/, and/CC)
#   been/VBN
#   (Chink complicit/NNS)
#   in/IN
#   the/DT
#   (Chink oppression/NN)
#   of/IN
#   (Chink others/NNS ./.))
# (S
#   (Chink Today/NN ,/,)
#   having/VBG
#   come/VBN
#   (Chink far/RB)
#   in/IN
#   (Chink our/PRP$ own/JJ historical/JJ journey/NN ,/, we/PRP must/MD)
#   decide/VB
#   (Chink :/: Will/MD we/PRP)
#   turn/VB
#   (Chink back/RP ,/, or/CC)
#   finish/VB
#   (Chink well/RB ?/.))
# (S
#   Before/IN
#   (Chink history/NN)
#   is/VBZ
#   written/VBN
#   (Chink down/RP)
#   in/IN
#   (Chink books/NNS ,/, it/PRP)
#   is/VBZ
#   written/VBN
#   in/IN
#   (Chink courage/NN ./.))
# (S
#   Like/IN
#   (Chink Americans/NNPS)
#   before/IN
#   (Chink us/PRP ,/, we/PRP will/MD)
#   show/VB
#   that/DT
#   (Chink courage/NN and/CC we/PRP will/MD)
#   finish/VB
#   (Chink well/RB ./.))
# (S
#   (Chink We/PRP will/MD)
#   lead/VB
#   (Chink freedom/NN 's/POS advance/NN ./.))
# (S
#   (Chink We/PRP will/MD)
#   compete/VB
#   (Chink and/CC)
#   excel/VB
#   in/IN
#   the/DT
#   (Chink global/JJ economy/NN ./.))
# (S
#   (Chink We/PRP will/MD)
#   renew/VB
#   the/DT
#   defining/VBG
#   (Chink moral/JJ commitments/NNS)
#   of/IN
#   this/DT
#   (Chink land/NN ./.))
# (S
#   (Chink And/CC so/RB we/PRP)
#   move/VBP
#   (Chink forward/RB --/: optimistic/JJ)
#   about/IN
#   (Chink our/PRP$ country/NN ,/, faithful/JJ)
#   to/TO
#   (Chink its/PRP$ cause/NN ,/, and/CC confident/NN)
#   of/IN
#   the/DT
#   (Chink victories/NNS)
#   to/TO
#   come/VB
#   (Chink ./.))
# (S (Chink May/NNP God/NNP bless/NN America/NNP ./.))
# (S (Chink (/( Applause/NNP ./. )/)))

# %% [markdown]
# ## ---------------------------------------------

# %% [markdown]
# ## 7. Named Entity Recognition :

# %%
NER is a subtask to extract information that seeks to locate and classify named entity 
mentions in unstructured text into pre-defined categories such as the names, organizations, locations, values etc.                                       
      
NER:                                                                                                                       
person name, company name, organisation name, location name, entity name, monetary value name called NER.

a.Non-phase identification : 
deals with the extracting all noun phrases from text using dependency passing and POS tagging.

b.Phrase calssification : 
all extarcted noun phrases are classified into respective categories (location, name, org. etc.)   

c.Entity disambiguation : 
sometimes its possible the entities are mis-classified, hence creating a validation layer 
on top of result is useful and use of knowledge graphs can be exploited for this purpose         
(Popular knowledge graphs are : Google Knowledge graph, IBM watson , wikipedia)

# %%
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer       # PunktSentenceTokenizer : is Unsupervise ML tokenizer  

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_token = PunktSentenceTokenizer(train_text)
tokenized = custom_token.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            namedEnt = nltk.ne_chunk(tagged, binary = True)
            print(namedEnt)
            # namedEnt.draw()
            
    except Exception as e:
        print(str(e))
        
process_content()
# Out:
# (S
#   PRESIDENT/NNP
#   (NE GEORGE/NNP)
#   W./NNP
#   BUSH/NNP
#   'S/POS
#   (NE ADDRESS/NNP)
#   BEFORE/IN
#   A/NNP
#   JOINT/NNP
#   SESSION/NNP
#   OF/IN
#   (NE THE/NNP)
#   (NE CONGRESS/NNP)
#   ON/NNP
#   THE/NNP
#   STATE/NNP
#   OF/IN
#   (NE THE/NNP UNION/NNP)
#   January/NNP
#   31/CD
#   ,/,
#   2006/CD
#   THE/NNP
#   PRESIDENT/NNP
#   :/:
#   Thank/NNP
#   you/PRP
#   all/DT
#   ./.)
# (S
#   (NE Mr./NNP Speaker/NNP)
#   ,/,
#   Vice/NNP
#   President/NNP
#   (NE Cheney/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   (NE Congress/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   the/DT
#   (NE Supreme/NNP Court/NNP)
#   and/CC
#   diplomatic/JJ
#   corps/NN
#   ,/,
#   distinguished/JJ
#   guests/NNS
#   ,/,
#   and/CC
#   fellow/JJ
#   citizens/NNS
#   :/:
#   Today/VB
#   our/PRP$
#   nation/NN
#   lost/VBD
#   a/DT
#   beloved/VBN
#   ,/,
#   graceful/JJ
#   ,/,
#   courageous/JJ
#   woman/NN
#   who/WP
#   called/VBD
#   (NE America/NNP)
#   to/TO
#   its/PRP$
#   founding/NN
#   ideals/NNS
#   and/CC
#   carried/VBD
#   on/IN
#   a/DT
#   noble/JJ
#   dream/NN
#   ./.)
# (S
#   Tonight/NN
#   we/PRP
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   hope/NN
#   of/IN
#   a/DT
#   glad/JJ
#   reunion/NN
#   with/IN
#   the/DT
#   husband/NN
#   who/WP
#   was/VBD
#   taken/VBN
#   so/RB
#   long/RB
#   ago/RB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   grateful/JJ
#   for/IN
#   the/DT
#   good/JJ
#   life/NN
#   of/IN
#   (NE Coretta/NNP Scott/NNP King/NNP)
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   President/NNP
#   (NE George/NNP)
#   W./NNP
#   Bush/NNP
#   reacts/VBZ
#   to/TO
#   applause/VB
#   during/IN
#   his/PRP$
#   State/NNP
#   of/IN
#   the/DT
#   (NE Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (NE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (NE Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (NE White/NNP House/NNP)
#   photo/NN
#   by/IN
#   (NE Eric/NNP)
#   DraperEvery/NNP
#   time/NN
#   I/PRP
#   'm/VBP
#   invited/JJ
#   to/TO
#   this/DT
#   rostrum/NN
#   ,/,
#   I/PRP
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   privilege/NN
#   ,/,
#   and/CC
#   mindful/NN
#   of/IN
#   the/DT
#   history/NN
#   we/PRP
#   've/VBP
#   seen/VBN
#   together/RB
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   Capitol/NNP
#   dome/NN
#   in/IN
#   moments/NNS
#   of/IN
#   national/JJ
#   mourning/NN
#   and/CC
#   national/JJ
#   achievement/NN
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   served/VBN
#   (NE America/NNP)
#   through/IN
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   consequential/JJ
#   periods/NNS
#   of/IN
#   our/PRP$
#   history/NN
#   --/:
#   and/CC
#   it/PRP
#   has/VBZ
#   been/VBN
#   my/PRP$
#   honor/NN
#   to/TO
#   serve/VB
#   with/IN
#   you/PRP
#   ./.)
# (S
#   In/IN
#   a/DT
#   system/NN
#   of/IN
#   two/CD
#   parties/NNS
#   ,/,
#   two/CD
#   chambers/NNS
#   ,/,
#   and/CC
#   two/CD
#   elected/JJ
#   branches/NNS
#   ,/,
#   there/EX
#   will/MD
#   always/RB
#   be/VB
#   differences/NNS
#   and/CC
#   debate/NN
#   ./.)
# (S
#   But/CC
#   even/RB
#   tough/JJ
#   debates/NNS
#   can/MD
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   civil/JJ
#   tone/NN
#   ,/,
#   and/CC
#   our/PRP$
#   differences/NNS
#   can/MD
#   not/RB
#   be/VB
#   allowed/VBN
#   to/TO
#   harden/VB
#   into/IN
#   anger/NN
#   ./.)
# (S
#   To/TO
#   confront/VB
#   the/DT
#   great/JJ
#   issues/NNS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   must/MD
#   act/VB
#   in/IN
#   a/DT
#   spirit/NN
#   of/IN
#   goodwill/NN
#   and/CC
#   respect/NN
#   for/IN
#   one/CD
#   another/DT
#   --/:
#   and/CC
#   I/PRP
#   will/MD
#   do/VB
#   my/PRP$
#   part/NN
#   ./.)
# (S
#   Tonight/NNP
#   the/DT
#   state/NN
#   of/IN
#   our/PRP$
#   Union/NNP
#   is/VBZ
#   strong/JJ
#   --/:
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   make/VB
#   it/PRP
#   stronger/JJR
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   In/IN
#   this/DT
#   decisive/JJ
#   year/NN
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   will/MD
#   make/VB
#   choices/NNS
#   that/WDT
#   determine/VBP
#   both/DT
#   the/DT
#   future/NN
#   and/CC
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   act/VB
#   confidently/RB
#   in/IN
#   pursuing/VBG
#   the/DT
#   enemies/NNS
#   of/IN
#   freedom/NN
#   --/:
#   or/CC
#   retreat/NN
#   from/IN
#   our/PRP$
#   duties/NNS
#   in/IN
#   the/DT
#   hope/NN
#   of/IN
#   an/DT
#   easier/JJR
#   life/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   build/VB
#   our/PRP$
#   prosperity/NN
#   by/IN
#   leading/VBG
#   the/DT
#   world/NN
#   economy/NN
#   --/:
#   or/CC
#   shut/VB
#   ourselves/PRP
#   off/RP
#   from/IN
#   trade/NN
#   and/CC
#   opportunity/NN
#   ./.)
# (S
#   In/IN
#   a/DT
#   complex/JJ
#   and/CC
#   challenging/JJ
#   time/NN
#   ,/,
#   the/DT
#   road/NN
#   of/IN
#   isolationism/NN
#   and/CC
#   protectionism/NN
#   may/MD
#   seem/VB
#   broad/JJ
#   and/CC
#   inviting/NN
#   --/:
#   yet/CC
#   it/PRP
#   ends/VBZ
#   in/IN
#   danger/NN
#   and/CC
#   decline/NN
#   ./.)
# (S
#   The/DT
#   only/JJ
#   way/NN
#   to/TO
#   protect/VB
#   our/PRP$
#   people/NNS
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   secure/VB
#   the/DT
#   peace/NN
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   control/VB
#   our/PRP$
#   destiny/NN
#   is/VBZ
#   by/IN
#   our/PRP$
#   leadership/NN
#   --/:
#   so/IN
#   the/DT
#   (NE United/NNP States/NNPS)
#   of/IN
#   (NE America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   lead/VB
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Abroad/RB
#   ,/,
#   our/PRP$
#   nation/NN
#   is/VBZ
#   committed/VBN
#   to/TO
#   an/DT
#   historic/JJ
#   ,/,
#   long-term/JJ
#   goal/NN
#   --/:
#   we/PRP
#   seek/VBP
#   the/DT
#   end/NN
#   of/IN
#   tyranny/NN
#   in/IN
#   our/PRP$
#   world/NN
#   ./.)
# (S
#   Some/DT
#   dismiss/VBP
#   that/DT
#   goal/NN
#   as/IN
#   misguided/JJ
#   idealism/NN
#   ./.)
# (S
#   In/IN
#   reality/NN
#   ,/,
#   the/DT
#   future/JJ
#   security/NN
#   of/IN
#   (NE America/NNP)
#   depends/VBZ
#   on/IN
#   it/PRP
#   ./.)
# (S
#   On/IN
#   September/NNP
#   the/DT
#   11th/CD
#   ,/,
#   2001/CD
#   ,/,
#   we/PRP
#   found/VBD
#   that/IN
#   problems/NNS
#   originating/VBG
#   in/IN
#   a/DT
#   failed/JJ
#   and/CC
#   oppressive/JJ
#   state/NN
#   7,000/CD
#   miles/NNS
#   away/RB
#   could/MD
#   bring/VB
#   murder/NN
#   and/CC
#   destruction/NN
#   to/TO
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   (NE Dictatorships/NNP)
#   shelter/NN
#   terrorists/NNS
#   ,/,
#   and/CC
#   feed/VB
#   resentment/NN
#   and/CC
#   radicalism/NN
#   ,/,
#   and/CC
#   seek/JJ
#   weapons/NNS
#   of/IN
#   mass/NN
#   destruction/NN
#   ./.)
# (S
#   Democracies/NNS
#   replace/VB
#   resentment/NN
#   with/IN
#   hope/NN
#   ,/,
#   respect/VB
#   the/DT
#   rights/NNS
#   of/IN
#   their/PRP$
#   citizens/NNS
#   and/CC
#   their/PRP$
#   neighbors/NNS
#   ,/,
#   and/CC
#   join/VB
#   the/DT
#   fight/NN
#   against/IN
#   terror/NN
#   ./.)
# (S
#   Every/DT
#   step/NN
#   toward/IN
#   freedom/NN
#   in/IN
#   the/DT
#   world/NN
#   makes/VBZ
#   our/PRP$
#   country/NN
#   safer/NN
#   --/:
#   so/IN
#   we/PRP
#   will/MD
#   act/VB
#   boldly/RB
#   in/IN
#   freedom/NN
#   's/POS
#   cause/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Far/RB
#   from/IN
#   being/VBG
#   a/DT
#   hopeless/NN
#   dream/NN
#   ,/,
#   the/DT
#   advance/NN
#   of/IN
#   freedom/NN
#   is/VBZ
#   the/DT
#   great/JJ
#   story/NN
#   of/IN
#   our/PRP$
#   time/NN
#   ./.)
# (S
#   In/IN
#   1945/CD
#   ,/,
#   there/EX
#   were/VBD
#   about/RB
#   two/CD
#   dozen/NN
#   lonely/RB
#   democracies/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S Today/NN ,/, there/EX are/VBP 122/CD ./.)
# (S
#   And/CC
#   we/PRP
#   're/VBP
#   writing/VBG
#   a/DT
#   new/JJ
#   chapter/NN
#   in/IN
#   the/DT
#   story/NN
#   of/IN
#   self-government/JJ
#   --/:
#   with/IN
#   women/NNS
#   lining/VBG
#   up/RP
#   to/TO
#   vote/VB
#   in/IN
#   (NE Afghanistan/NNP)
#   ,/,
#   and/CC
#   millions/NNS
#   of/IN
#   (NE Iraqis/NNP)
#   marking/VBG
#   their/PRP$
#   liberty/NN
#   with/IN
#   purple/JJ
#   ink/NN
#   ,/,
#   and/CC
#   men/NNS
#   and/CC
#   women/NNS
#   from/IN
#   (NE Lebanon/NNP)
#   to/TO
#   (NE Egypt/NNP)
#   debating/VBG
#   the/DT
#   rights/NNS
#   of/IN
#   individuals/NNS
#   and/CC
#   the/DT
#   necessity/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   At/IN
#   the/DT
#   start/NN
#   of/IN
#   2006/CD
#   ,/,
#   more/JJR
#   than/IN
#   half/PDT
#   the/DT
#   people/NNS
#   of/IN
#   our/PRP$
#   world/NN
#   live/VBP
#   in/IN
#   democratic/JJ
#   nations/NNS
#   ./.)
# (S
#   And/CC
#   we/PRP
#   do/VBP
#   not/RB
#   forget/VB
#   the/DT
#   other/JJ
#   half/NN
#   --/:
#   in/IN
#   places/NNS
#   like/IN
#   (NE Syria/NNP)
#   and/CC
#   (NE Burma/NNP)
#   ,/,
#   (NE Zimbabwe/NNP)
#   ,/,
#   (NE North/NNP Korea/NNP)
#   ,/,
#   and/CC
#   (NE Iran/NNP)
#   --/:
#   because/IN
#   the/DT
#   demands/NNS
#   of/IN
#   justice/NN
#   ,/,
#   and/CC
#   the/DT
#   peace/NN
#   of/IN
#   this/DT
#   world/NN
#   ,/,
#   require/VBP
#   their/PRP$
#   freedom/NN
#   ,/,
#   as/RB
#   well/RB
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   President/NNP
#   (NE George/NNP)
#   W./NNP
#   Bush/NNP
#   delivers/VBZ
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (NE Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (NE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (NE Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (NE White/NNP House/NNP)
#   photo/NN
#   by/IN
#   (NE Eric/NNP Draper/NNP No/NNP)
#   one/NN
#   can/MD
#   deny/VB
#   the/DT
#   success/NN
#   of/IN
#   freedom/NN
#   ,/,
#   but/CC
#   some/DT
#   men/NNS
#   rage/VB
#   and/CC
#   fight/VB
#   against/IN
#   it/PRP
#   ./.)
# (S
#   And/CC
#   one/CD
#   of/IN
#   the/DT
#   main/JJ
#   sources/NNS
#   of/IN
#   reaction/NN
#   and/CC
#   opposition/NN
#   is/VBZ
#   radical/JJ
#   Islam/NNP
#   --/:
#   the/DT
#   perversion/NN
#   by/IN
#   a/DT
#   few/JJ
#   of/IN
#   a/DT
#   noble/JJ
#   faith/NN
#   into/IN
#   an/DT
#   ideology/NN
#   of/IN
#   terror/NN
#   and/CC
#   death/NN
#   ./.)
# (S
#   Terrorists/NNS
#   like/IN
#   bin/NN
#   Laden/NNP
#   are/VBP
#   serious/JJ
#   about/IN
#   mass/NN
#   murder/NN
#   --/:
#   and/CC
#   all/DT
#   of/IN
#   us/PRP
#   must/MD
#   take/VB
#   their/PRP$
#   declared/JJ
#   intentions/NNS
#   seriously/RB
#   ./.)
# (S
#   They/PRP
#   seek/VBP
#   to/TO
#   impose/VB
#   a/DT
#   heartless/NN
#   system/NN
#   of/IN
#   totalitarian/JJ
#   control/NN
#   throughout/IN
#   the/DT
#   (NE Middle/NNP East/NNP)
#   ,/,
#   and/CC
#   arm/NN
#   themselves/PRP
#   with/IN
#   weapons/NNS
#   of/IN
#   mass/NN
#   murder/NN
#   ./.)
# (S
#   Their/PRP$
#   aim/NN
#   is/VBZ
#   to/TO
#   seize/VB
#   power/NN
#   in/IN
#   (NE Iraq/NNP)
#   ,/,
#   and/CC
#   use/VB
#   it/PRP
#   as/IN
#   a/DT
#   safe/JJ
#   haven/NN
#   to/TO
#   launch/VB
#   attacks/NNS
#   against/IN
#   (NE America/NNP)
#   and/CC
#   the/DT
#   world/NN
#   ./.)
# (S
#   Lacking/VBG
#   the/DT
#   military/JJ
#   strength/NN
#   to/TO
#   challenge/VB
#   us/PRP
#   directly/RB
#   ,/,
#   the/DT
#   terrorists/NNS
#   have/VBP
#   chosen/VBN
#   the/DT
#   weapon/NN
#   of/IN
#   fear/NN
#   ./.)
# (S
#   When/WRB
#   they/PRP
#   murder/VBP
#   children/NNS
#   at/IN
#   a/DT
#   school/NN
#   in/IN
#   (NE Beslan/NNP)
#   ,/,
#   or/CC
#   blow/VB
#   up/RP
#   commuters/NNS
#   in/IN
#   (NE London/NNP)
#   ,/,
#   or/CC
#   behead/VB
#   a/DT
#   bound/NN
#   captive/NN
#   ,/,
#   the/DT
#   terrorists/NNS
#   hope/VBP
#   these/DT
#   horrors/NNS
#   will/MD
#   break/VB
#   our/PRP$
#   will/MD
#   ,/,
#   allowing/VBG
#   the/DT
#   violent/NN
#   to/TO
#   inherit/VB
#   the/DT
#   (NE Earth/NNP)
#   ./.)
# (S
#   But/CC
#   they/PRP
#   have/VBP
#   miscalculated/VBN
#   :/:
#   We/PRP
#   love/VBP
#   our/PRP$
#   freedom/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   fight/VB
#   to/TO
#   keep/VB
#   it/PRP
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   In/IN
#   a/DT
#   time/NN
#   of/IN
#   testing/VBG
#   ,/,
#   we/PRP
#   can/MD
#   not/RB
#   find/VB
#   security/NN
#   by/IN
#   abandoning/VBG
#   our/PRP$
#   commitments/NNS
#   and/CC
#   retreating/VBG
#   within/IN
#   our/PRP$
#   borders/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   were/VBD
#   to/TO
#   leave/VB
#   these/DT
#   vicious/JJ
#   attackers/NNS
#   alone/RB
#   ,/,
#   they/PRP
#   would/MD
#   not/RB
#   leave/VB
#   us/PRP
#   alone/RB
#   ./.)
# (S
#   They/PRP
#   would/MD
#   simply/RB
#   move/VB
#   the/DT
#   battlefield/NN
#   to/TO
#   our/PRP$
#   own/JJ
#   shores/NNS
#   ./.)
# (S There/EX is/VBZ no/DT peace/NN in/IN retreat/NN ./.)
# (S And/CC there/EX is/VBZ no/DT honor/NN in/IN retreat/NN ./.)
# (S
#   By/IN
#   allowing/VBG
#   radical/JJ
#   Islam/NNP
#   to/TO
#   work/VB
#   its/PRP$
#   will/MD
#   --/:
#   by/IN
#   leaving/VBG
#   an/DT
#   assaulted/JJ
#   world/NN
#   to/TO
#   fend/VB
#   for/IN
#   itself/PRP
#   --/:
#   we/PRP
#   would/MD
#   signal/VB
#   to/TO
#   all/PDT
#   that/IN
#   we/PRP
#   no/DT
#   longer/RBR
#   believe/VBP
#   in/IN
#   our/PRP$
#   own/JJ
#   ideals/NNS
#   ,/,
#   or/CC
#   even/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   courage/NN
#   ./.)
# (S
#   But/CC
#   our/PRP$
#   enemies/NNS
#   and/CC
#   our/PRP$
#   friends/NNS
#   can/MD
#   be/VB
#   certain/JJ
#   :/:
#   The/DT
#   (NE United/NNP States/NNPS)
#   will/MD
#   not/RB
#   retreat/VB
#   from/IN
#   the/DT
#   world/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   never/RB
#   surrender/VB
#   to/TO
#   evil/VB
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   (NE America/NNP)
#   rejects/VBZ
#   the/DT
#   false/JJ
#   comfort/NN
#   of/IN
#   isolationism/NN
#   ./.)
# (S
#   We/PRP
#   are/VBP
#   the/DT
#   nation/NN
#   that/IN
#   saved/VBD
#   liberty/NN
#   in/IN
#   (NE Europe/NNP)
#   ,/,
#   and/CC
#   liberated/VBD
#   death/NN
#   camps/NNS
#   ,/,
#   and/CC
#   helped/VBD
#   raise/VB
#   up/RP
#   democracies/NNS
#   ,/,
#   and/CC
#   faced/VBD
#   down/IN
#   an/DT
#   evil/JJ
#   empire/NN
#   ./.)
# (S
#   Once/RB
#   again/RB
#   ,/,
#   we/PRP
#   accept/VBP
#   the/DT
#   call/NN
#   of/IN
#   history/NN
#   to/TO
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   and/CC
#   move/VB
#   this/DT
#   world/NN
#   toward/IN
#   peace/NN
#   ./.)
# (S
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terror/NN
#   networks/NNS
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   killed/VBN
#   or/CC
#   captured/VBN
#   many/JJ
#   of/IN
#   their/PRP$
#   leaders/NNS
#   --/:
#   and/CC
#   for/IN
#   the/DT
#   others/NNS
#   ,/,
#   their/PRP$
#   day/NN
#   will/MD
#   come/VB
#   ./.)
# (S
#   President/NNP
#   (NE George/NNP)
#   W./NNP
#   Bush/NNP
#   greets/VBZ
#   members/NNS
#   of/IN
#   (NE Congress/NNP)
#   after/IN
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (NE Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (NE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (NE Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (NE White/NNP House/NNP)
#   photo/NN
#   by/IN
#   (NE Eric/NNP Draper/NNP)
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (NE Afghanistan/NNP)
#   ,/,
#   where/WRB
#   a/DT
#   fine/JJ
#   President/NNP
#   and/CC
#   a/DT
#   (NE National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   terror/NN
#   while/IN
#   building/VBG
#   the/DT
#   institutions/NNS
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (NE Iraq/NNP)
#   ,/,
#   with/IN
#   a/DT
#   clear/JJ
#   plan/NN
#   for/IN
#   victory/NN
#   ./.)
# (S
#   First/RB
#   ,/,
#   we/PRP
#   're/VBP
#   helping/VBG
#   (NE Iraqis/NNP)
#   build/VB
#   an/DT
#   inclusive/JJ
#   government/NN
#   ,/,
#   so/IN
#   that/DT
#   old/JJ
#   resentments/NNS
#   will/MD
#   be/VB
#   eased/VBN
#   and/CC
#   the/DT
#   insurgency/NN
#   will/MD
#   be/VB
#   marginalized/VBN
#   ./.)
# (S
#   Second/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   continuing/VBG
#   reconstruction/NN
#   efforts/NNS
#   ,/,
#   and/CC
#   helping/VBG
#   the/DT
#   (NE Iraqi/NNP)
#   government/NN
#   to/TO
#   fight/VB
#   corruption/NN
#   and/CC
#   build/VB
#   a/DT
#   modern/JJ
#   economy/NN
#   ,/,
#   so/IN
#   all/DT
#   (NE Iraqis/NNP)
#   can/MD
#   experience/VB
#   the/DT
#   benefits/NNS
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   ,/,
#   third/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   striking/VBG
#   terrorist/JJ
#   targets/NNS
#   while/IN
#   we/PRP
#   train/VBP
#   (NE Iraqi/JJ)
#   forces/NNS
#   that/WDT
#   are/VBP
#   increasingly/RB
#   capable/JJ
#   of/IN
#   defeating/VBG
#   the/DT
#   enemy/NN
#   ./.)
# (S
#   (NE Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   their/PRP$
#   courage/NN
#   every/DT
#   day/NN
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   proud/JJ
#   to/TO
#   be/VB
#   their/PRP$
#   allies/NNS
#   in/IN
#   the/DT
#   cause/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   work/NN
#   in/IN
#   (NE Iraq/NNP)
#   is/VBZ
#   difficult/JJ
#   because/IN
#   our/PRP$
#   enemy/NN
#   is/VBZ
#   brutal/JJ
#   ./.)
# (S
#   But/CC
#   that/DT
#   brutality/NN
#   has/VBZ
#   not/RB
#   stopped/VBN
#   the/DT
#   dramatic/JJ
#   progress/NN
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   In/IN
#   less/JJR
#   than/IN
#   three/CD
#   years/NNS
#   ,/,
#   the/DT
#   nation/NN
#   has/VBZ
#   gone/VBN
#   from/IN
#   dictatorship/NN
#   to/TO
#   liberation/NN
#   ,/,
#   to/TO
#   sovereignty/VB
#   ,/,
#   to/TO
#   a/DT
#   constitution/NN
#   ,/,
#   to/TO
#   national/JJ
#   elections/NNS
#   ./.)
# (S
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   our/PRP$
#   coalition/NN
#   has/VBZ
#   been/VBN
#   relentless/VBN
#   in/IN
#   shutting/VBG
#   off/RP
#   terrorist/JJ
#   infiltration/NN
#   ,/,
#   clearing/VBG
#   out/RP
#   insurgent/JJ
#   strongholds/NNS
#   ,/,
#   and/CC
#   turning/VBG
#   over/RP
#   territory/NN
#   to/TO
#   (NE Iraqi/NNP)
#   security/NN
#   forces/NNS
#   ./.)
# (S
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   our/PRP$
#   plan/NN
#   for/IN
#   victory/NN
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   will/MD
#   of/IN
#   the/DT
#   (NE Iraqi/NNP)
#   people/NNS
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   skill/NN
#   and/CC
#   spirit/NN
#   of/IN
#   our/PRP$
#   military/JJ
#   ./.)
# (S
#   (NE Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   are/VBP
#   in/IN
#   this/DT
#   fight/NN
#   to/TO
#   win/VB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   winning/VBG
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   The/DT
#   road/NN
#   of/IN
#   victory/NN
#   is/VBZ
#   the/DT
#   road/NN
#   that/WDT
#   will/MD
#   take/VB
#   our/PRP$
#   troops/NNS
#   home/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   make/VBP
#   progress/NN
#   on/IN
#   the/DT
#   ground/NN
#   ,/,
#   and/CC
#   (NE Iraqi/NNP)
#   forces/NNS
#   increasingly/RB
#   take/VBP
#   the/DT
#   lead/NN
#   ,/,
#   we/PRP
#   should/MD
#   be/VB
#   able/JJ
#   to/TO
#   further/JJ
#   decrease/VB
#   our/PRP$
#   troop/NN
#   levels/NNS
#   --/:
#   but/CC
#   those/DT
#   decisions/NNS
#   will/MD
#   be/VB
#   made/VBN
#   by/IN
#   our/PRP$
#   military/JJ
#   commanders/NNS
#   ,/,
#   not/RB
#   by/IN
#   politicians/NNS
#   in/IN
#   (NE Washington/NNP)
#   ,/,
#   D.C/NNP
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   coalition/NN
#   has/VBZ
#   learned/VBN
#   from/IN
#   our/PRP$
#   experience/NN
#   in/IN
#   (NE Iraq/NNP)
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   adjusted/VBN
#   our/PRP$
#   military/JJ
#   tactics/NNS
#   and/CC
#   changed/VBD
#   our/PRP$
#   approach/NN
#   to/TO
#   reconstruction/NN
#   ./.)
# (S
#   Along/IN
#   the/DT
#   way/NN
#   ,/,
#   we/PRP
#   have/VBP
#   benefitted/VBN
#   from/IN
#   responsible/JJ
#   criticism/NN
#   and/CC
#   counsel/NN
#   offered/VBN
#   by/IN
#   members/NNS
#   of/IN
#   (NE Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   coming/VBG
#   year/NN
#   ,/,
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   reach/VB
#   out/RP
#   and/CC
#   seek/VB
#   your/PRP$
#   good/JJ
#   advice/NN
#   ./.)
# (S
#   Yet/RB
#   ,/,
#   there/EX
#   is/VBZ
#   a/DT
#   difference/NN
#   between/IN
#   responsible/JJ
#   criticism/NN
#   that/WDT
#   aims/VBZ
#   for/IN
#   success/NN
#   ,/,
#   and/CC
#   defeatism/NN
#   that/WDT
#   refuses/VBZ
#   to/TO
#   acknowledge/VB
#   anything/NN
#   but/CC
#   failure/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   (NE Hindsight/NNP)
#   alone/RB
#   is/VBZ
#   not/RB
#   wisdom/JJ
#   ,/,
#   and/CC
#   second-guessing/NN
#   is/VBZ
#   not/RB
#   a/DT
#   strategy/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   With/IN
#   so/RB
#   much/JJ
#   in/IN
#   the/DT
#   balance/NN
#   ,/,
#   those/DT
#   of/IN
#   us/PRP
#   in/IN
#   public/JJ
#   office/NN
#   have/VBP
#   a/DT
#   duty/NN
#   to/TO
#   speak/VB
#   with/IN
#   candor/NN
#   ./.)
# (S
#   A/DT
#   sudden/JJ
#   withdrawal/NN
#   of/IN
#   our/PRP$
#   forces/NNS
#   from/IN
#   (NE Iraq/NNP)
#   would/MD
#   abandon/VB
#   our/PRP$
#   (NE Iraqi/NNP)
#   allies/NNS
#   to/TO
#   death/NN
#   and/CC
#   prison/NN
#   ,/,
#   would/MD
#   put/VB
#   men/NNS
#   like/IN
#   bin/NN
#   (NE Laden/NNP)
#   and/CC
#   (NE Zarqawi/NNP)
#   in/IN
#   charge/NN
#   of/IN
#   a/DT
#   strategic/JJ
#   country/NN
#   ,/,
#   and/CC
#   show/VBP
#   that/IN
#   a/DT
#   pledge/NN
#   from/IN
#   (NE America/NNP)
#   means/VBZ
#   little/JJ
#   ./.)
# (S
#   Members/NNS
#   of/IN
#   (NE Congress/NNP)
#   ,/,
#   however/RB
#   we/PRP
#   feel/VBP
#   about/IN
#   the/DT
#   decisions/NNS
#   and/CC
#   debates/NNS
#   of/IN
#   the/DT
#   past/NN
#   ,/,
#   our/PRP$
#   nation/NN
#   has/VBZ
#   only/RB
#   one/CD
#   option/NN
#   :/:
#   We/PRP
#   must/MD
#   keep/VB
#   our/PRP$
#   word/NN
#   ,/,
#   defeat/VB
#   our/PRP$
#   enemies/NNS
#   ,/,
#   and/CC
#   stand/VBP
#   behind/IN
#   the/DT
#   (NE American/JJ)
#   military/NN
#   in/IN
#   this/DT
#   vital/JJ
#   mission/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   (NE Laura/NNP Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/IN
#   she/PRP
#   is/VBZ
#   introduced/VBN
#   Tuesday/NNP
#   evening/NN
#   ,/,
#   (NE Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   during/IN
#   the/DT
#   State/NNP
#   of/IN
#   the/DT
#   (NE Union/NNP Address/NNP)
#   at/IN
#   (NE United/NNP States/NNPS Capitol/NNP)
#   in/IN
#   (NE Washington/NNP)
#   ./.)
# (S
#   (NE White/NNP House/NNP)
#   photo/NN
#   by/IN
#   (NE Eric/NNP Draper/NNP)
#   Our/PRP$
#   men/NNS
#   and/CC
#   women/NNS
#   in/IN
#   uniform/JJ
#   are/VBP
#   making/VBG
#   sacrifices/NNS
#   --/:
#   and/CC
#   showing/VBG
#   a/DT
#   sense/NN
#   of/IN
#   duty/NN
#   stronger/JJR
#   than/IN
#   all/DT
#   fear/NN
#   ./.)
# (S
#   They/PRP
#   know/VBP
#   what/WP
#   it/PRP
#   's/VBZ
#   like/IN
#   to/TO
#   fight/VB
#   house/NN
#   to/TO
#   house/NN
#   in/IN
#   a/DT
#   maze/NN
#   of/IN
#   streets/NNS
#   ,/,
#   to/TO
#   wear/VB
#   heavy/JJ
#   gear/NN
#   in/IN
#   the/DT
#   desert/NN
#   heat/NN
#   ,/,
#   to/TO
#   see/VB
#   a/DT
#   comrade/NN
#   killed/VBN
#   by/IN
#   a/DT
#   roadside/NN
#   bomb/NN
#   ./.)
# (S
#   And/CC
#   those/DT
#   who/WP
#   know/VBP
#   the/DT
#   costs/NNS
#   also/RB
#   know/VBP
#   the/DT
#   stakes/NNS
#   ./.)
# (S
#   (NE Marine/JJ Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   was/VBD
#   killed/VBN
#   last/JJ
#   month/NN
#   fighting/VBG
#   in/IN
#   (NE Fallujah/NNP)
#   ./.)
# (S
#   He/PRP
#   left/VBD
#   behind/RP
#   a/DT
#   letter/NN
#   to/TO
#   his/PRP$
#   family/NN
#   ,/,
#   but/CC
#   his/PRP$
#   words/NNS
#   could/MD
#   just/RB
#   as/RB
#   well/RB
#   be/VB
#   addressed/VBN
#   to/TO
#   every/DT
#   (NE American/NNP)
#   ./.)
# (S
#   Here/RB
#   is/VBZ
#   what/WP
#   (NE Dan/NNP)
#   wrote/VBD
#   :/:
#   ``/``
#   I/PRP
#   know/VBP
#   what/WP
#   honor/NN
#   is/VBZ
#   ./.)
# (S
#   .../:
#   It/PRP
#   has/VBZ
#   been/VBN
#   an/DT
#   honor/NN
#   to/TO
#   protect/VB
#   and/CC
#   serve/VB
#   all/DT
#   of/IN
#   you/PRP
#   ./.)
# (S
#   I/PRP
#   faced/VBD
#   death/NN
#   with/IN
#   the/DT
#   secure/NN
#   knowledge/NN
#   that/IN
#   you/PRP
#   would/MD
#   not/RB
#   have/VB
#   to/TO
#   .../:
#   ./.)
# (S Never/RB falter/NN !/.)
# (S
#   Do/VBP
#   n't/RB
#   hesitate/VB
#   to/TO
#   honor/VB
#   and/CC
#   support/VB
#   those/DT
#   of/IN
#   us/PRP
#   who/WP
#   have/VBP
#   the/DT
#   honor/NN
#   of/IN
#   protecting/VBG
#   that/DT
#   which/WDT
#   is/VBZ
#   worth/JJ
#   protecting/VBG
#   ./.
#   ''/'')
# (S
#   (NE Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   's/POS
#   wife/NN
#   ,/,
#   (NE Lisa/NNP)
#   ,/,
#   and/CC
#   his/PRP$
#   mom/NN
#   and/CC
#   dad/NN
#   ,/,
#   (NE Sara/NNP Jo/NNP)
#   and/CC
#   (NE Bud/NNP)
#   ,/,
#   are/VBP
#   with/IN
#   us/PRP
#   this/DT
#   evening/NN
#   ./.)
# (S (NE Welcome/NNP) ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   nation/NN
#   is/VBZ
#   grateful/JJ
#   to/TO
#   the/DT
#   fallen/VBN
#   ,/,
#   who/WP
#   live/VBP
#   in/IN
#   the/DT
#   memory/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   grateful/JJ
#   to/TO
#   all/DT
#   who/WP
#   volunteer/VBP
#   to/TO
#   wear/VB
#   our/PRP$
#   nation/NN
#   's/POS
#   uniform/NN
#   --/:
#   and/CC
#   as/IN
#   we/PRP
#   honor/VBP
#   our/PRP$
#   brave/NN
#   troops/NNS
#   ,/,
#   let/VB
#   us/PRP
#   never/RB
#   forget/VBP
#   the/DT
#   sacrifices/NNS
#   of/IN
#   (NE America/NNP)
#   's/POS
#   military/JJ
#   families/NNS
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   offensive/JJ
#   against/IN
#   terror/NN
#   involves/VBZ
#   more/JJR
#   than/IN
#   military/JJ
#   action/NN
#   ./.)
# (S
#   Ultimately/RB
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   defeat/VB
#   the/DT
#   terrorists/NNS
#   is/VBZ
#   to/TO
#   defeat/VB
#   their/PRP$
#   dark/JJ
#   vision/NN
#   of/IN
#   hatred/VBN
#   and/CC
#   fear/VBN
#   by/IN
#   offering/VBG
#   the/DT
#   hopeful/JJ
#   alternative/NN
#   of/IN
#   political/JJ
#   freedom/NN
#   and/CC
#   peaceful/JJ
#   change/NN
#   ./.)
# (S
#   So/IN
#   the/DT
#   (NE United/NNP States/NNPS)
#   of/IN
#   (NE America/NNP)
#   supports/NNS
#   democratic/JJ
#   reform/NN
#   across/IN
#   the/DT
#   broader/JJR
#   (NE Middle/NNP East/NNP)
#   ./.)
# (S
#   Elections/NNS
#   are/VBP
#   vital/JJ
#   ,/,
#   but/CC
#   they/PRP
#   are/VBP
#   only/RB
#   the/DT
#   beginning/NN
#   ./.)
# (S
#   Raising/VBG
#   up/RP
#   a/DT
#   democracy/NN
#   requires/VBZ
#   the/DT
#   rule/NN
#   of/IN
#   law/NN
#   ,/,
#   and/CC
#   protection/NN
#   of/IN
#   minorities/NNS
#   ,/,
#   and/CC
#   strong/JJ
#   ,/,
#   accountable/JJ
#   institutions/NNS
#   that/IN
#   last/JJ
#   longer/JJR
#   than/IN
#   a/DT
#   single/JJ
#   vote/NN
#   ./.)
# (S
#   The/DT
#   great/JJ
#   people/NNS
#   of/IN
#   (NE Egypt/NNP)
#   have/VBP
#   voted/VBN
#   in/IN
#   a/DT
#   multi-party/JJ
#   presidential/JJ
#   election/NN
#   --/:
#   and/CC
#   now/RB
#   their/PRP$
#   government/NN
#   should/MD
#   open/VB
#   paths/NNS
#   of/IN
#   peaceful/JJ
#   opposition/NN
#   that/WDT
#   will/MD
#   reduce/VB
#   the/DT
#   appeal/NN
#   of/IN
#   radicalism/NN
#   ./.)
# (S
#   The/DT
#   (NE Palestinian/JJ)
#   people/NNS
#   have/VBP
#   voted/VBN
#   in/IN
#   elections/NNS
#   ./.)
# (S
#   And/CC
#   now/RB
#   the/DT
#   leaders/NNS
#   of/IN
#   (NE Hamas/NNP)
#   must/MD
#   recognize/VB
#   (NE Israel/NNP)
#   ,/,
#   disarm/NN
#   ,/,
#   reject/JJ
#   terrorism/NN
#   ,/,
#   and/CC
#   work/NN
#   for/IN
#   lasting/VBG
#   peace/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   (NE Saudi/NNP Arabia/NNP)
#   has/VBZ
#   taken/VBN
#   the/DT
#   first/JJ
#   steps/NNS
#   of/IN
#   reform/NN
#   --/:
#   now/RB
#   it/PRP
#   can/MD
#   offer/VB
#   its/PRP$
#   people/NNS
#   a/DT
#   better/JJR
#   future/NN
#   by/IN
#   pressing/VBG
#   forward/RB
#   with/IN
#   those/DT
#   efforts/NNS
#   ./.)
# (S
#   Democracies/NNS
#   in/IN
#   the/DT
#   (NE Middle/NNP East/NNP)
#   will/MD
#   not/RB
#   look/VB
#   like/IN
#   our/PRP$
#   own/JJ
#   ,/,
#   because/IN
#   they/PRP
#   will/MD
#   reflect/VB
#   the/DT
#   traditions/NNS
#   of/IN
#   their/PRP$
#   own/JJ
#   citizens/NNS
#   ./.)
# (S
#   Yet/RB
#   liberty/NN
#   is/VBZ
#   the/DT
#   future/NN
#   of/IN
#   every/DT
#   nation/NN
#   in/IN
#   the/DT
#   (NE Middle/NNP East/NNP)
#   ,/,
#   because/IN
#   liberty/NN
#   is/VBZ
#   the/DT
#   right/NN
#   and/CC
#   hope/NN
#   of/IN
#   all/DT
#   humanity/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   President/NNP
#   (NE George/NNP)
#   W./NNP
#   Bush/NNP
#   waves/VBZ
#   toward/IN
#   the/DT
#   upper/JJ
#   visitors/NNS
#   gallery/NN
#   of/IN
#   the/DT
#   (NE House/NNP)
#   Chamber/NNP
#   following/VBG
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   Union/NNP
#   remarks/NNS
#   Tuesday/NNP
#   ,/,
#   (NE Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   at/IN
#   the/DT
#   (NE United/NNP States/NNPS Capitol/NNP)
#   ./.)
# (S
#   (NE White/NNP House/NNP)
#   photo/NN
#   by/IN
#   (NE Eric/NNP)
#   Draper/NNP
#   The/DT
#   same/JJ
#   is/VBZ
#   true/JJ
#   of/IN
#   (NE Iran/NNP)
#   ,/,
#   a/DT
#   nation/NN
#   now/RB
#   held/VBN
#   hostage/NN
#   by/IN
#   a/DT
#   small/JJ
#   clerical/JJ
#   elite/NN
#   that/WDT
#   is/VBZ
#   isolating/VBG
#   and/CC
#   repressing/VBG
#   its/PRP$
#   people/NNS
#   ./.)
# (S
#   The/DT
#   regime/NN
#   in/IN
#   that/DT
#   country/NN
#   sponsors/NNS
#   terrorists/NNS
#   in/IN
#   the/DT
#   (NE Palestinian/JJ)
#   territories/NNS
#   and/CC
#   in/IN
#   (NE Lebanon/NNP)
#   --/:
#   and/CC
#   that/DT
#   must/MD
#   come/VB
#   to/TO
#   an/DT
#   end/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   The/DT
#   (NE Iranian/JJ)
#   government/NN
#   is/VBZ
#   defying/VBG
#   the/DT
#   world/NN
#   with/IN
#   its/PRP$
#   nuclear/JJ
#   ambitions/NNS
#   ,/,
#   and/CC
#   the/DT
#   nations/NNS
#   of/IN
#   the/DT
#   world/NN
#   must/MD
#   not/RB
#   permit/VB
#   the/DT
#   (NE Iranian/JJ)
#   regime/NN
#   to/TO
#   gain/VB
#   nuclear/JJ
#   weapons/NNS
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   (NE America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   rally/VB
#   the/DT
#   world/NN
#   to/TO
#   confront/VB
#   these/DT
#   threats/NNS
#   ./.)
# (S
#   (NE Tonight/NNP)
#   ,/,
#   let/VB
#   me/PRP
#   speak/VB
#   directly/RB
#   to/TO
#   the/DT
#   citizens/NNS
#   of/IN
#   (NE Iran/NNP)
#   :/:
#   (NE America/NNP)
#   respects/VBZ
#   you/PRP
#   ,/,
#   and/CC
#   we/PRP
#   respect/VBP
#   your/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   respect/VBP
#   your/PRP$
#   right/NN
#   to/TO
#   choose/VB
#   your/PRP$
#   own/JJ
#   future/NN
#   and/CC
#   win/VB
#   your/PRP$
#   own/JJ
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   nation/NN
#   hopes/VBZ
#   one/CD
#   day/NN
#   to/TO
#   be/VB
#   the/DT
#   closest/JJS
#   of/IN
#   friends/NNS
#   with/IN
#   a/DT
#   free/JJ
#   and/CC
#   democratic/JJ
#   (NE Iran/NNP)
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   To/TO
#   overcome/VB
#   dangers/NNS
#   in/IN
#   our/PRP$
#   world/NN
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   take/VB
#   the/DT
#   offensive/JJ
#   by/IN
#   encouraging/VBG
#   economic/JJ
#   progress/NN
#   ,/,
#   and/CC
#   fighting/VBG
#   disease/NN
#   ,/,
#   and/CC
#   spreading/VBG
#   hope/NN
#   in/IN
#   hopeless/JJ
#   lands/NNS
#   ./.)
# (S
#   (NE Isolationism/NNP)
#   would/MD
#   not/RB
#   only/RB
#   tie/VB
#   our/PRP$
#   hands/NNS
#   in/IN
#   fighting/VBG
#   enemies/NNS
#   ,/,
#   it/PRP
#   would/MD
#   keep/VB
#   us/PRP
#   from/IN
#   helping/VBG
#   our/PRP$
#   friends/NNS
#   in/IN
#   desperate/JJ
#   need/NN
#   ./.)
# (S
#   We/PRP
#   show/VBP
#   compassion/JJ
#   abroad/RB
#   because/IN
#   Americans/NNPS
#   believe/VBP
#   in/IN
#   the/DT
#   God-given/NNP
#   dignity/NN
#   and/CC
#   worth/NN
#   of/IN
#   a/DT
#   villager/NN
#   with/IN
#   HIV/AIDS/NNP
#   ,/,
#   or/CC
#   an/DT
#   infant/NN
#   with/IN
#   malaria/NNS
#   ,/,
#   or/CC
#   a/DT
#   refugee/JJ
#   fleeing/NN
#   genocide/NN
#   ,/,
#   or/CC
#   a/DT
#   young/JJ
#   girl/NN
#   sold/VBN
#   into/IN
#   slavery/NN
#   ./.)
# (S
#   We/PRP
#   also/RB
#   show/VBP
#   compassion/NN
#   abroad/RB
#   because/IN
#   regions/NNS
#   overwhelmed/VBN
#   by/IN
#   poverty/NN
#   ,/,
#   corruption/NN
#   ,/,
#   and/CC
#   despair/NN
#   are/VBP
#   sources/NNS
#   of/IN
#   terrorism/NN
#   ,/,
#   and/CC
#   organized/VBD
#   crime/NN
#   ,/,
#   and/CC
#   human/JJ
#   trafficking/NN
#   ,/,
#   and/CC
#   the/DT
#   drug/NN
#   trade/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   have/VBP
#   taken/VBN
#   unprecedented/JJ
#   action/NN
#   to/TO
#   fight/VB
#   (NE AIDS/NNP)
#   and/CC
#   malaria/NNS
#   ,/,
#   expand/VBP
#   the/DT
#   education/NN
#   of/IN
#   girls/NNS
#   ,/,
#   and/CC
#   reward/RB
#   developing/VBG
#   nations/NNS
#   that/WDT
#   are/VBP
#   moving/VBG
#   forward/RB
#   with/IN
#   economic/JJ
#   and/CC
#   political/JJ
#   reform/NN
#   ./.)
# (S
#   For/IN
#   people/NNS
#   everywhere/RB
#   ,/,
#   the/DT
#   (NE United/NNP States/NNPS)
#   is/VBZ
#   a/DT
#   partner/NN
#   for/IN
#   a/DT
#   better/JJR
#   life/NN
#   ./.)
# (S
#   Short-changing/VBG
#   these/DT
#   efforts/NNS
#   would/MD
#   increase/VB
#   the/DT
#   suffering/NN
#   and/CC
#   chaos/NN
#   of/IN
#   our/PRP$
#   world/NN
#   ,/,
#   undercut/JJ
#   our/PRP$
#   long-term/JJ
#   security/NN
#   ,/,
#   and/CC
#   dull/VB
#   the/DT
#   conscience/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   members/NNS
#   of/IN
#   (NE Congress/NNP)
#   to/TO
#   serve/VB
#   the/DT
#   interests/NNS
#   of/IN
#   (NE America/NNP)
#   by/IN
#   showing/VBG
#   the/DT
#   compassion/NN
#   of/IN
#   (NE America/NNP)
#   ./.)
# (S
#   Our/PRP$
#   country/NN
#   must/MD
#   also/RB
#   remain/VB
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terrorism/NN
#   here/RB
#   at/IN
#   home/NN
#   ./.)
# (S
#   The/DT
#   enemy/NN
#   has/VBZ
#   not/RB
#   lost/VBN
#   the/DT
#   desire/NN
#   or/CC
#   capability/NN
#   to/TO
#   attack/VB
#   us/PRP
#   ./.)
# (S
#   Fortunately/RB
#   ,/,
#   this/DT
#   nation/NN
#   has/VBZ
#   superb/VBN
#   professionals/NNS
#   in/IN
#   law/NN
#   enforcement/NN
#   ,/,
#   intelligence/NN
#   ,/,
#   the/DT
#   military/JJ
#   ,/,
#   and/CC
#   homeland/VBP
#   security/NN
#   ./.)
# (S
#   These/DT
#   men/NNS
#   and/CC
#   women/NNS
#   are/VBP
#   dedicating/VBG
#   their/PRP$
#   lives/NNS
#   ,/,
#   protecting/VBG
#   us/PRP
#   all/DT
#   ,/,
#   and/CC
#   they/PRP
#   deserve/VBP
#   our/PRP$
#   support/NN
#   and/CC
#   our/PRP$
#   thanks/NNS
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   They/PRP
#   also/RB
#   deserve/VBP
#   the/DT
#   same/JJ
#   tools/NNS
#   they/PRP
#   already/RB
#   use/VBP
#   to/TO
#   fight/VB
#   drug/NN
#   trafficking/NN
#   and/CC
#   organized/VBN
#   crime/NN
#   --/:
#   so/RB
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   reauthorize/VB
#   the/DT
#   (NE Patriot/NNP Act/NNP)
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   It/PRP
#   is/VBZ
#   said/VBD
#   that/IN
#   prior/JJ
#   to/TO
#   the/DT
#   attacks/NNS
#   of/IN
#   September/NNP
#   the/DT
#   11th/CD
#   ,/,
#   our/PRP$
#   government/NN
#   failed/VBD
#   to/TO
#   connect/VB
#   the/DT
#   dots/NNS
#   of/IN
#   the/DT
#   conspiracy/NN
#   ./.)
# (S
#   We/PRP
#   now/RB
#   know/VBP
#   that/IN
#   two/CD
#   of/IN
#   the/DT
#   hijackers/NNS
#   in/IN
#   the/DT
#   (NE United/NNP States/NNPS)
#   placed/VBD
#   telephone/NN
#   calls/NNS
#   to/TO
#   al/VB
#   (NE Qaeda/NNP)
#   operatives/VBZ
#   overseas/RB
#   ./.)
# (S
#   But/CC
#   we/PRP
#   did/VBD
#   not/RB
#   know/VB
#   about/IN
#   their/PRP$
#   plans/NNS
#   until/IN
#   it/PRP
#   was/VBD
#   too/RB
#   late/JJ
#   ./.)
# (S
#   So/RB
#   to/TO
#   prevent/VB
#   another/DT
#   attack/NN
#   --/:
#   based/VBN
#   on/IN
#   authority/NN
#   given/VBN
#   to/TO
#   me/PRP
#   by/IN
#   the/DT
#   Constitution/NNP
#   and/CC
#   by/IN
#   statute/NN
#   --/:
#   I/PRP
#   have/VBP
#   authorized/VBN
#   a/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   to/TO
#   aggressively/RB
#   pursue/VB
#   the/DT
#   international/JJ
#   communications/NNS
#   of/IN
#   suspected/JJ
#   al/JJ
#   Qaeda/NNP
#   operatives/NNS
#   and/CC
#   affiliates/NNS
#   to/TO
#   and/CC
#   from/IN
#   (NE America/NNP)
#   ./.)
# (S
#   Previous/JJ
#   Presidents/NNS
#   have/VBP
#   used/VBN
#   the/DT
#   same/JJ
#   constitutional/JJ
#   authority/NN
#   I/PRP
#   have/VBP
#   ,/,
#   and/CC
#   federal/JJ
#   courts/NNS
#   have/VBP
#   approved/VBN
#   the/DT
#   use/NN
#   of/IN
#   that/DT
#   authority/NN
#   ./.)
# (S
#   Appropriate/JJ
#   members/NNS
#   of/IN
#   (NE Congress/NNP)
#   have/VBP
#   been/VBN
#   kept/VBN
#   informed/VBN
#   ./.)
# (S
#   The/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   has/VBZ
#   helped/VBN
#   prevent/VB
#   terrorist/JJ
#   attacks/NNS
#   ./.)
# (S
#   It/PRP
#   remains/VBZ
#   essential/JJ
#   to/TO
#   the/DT
#   security/NN
#   of/IN
#   (NE America/NNP)
#   ./.)
# (S
#   If/IN
#   there/EX
#   are/VBP
#   people/NNS
#   inside/IN
#   our/PRP$
#   country/NN
#   who/WP
#   are/VBP
#   talking/VBG
#   with/IN
#   al/NN
#   (NE Qaeda/NNP)
#   ,/,
#   we/PRP
#   want/VBP
#   to/TO
#   know/VB
#   about/IN
#   it/PRP
#   ,/,
#   because/IN
#   we/PRP
#   will/MD
#   not/RB
#   sit/VB
#   back/RB
#   and/CC
#   wait/NN
#   to/TO
#   be/VB
#   hit/VBN
#   again/RB
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   In/IN
#   all/PDT
#   these/DT
#   areas/NNS
#   --/:
#   from/IN
#   the/DT
#   disruption/NN
#   of/IN
#   terror/NN
#   networks/NNS
#   ,/,
#   to/TO
#   victory/NN
#   in/IN
#   (NE Iraq/NNP)
#   ,/,
#   to/TO
#   the/DT
#   spread/NN
#   of/IN
#   freedom/NN
#   and/CC
#   hope/NN
#   in/IN
#   troubled/JJ
#   regions/NNS
#   --/:
#   we/PRP
#   need/VBP
#   the/DT
#   support/NN
#   of/IN
#   our/PRP$
#   friends/NNS
#   and/CC
#   allies/NNS
#   ./.)
# (S
#   To/TO
#   draw/VB
#   that/DT
#   support/NN
#   ,/,
#   we/PRP
#   must/MD
#   always/RB
#   be/VB
#   clear/JJ
#   in/IN
#   our/PRP$
#   principles/NNS
#   and/CC
#   willing/JJ
#   to/TO
#   act/VB
#   ./.)
# (S
#   The/DT
#   only/JJ
#   alternative/NN
#   to/TO
#   (NE American/JJ)
#   leadership/NN
#   is/VBZ
#   a/DT
#   dramatically/RB
#   more/RBR
#   dangerous/JJ
#   and/CC
#   anxious/JJ
#   world/NN
#   ./.)
# (S
#   Yet/CC
#   we/PRP
#   also/RB
#   choose/VBP
#   to/TO
#   lead/VB
#   because/IN
#   it/PRP
#   is/VBZ
#   a/DT
#   privilege/NN
#   to/TO
#   serve/VB
#   the/DT
#   values/NNS
#   that/WDT
#   gave/VBD
#   us/PRP
#   birth/NN
#   ./.)
# (S
#   (NE American/JJ)
#   leaders/NNS
#   --/:
#   from/IN
#   (NE Roosevelt/NNP)
#   to/TO
#   (NE Truman/NNP)
#   to/TO
#   (NE Kennedy/NNP)
#   to/TO
#   (NE Reagan/NNP)
#   --/:
#   rejected/VBD
#   isolation/NN
#   and/CC
#   retreat/NN
#   ,/,
#   because/IN
#   they/PRP
#   knew/VBD
#   that/IN
#   (NE America/NNP)
#   is/VBZ
#   always/RB
#   more/RBR
#   secure/JJ
#   when/WRB
#   freedom/NN
#   is/VBZ
#   on/IN
#   the/DT
#   march/NN
#   ./.)
# (S
#   Our/PRP$
#   own/JJ
#   generation/NN
#   is/VBZ
#   in/IN
#   a/DT
#   long/JJ
#   war/NN
#   against/IN
#   a/DT
#   determined/JJ
#   enemy/NN
#   --/:
#   a/DT
#   war/NN
#   that/WDT
#   will/MD
#   be/VB
#   fought/VBN
#   by/IN
#   Presidents/NNS
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   who/WP
#   will/MD
#   need/VB
#   steady/JJ
#   bipartisan/JJ
#   support/NN
#   from/IN
#   the/DT
#   (NE Congress/NNP)
#   ./.)
# (S And/CC tonight/NN I/PRP ask/VBP for/IN yours/NNS ./.)
# (S
#   Together/RB
#   ,/,
#   let/VB
#   us/PRP
#   protect/VB
#   our/PRP$
#   country/NN
#   ,/,
#   support/VB
#   the/DT
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   defend/VBP
#   us/PRP
#   ,/,
#   and/CC
#   lead/VB
#   this/DT
#   world/NN
#   toward/IN
#   freedom/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Here/RB
#   at/IN
#   home/NN
#   ,/,
#   (NE America/NNP)
#   also/RB
#   has/VBZ
#   a/DT
#   great/JJ
#   opportunity/NN
#   :/:
#   We/PRP
#   will/MD
#   build/VB
#   the/DT
#   prosperity/NN
#   of/IN
#   our/PRP$
#   country/NN
#   by/IN
#   strengthening/VBG
#   our/PRP$
#   economic/JJ
#   leadership/NN
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   Our/PRP$
#   economy/NN
#   is/VBZ
#   healthy/JJ
#   and/CC
#   vigorous/JJ
#   ,/,
#   and/CC
#   growing/VBG
#   faster/RBR
#   than/IN
#   other/JJ
#   major/JJ
#   industrialized/VBN
#   nations/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   two-and-a-half/JJ
#   years/NNS
#   ,/,
#   (NE America/NNP)
#   has/VBZ
#   created/VBN
#   4.6/CD
#   million/CD
#   new/JJ
#   jobs/NNS
#   --/:
#   more/JJR
#   than/IN
#   (NE Japan/NNP)
#   and/CC
#   the/DT
#   (NE European/NNP Union/NNP)
#   combined/VBD
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Even/RB
#   in/IN
#   the/DT
#   face/NN
#   of/IN
#   higher/JJR
#   energy/NN
#   prices/NNS
#   and/CC
#   natural/JJ
#   disasters/NNS
#   ,/,
#   the/DT
#   (NE American/JJ)
#   people/NNS
#   have/VBP
#   turned/VBN
#   in/IN
#   an/DT
#   economic/JJ
#   performance/NN
#   that/WDT
#   is/VBZ
#   the/DT
#   envy/NN
#   of/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   The/DT
#   (NE American/JJ)
#   economy/NN
#   is/VBZ
#   preeminent/JJ
#   ,/,
#   but/CC
#   we/PRP
#   can/MD
#   not/RB
#   afford/VB
#   to/TO
#   be/VB
#   complacent/JJ
#   ./.)
# (S
#   In/IN
#   a/DT
#   dynamic/JJ
#   world/NN
#   economy/NN
#   ,/,
#   we/PRP
#   are/VBP
#   seeing/VBG
#   new/JJ
#   competitors/NNS
#   ,/,
#   like/IN
#   (NE China/NNP)
#   and/CC
#   (NE India/NNP)
#   ,/,
#   and/CC
#   this/DT
#   creates/VBZ
#   uncertainty/NN
#   ,/,
#   which/WDT
#   makes/VBZ
#   it/PRP
#   easier/JJR
#   to/TO
#   feed/VB
#   people/NNS
#   's/POS
#   fears/NNS
#   ./.)
# (S
#   So/IN
#   we/PRP
#   're/VBP
#   seeing/VBG
#   some/DT
#   old/JJ
#   temptations/NNS
#   return/NN
#   ./.)
# (S
#   Protectionists/NNS
#   want/VBP
#   to/TO
#   escape/VB
#   competition/NN
#   ,/,
#   pretending/VBG
#   that/IN
#   we/PRP
#   can/MD
#   keep/VB
#   our/PRP$
#   high/JJ
#   standard/NN
#   of/IN
#   living/NN
#   while/IN
#   walling/VBG
#   off/RP
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Others/NNS
#   say/VBP
#   that/IN
#   the/DT
#   government/NN
#   needs/VBZ
#   to/TO
#   take/VB
#   a/DT
#   larger/JJR
#   role/NN
#   in/IN
#   directing/VBG
#   the/DT
#   economy/NN
#   ,/,
#   centralizing/VBG
#   more/JJR
#   power/NN
#   in/IN
#   (NE Washington/NNP)
#   and/CC
#   increasing/VBG
#   taxes/NNS
#   ./.)
# (S
#   We/PRP
#   hear/VBP
#   claims/NNS
#   that/IN
#   immigrants/NNS
#   are/VBP
#   somehow/RB
#   bad/JJ
#   for/IN
#   the/DT
#   economy/NN
#   --/:
#   even/RB
#   though/IN
#   this/DT
#   economy/NN
#   could/MD
#   not/RB
#   function/VB
#   without/IN
#   them/PRP
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   All/PDT
#   these/DT
#   are/VBP
#   forms/NNS
#   of/IN
#   economic/JJ
#   retreat/NN
#   ,/,
#   and/CC
#   they/PRP
#   lead/VBP
#   in/IN
#   the/DT
#   same/JJ
#   direction/NN
#   --/:
#   toward/IN
#   a/DT
#   stagnant/JJ
#   and/CC
#   second-rate/JJ
#   economy/NN
#   ./.)
# (S
#   Tonight/NNP
#   I/PRP
#   will/MD
#   set/VB
#   out/RP
#   a/DT
#   better/JJR
#   path/NN
#   :/:
#   an/DT
#   agenda/NN
#   for/IN
#   a/DT
#   nation/NN
#   that/WDT
#   competes/VBZ
#   with/IN
#   confidence/NN
#   ;/:
#   an/DT
#   agenda/NN
#   that/WDT
#   will/MD
#   raise/VB
#   standards/NNS
#   of/IN
#   living/NN
#   and/CC
#   generate/VB
#   new/JJ
#   jobs/NNS
#   ./.)
# (S
#   Americans/NNPS
#   should/MD
#   not/RB
#   fear/VB
#   our/PRP$
#   economic/JJ
#   future/NN
#   ,/,
#   because/IN
#   we/PRP
#   intend/VBP
#   to/TO
#   shape/VB
#   it/PRP
#   ./.)
# (S
#   Keeping/VBG
#   (NE America/NNP)
#   competitive/JJ
#   begins/NNS
#   with/IN
#   keeping/VBG
#   our/PRP$
#   economy/NN
#   growing/VBG
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   economy/NN
#   grows/VBZ
#   when/WRB
#   Americans/NNPS
#   have/VBP
#   more/JJR
#   of/IN
#   their/PRP$
#   own/JJ
#   money/NN
#   to/TO
#   spend/VB
#   ,/,
#   save/VB
#   ,/,
#   and/CC
#   invest/JJS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   five/CD
#   years/NNS
#   ,/,
#   the/DT
#   tax/NN
#   relief/NN
#   you/PRP
#   passed/VBN
#   has/VBZ
#   left/VBN
#   $/$
#   880/CD
#   billion/CD
#   in/IN
#   the/DT
#   hands/NNS
#   of/IN
#   (NE American/JJ)
#   workers/NNS
#   ,/,
#   investors/NNS
#   ,/,
#   small/JJ
#   businesses/NNS
#   ,/,
#   and/CC
#   families/NNS
#   --/:
#   and/CC
#   they/PRP
#   have/VBP
#   used/VBN
#   it/PRP
#   to/TO
#   help/VB
#   produce/VB
#   more/JJR
#   than/IN
#   four/CD
#   years/NNS
#   of/IN
#   uninterrupted/JJ
#   economic/JJ
#   growth/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   the/DT
#   tax/NN
#   relief/NN
#   is/VBZ
#   set/VBN
#   to/TO
#   expire/VB
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   years/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   do/VBP
#   nothing/NN
#   ,/,
#   (NE American/NNP)
#   families/NNS
#   will/MD
#   face/VB
#   a/DT
#   massive/JJ
#   tax/NN
#   increase/NN
#   they/PRP
#   do/VBP
#   not/RB
#   expect/VB
#   and/CC
#   will/MD
#   not/RB
#   welcome/VB
#   ./.)
# (S
#   Because/IN
#   (NE America/NNP)
#   needs/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   temporary/JJ
#   expansion/NN
#   ,/,
#   we/PRP
#   need/VBP
#   more/JJR
#   than/IN
#   temporary/JJ
#   tax/NN
#   relief/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   the/DT
#   (NE Congress/NNP)
#   to/TO
#   act/VB
#   responsibly/RB
#   ,/,
#   and/CC
#   make/VB
#   the/DT
#   tax/NN
#   cuts/NNS
#   permanent/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (NE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   be/VB
#   good/JJ
#   stewards/NNS
#   of/IN
#   tax/NN
#   dollars/NNS
#   ./.)
# (S
#   Every/DT
#   year/NN
#   of/IN
#   my/PRP$
#   presidency/NN
#   ,/,
#   we/PRP
#   've/VBP
#   reduced/VBN
#   the/DT
#   growth/NN
#   of/IN
#   non-security/JJ
#   discretionary/JJ
#   spending/NN
#   ,/,
#   and/CC
#   last/JJ
#   year/NN
#   you/PRP
#   passed/VBD
#   bills/NNS
#   that/IN
#   cut/VBD
#   this/DT
#   spending/NN
#   ./.)
# (S
#   This/DT
#   year/NN
#   my/PRP$
#   budget/NN
#   will/MD
#   cut/VB
#   it/PRP
#   again/RB
#   ,/,
#   and/CC
#   reduce/VB
#   or/CC
#   eliminate/VB
#   more/JJR
#   than/IN
#   140/CD
#   programs/NNS
#   that/WDT
#   are/VBP
#   performing/VBG
#   poorly/RB
#   or/CC
#   not/RB
#   fulfilling/JJ
#   essential/JJ
#   priorities/NNS
#   ./.)
# (S
#   By/IN
#   passing/VBG
#   these/DT
#   reforms/NNS
#   ,/,
#   we/PRP
#   will/MD
#   save/VB
#   the/DT
#   (NE American/NNP)
#   taxpayer/NN
#   another/DT
#   $/$
#   14/CD
#   billion/CD
#   next/JJ
#   year/NN
#   ,/,
#   and/CC
#   stay/VB
#   on/IN
#   track/NN
#   to/TO
#   cut/VB
#   the/DT
#   deficit/NN
#   in/IN
#   half/NN
#   by/IN
#   2009/CD
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   I/PRP
#   am/VBP
#   pleased/JJ
#   that/IN
#   members/NNS
#   of/IN
#   (NE Congress/NNP)
#   are/VBP
#   working/VBG
#   on/IN
#   earmark/NN
#   reform/NN
#   ,/,
#   because/IN
#   the/DT
#   federal/JJ
#   budget/NN
#   has/VBZ
#   too/RB
#   many/JJ
#   special/JJ
#   interest/NN
#   projects/NNS
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   can/MD
#   tackle/VB
#   this/DT
#   problem/NN
#   together/RB
#   ,/,
#   if/IN
#   you/PRP
#   pass/VBP
#   the/DT
#   line-item/JJ
#   veto/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   We/PRP
#   must/MD
#   also/RB
#   confront/VB
#   the/DT
#   larger/JJR
#   challenge/NN
#   of/IN
#   mandatory/JJ
#   spending/NN
#   ,/,
#   or/CC
#   entitlements/NNS
#   ./.)
# (S
#   This/DT
#   year/NN
#   ,/,
#   the/DT
#   first/JJ
#   of/IN
#   about/RB
#   78/CD
#   million/CD
#   baby/NN
#   boomers/NNS
#   turn/VBP
#   60/CD
#   ,/,
#   including/VBG
#   two/CD
#   of/IN
#   my/PRP$
#   Dad/NNP
#   's/POS
#   favorite/JJ
#   people/NNS
#   --/:
#   me/PRP
#   and/CC
#   President/NNP
#   (NE Clinton/NNP)
#   ./.)
# (S (/( Laughter/NNP ./. )/))
# (S
#   This/DT
#   milestone/NN
#   is/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   personal/JJ
#   crisis/NN
#   --/:
#   (/(
#   laughter/NN
#   )/)
#   --/:
#   it/PRP
#   is/VBZ
#   a/DT
#   national/JJ
#   challenge/NN
#   ./.)
# (S
#   The/DT
#   retirement/NN
#   of/IN
#   the/DT
#   baby/NN
#   boom/NN
#   generation/NN
#   will/MD
#   put/VB
#   unprecedented/JJ
#   strains/NNS
#   on/IN
#   the/DT
#   federal/JJ
#   government/NN
#   ./.)
# (S
#   By/IN
#   2030/CD
#   ,/,
#   spending/VBG
#   for/IN
#   (NE Social/NNP Security/NNP)
#   ,/,
#   (NE Medicare/NNP)
#   and/CC
#   (NE Medicaid/NNP)
#   alone/RB
#   will/MD
#   be/VB
#   almost/RB
#   60/CD
#   percent/NN
#   of/IN
#   the/DT
#   entire/JJ
#   federal/JJ
#   budget/NN
#   ./.)
# (S
#   And/CC
#   that/DT
#   will/MD
#   present/VB
#   future/JJ
#   Congresses/NNS
#   with/IN
#   impossible/JJ
#   choices/NNS
#   --/:
#   staggering/VBG
#   tax/NN
#   increases/NNS
#   ,/,
#   immense/JJ
#   deficits/NNS
#   ,/,
#   or/CC
#   deep/JJ
#   cuts/NNS
#   in/IN
#   every/DT
#   category/NN
#   of/IN
#   spending/NN
#   ./.)
# (S
#   (NE Congress/NNP)
#   did/VBD
#   not/RB
#   act/VB
#   last/JJ
#   year/NN
#   on/IN
#   my/PRP$
#   proposal/NN
#   to/TO
#   save/VB
#   (NE Social/NNP)
#   Security/NNP
#   --/:
#   (/(
#   applause/NN
#   )/)
#   --/:
#   yet/RB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   entitlements/NNS
#   is/VBZ
#   a/DT
#   problem/NN
#   that/WDT
#   is/VBZ
#   not/RB
#   going/VBG
#   away/RB
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   And/CC
#   every/DT
#   year/NN
#   we/PRP
#   fail/VBP
#   to/TO
#   act/VB
#   ,/,
#   the/DT
#   situation/NN
#   gets/VBZ
#   worse/JJR
#   ./.)
# (S
#   So/RB
#   tonight/JJ
#   ,/,
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   join/VB
#   me/PRP
#   in/IN
#   creating/VBG
#   a/DT
#   commission/NN
#   to/TO
#   examine/VB
#   the/DT
#   full/JJ
#   impact/NN
#   of/IN
#   baby/NN
#   boom/NN
#   retirements/NNS
#   on/IN
#   (NE Social/NNP Security/NNP)
#   ,/,
#   (NE Medicare/NNP)
#   ,/,
#   and/CC
#   (NE Medicaid/NNP)
#   ./.)
# (S
#   This/DT
#   commission/NN
#   should/MD
#   include/VB
#   members/NNS
#   of/IN
#   (NE Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   and/CC
#   offer/VBP
#   bipartisan/JJ
#   solutions/NNS
#   ./.)
# (S
#   We/PRP
#   need/VBP
#   to/TO
#   put/VB
#   aside/RP
#   partisan/JJ
#   politics/NNS
#   and/CC
#   work/NN
#   together/RB
#   and/CC
#   get/VB
#   this/DT
#   problem/NN
#   solved/VBD
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (NE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   open/VB
#   more/JJR
#   markets/NNS
#   for/IN
#   all/DT
#   that/DT
#   Americans/NNPS
#   make/VBP
#   and/CC
#   grow/VB
#   ./.)
# (S
#   One/CD
#   out/NN
#   of/IN
#   every/DT
#   five/CD
#   factory/NN
#   jobs/NNS
#   in/IN
#   (NE America/NNP)
#   is/VBZ
#   related/VBN
#   to/TO
#   global/JJ
#   trade/NN
#   ,/,
#   and/CC
#   we/PRP
#   want/VBP
#   people/NNS
#   everywhere/RB
#   to/TO
#   buy/VB
#   (NE American/NNP)
#   ./.)
# (S
#   With/IN
#   open/JJ
#   markets/NNS
#   and/CC
#   a/DT
#   level/JJ
#   playing/NN
#   field/NN
#   ,/,
#   no/DT
#   one/NN
#   can/MD
#   out-produce/VB
#   or/CC
#   out-compete/VB
#   the/DT
#   (NE American/JJ)
#   worker/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (NE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   an/DT
#   immigration/NN
#   system/NN
#   that/WDT
#   upholds/VBZ
#   our/PRP$
#   laws/NNS
#   ,/,
#   reflects/VBZ
#   our/PRP$
#   values/NNS
#   ,/,
#   and/CC
#   serves/VBZ
#   the/DT
#   interests/NNS
#   of/IN
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Our/PRP$
#   nation/NN
#   needs/VBZ
#   orderly/JJ
#   and/CC
#   secure/JJ
#   borders/NNS
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   To/TO
#   meet/VB
#   this/DT
#   goal/NN
#   ,/,
#   we/PRP
#   must/MD
#   have/VB
#   stronger/JJR
#   immigration/NN
#   enforcement/NN
#   and/CC
#   border/NN
#   protection/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   must/MD
#   have/VB
#   a/DT
#   rational/JJ
#   ,/,
#   humane/JJ
#   guest/JJS
#   worker/NN
#   program/NN
#   that/WDT
#   rejects/VBZ
#   amnesty/JJ
#   ,/,
#   allows/VBZ
#   temporary/JJ
#   jobs/NNS
#   for/IN
#   people/NNS
#   who/WP
#   seek/VBP
#   them/PRP
#   legally/RB
#   ,/,
#   and/CC
#   reduces/NNS
#   smuggling/VBG
#   and/CC
#   crime/NN
#   at/IN
#   the/DT
#   border/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (NE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   affordable/JJ
#   health/NN
#   care/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   government/NN
#   has/VBZ
#   a/DT
#   responsibility/NN
#   to/TO
#   provide/VB
#   health/NN
#   care/NN
#   for/IN
#   the/DT
#   poor/JJ
#   and/CC
#   the/DT
#   elderly/JJ
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   meeting/VBG
#   that/IN
#   responsibility/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   For/IN
#   all/DT
#   Americans/NNPS
#   --/:
#   for/IN
#   all/DT
#   Americans/NNPS
#   ,/,
#   we/PRP
#   must/MD
#   confront/VB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   care/NN
#   ,/,
#   strengthen/VB
#   the/DT
#   doctor-patient/JJ
#   relationship/NN
#   ,/,
#   and/CC
#   help/NN
#   people/NNS
#   afford/VBP
#   the/DT
#   insurance/NN
#   coverage/NN
#   they/PRP
#   need/VBP
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   make/VB
#   wider/JJR
#   use/NN
#   of/IN
#   electronic/JJ
#   records/NNS
#   and/CC
#   other/JJ
#   health/NN
#   information/NN
#   technology/NN
#   ,/,
#   to/TO
#   help/VB
#   control/VB
#   costs/NNS
#   and/CC
#   reduce/VB
#   dangerous/JJ
#   medical/JJ
#   errors/NNS
#   ./.)
# (S
#   We/PRP
#   will/MD
#   strengthen/VB
#   health/NN
#   savings/NNS
#   accounts/NNS
#   --/:
#   making/VBG
#   sure/JJ
#   individuals/NNS
#   and/CC
#   small/JJ
#   business/NN
#   employees/NNS
#   can/MD
#   buy/VB
#   insurance/NN
#   with/IN
#   the/DT
#   same/JJ
#   advantages/VBZ
#   that/IN
#   people/NNS
#   working/VBG
#   for/IN
#   big/JJ
#   businesses/NNS
#   now/RB
#   get/VBP
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   do/VB
#   more/JJR
#   to/TO
#   make/VB
#   this/DT
#   coverage/NN
#   portable/JJ
#   ,/,
#   so/IN
#   workers/NNS
#   can/MD
#   switch/VB
#   jobs/NNS
#   without/IN
#   having/VBG
#   to/TO
#   worry/VB
#   about/IN
#   losing/VBG
#   their/PRP$
#   health/NN
#   insurance/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   And/CC
#   because/IN
#   lawsuits/NNS
#   are/VBP
#   driving/VBG
#   many/JJ
#   good/JJ
#   doctors/NNS
#   out/IN
#   of/IN
#   practice/NN
#   --/:
#   leaving/VBG
#   women/NNS
#   in/IN
#   nearly/RB
#   1,500/CD
#   (NE American/JJ)
#   counties/NNS
#   without/IN
#   a/DT
#   single/JJ
#   OB/GYN/NNP
#   --/:
#   I/PRP
#   ask/VBP
#   the/DT
#   (NE Congress/NNP)
#   to/TO
#   pass/VB
#   medical/JJ
#   liability/NN
#   reform/NN
# ...
#   to/TO
#   compete/VB
#   with/IN
#   other/JJ
#   nations/NNS
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   made/VBN
#   a/DT
#   good/JJ
#   start/NN
#   in/IN
#   the/DT
#   early/JJ
#   grades/NNS
#   with/IN
#   the/DT
#   No/NNP
#   Child/NNP
#   Left/NNP
#   Behind/NNP
#   Act/NNP
#   ,/,
#   which/WDT
#   is/VBZ
#   raising/VBG
#   standards/NNS
#   and/CC
#   lifting/VBG
#   test/NN
#   scores/NNS
#   across/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   Tonight/NNP
#   I/PRP
#   propose/VBP
#   to/TO
#   train/VB
#   70,000/CD
#   high/JJ
#   school/NN
#   teachers/NNS
#   to/TO
#   lead/VB
#   advanced-placement/JJ
#   courses/NNS
#   in/IN
#   math/NN
#   and/CC
#   science/NN
#   ,/,
#   bring/VBG
#   30,000/CD
#   math/NN
#   and/CC
#   science/NN
#   professionals/NNS
#   to/TO
#   teach/VB
#   in/IN
#   classrooms/NNS
#   ,/,
#   and/CC
#   give/VB
#   early/JJ
#   help/NN
#   to/TO
#   students/NNS
#   who/WP
#   struggle/VBP
#   with/IN
#   math/NN
#   ,/,
#   so/IN
#   they/PRP
#   have/VBP
#   a/DT
#   better/JJR
#   chance/NN
#   at/IN
#   good/JJ
#   ,/,
#   high-wage/JJ
#   jobs/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   ensure/VB
#   that/IN
#   (NE America/NNP)
#   's/POS
#   children/NNS
#   succeed/VB
#   in/IN
#   life/NN
#   ,/,
#   they/PRP
#   will/MD
#   ensure/VB
#   that/IN
#   (NE America/NNP)
#   succeeds/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Preparing/VBG
#   our/PRP$
#   nation/NN
#   to/TO
#   compete/VB
#   in/IN
#   the/DT
#   world/NN
#   is/VBZ
#   a/DT
#   goal/NN
#   that/IN
#   all/DT
#   of/IN
#   us/PRP
#   can/MD
#   share/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   you/PRP
#   to/TO
#   support/VB
#   the/DT
#   (NE American/JJ Competitiveness/NNP Initiative/NNP)
#   ,/,
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   show/VB
#   the/DT
#   world/NN
#   what/WP
#   the/DT
#   (NE American/JJ)
#   people/NNS
#   can/MD
#   achieve/VB
#   ./.)
# (S
#   (NE America/NNP)
#   is/VBZ
#   a/DT
#   great/JJ
#   force/NN
#   for/IN
#   freedom/NN
#   and/CC
#   prosperity/NN
#   ./.)
# (S
#   Yet/RB
#   our/PRP$
#   greatness/NN
#   is/VBZ
#   not/RB
#   measured/VBN
#   in/IN
#   power/NN
#   or/CC
#   luxuries/NNS
#   ,/,
#   but/CC
#   by/IN
#   who/WP
#   we/PRP
#   are/VBP
#   and/CC
#   how/WRB
#   we/PRP
#   treat/VBP
#   one/CD
#   another/DT
#   ./.)
# (S
#   So/IN
#   we/PRP
#   strive/VBP
#   to/TO
#   be/VB
#   a/DT
#   compassionate/NN
#   ,/,
#   decent/NN
#   ,/,
#   hopeful/JJ
#   society/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   (NE America/NNP)
#   has/VBZ
#   become/VBN
#   a/DT
#   more/RBR
#   hopeful/JJ
#   nation/NN
#   ./.)
# (S
#   Violent/JJ
#   crime/NN
#   rates/NNS
#   have/VBP
#   fallen/VBN
#   to/TO
#   their/PRP$
#   lowest/JJS
#   levels/NNS
#   since/IN
#   the/DT
#   1970s/CD
#   ./.)
# (S
#   (NE Welfare/NN)
#   cases/NNS
#   have/VBP
#   dropped/VBN
#   by/IN
#   more/JJR
#   than/IN
#   half/NN
#   over/IN
#   the/DT
#   past/JJ
#   decade/NN
#   ./.)
# (S
#   (NE Drug/NN)
#   use/NN
#   among/IN
#   youth/NN
#   is/VBZ
#   down/RB
#   19/CD
#   percent/NN
#   since/IN
#   2001/CD
#   ./.)
# (S
#   There/EX
#   are/VBP
#   fewer/JJR
#   abortions/NNS
#   in/IN
#   (NE America/NNP)
#   than/IN
#   at/IN
#   any/DT
#   point/NN
#   in/IN
#   the/DT
#   last/JJ
#   three/CD
#   decades/NNS
#   ,/,
#   and/CC
#   the/DT
#   number/NN
#   of/IN
#   children/NNS
#   born/VBN
#   to/TO
#   teenage/VB
#   mothers/NNS
#   has/VBZ
#   been/VBN
#   falling/VBG
#   for/IN
#   a/DT
#   dozen/NN
#   years/NNS
#   in/IN
#   a/DT
#   row/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   These/DT
#   gains/NNS
#   are/VBP
#   evidence/NN
#   of/IN
#   a/DT
#   quiet/JJ
#   transformation/NN
#   --/:
#   a/DT
#   revolution/NN
#   of/IN
#   conscience/NN
#   ,/,
#   in/IN
#   which/WDT
#   a/DT
#   rising/VBG
#   generation/NN
#   is/VBZ
#   finding/VBG
#   that/IN
#   a/DT
#   life/NN
#   of/IN
#   personal/JJ
#   responsibility/NN
#   is/VBZ
#   a/DT
#   life/NN
#   of/IN
#   fulfillment/NN
#   ./.)
# (S Government/NNP has/VBZ played/VBN a/DT role/NN ./.)
# (S
#   (NE Wise/NNP)
#   policies/NNS
#   ,/,
#   such/JJ
#   as/IN
#   welfare/NN
#   reform/NN
#   and/CC
#   drug/NN
#   education/NN
#   and/CC
#   support/NN
#   for/IN
#   abstinence/NN
#   and/CC
#   adoption/NN
#   have/VBP
#   made/VBN
#   a/DT
#   difference/NN
#   in/IN
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   And/CC
#   everyone/NN
#   here/RB
#   tonight/RB
#   ,/,
#   (NE Democrat/NNP)
#   and/CC
#   (NE Republican/NNP)
#   ,/,
#   has/VBZ
#   a/DT
#   right/NN
#   to/TO
#   be/VB
#   proud/JJ
#   of/IN
#   this/DT
#   record/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   many/JJ
#   Americans/NNPS
#   ,/,
#   especially/RB
#   parents/NNS
#   ,/,
#   still/RB
#   have/VBP
#   deep/JJ
#   concerns/NNS
#   about/IN
#   the/DT
#   direction/NN
#   of/IN
#   our/PRP$
#   culture/NN
#   ,/,
#   and/CC
#   the/DT
#   health/NN
#   of/IN
#   our/PRP$
#   most/JJS
#   basic/JJ
#   institutions/NNS
#   ./.)
# (S
#   They/PRP
#   're/VBP
#   concerned/VBN
#   about/IN
#   unethical/JJ
#   conduct/NN
#   by/IN
#   public/JJ
#   officials/NNS
#   ,/,
#   and/CC
#   discouraged/VBN
#   by/IN
#   activist/NN
#   courts/NNS
#   that/WDT
#   try/VBP
#   to/TO
#   redefine/VB
#   marriage/NN
#   ./.)
# (S
#   They/PRP
#   worry/VBP
#   about/IN
#   children/NNS
#   in/IN
#   our/PRP$
#   society/NN
#   who/WP
#   need/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ,/,
#   and/CC
#   about/IN
#   fellow/JJ
#   citizens/NNS
#   still/RB
#   displaced/VBN
#   by/IN
#   natural/JJ
#   disaster/NN
#   ,/,
#   and/CC
#   about/IN
#   suffering/VBG
#   caused/VBN
#   by/IN
#   treatable/JJ
#   diseases/NNS
#   ./.)
# (S
#   As/IN
#   we/PRP
#   look/VBP
#   at/IN
#   these/DT
#   challenges/NNS
#   ,/,
#   we/PRP
#   must/MD
#   never/RB
#   give/VB
#   in/IN
#   to/TO
#   the/DT
#   belief/NN
#   that/IN
#   (NE America/NNP)
#   is/VBZ
#   in/IN
#   decline/NN
#   ,/,
#   or/CC
#   that/IN
#   our/PRP$
#   culture/NN
#   is/VBZ
#   doomed/VBN
#   to/TO
#   unravel/VB
#   ./.)
# (S
#   The/DT
#   (NE American/JJ)
#   people/NNS
#   know/VBP
#   better/JJR
#   than/IN
#   that/DT
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   proven/VBN
#   the/DT
#   pessimists/NNS
#   wrong/JJ
#   before/RB
#   --/:
#   and/CC
#   we/PRP
#   will/MD
#   do/VB
#   it/PRP
#   again/RB
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   depends/VBZ
#   on/IN
#   courts/NNS
#   that/IN
#   deliver/VBP
#   equal/JJ
#   justice/NN
#   under/IN
#   the/DT
#   law/NN
#   ./.)
# (S
#   The/DT
#   (NE Supreme/NNP Court/NNP)
#   now/RB
#   has/VBZ
#   two/CD
#   superb/JJ
#   new/JJ
#   members/NNS
#   --/:
#   new/JJ
#   members/NNS
#   on/IN
#   its/PRP$
#   bench/NN
#   :/:
#   Chief/JJ
#   Justice/NNP
#   (NE John/NNP Roberts/NNP)
#   and/CC
#   (NE Justice/NNP Sam/NNP Alito/NNP)
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   I/PRP
#   thank/VBD
#   the/DT
#   (NE Senate/NNP)
#   for/IN
#   confirming/VBG
#   both/DT
#   of/IN
#   them/PRP
#   ./.)
# (S
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   nominate/VB
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   understand/VBP
#   that/IN
#   judges/NNS
#   must/MD
#   be/VB
#   servants/NNS
#   of/IN
#   the/DT
#   law/NN
#   ,/,
#   and/CC
#   not/RB
#   legislate/VB
#   from/IN
#   the/DT
#   bench/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Today/NN
#   marks/VBZ
#   the/DT
#   official/JJ
#   retirement/NN
#   of/IN
#   a/DT
#   very/RB
#   special/JJ
#   (NE American/NNP)
#   ./.)
# (S
#   For/IN
#   24/CD
#   years/NNS
#   of/IN
#   faithful/JJ
#   service/NN
#   to/TO
#   our/PRP$
#   nation/NN
#   ,/,
#   the/DT
#   (NE United/NNP States/NNPS)
#   is/VBZ
#   grateful/JJ
#   to/TO
#   (NE Justice/NNP Sandra/NNP)
#   Day/NNP
#   O'Connor/NNP
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   has/VBZ
#   institutions/NNS
#   of/IN
#   science/NN
#   and/CC
#   medicine/NN
#   that/WDT
#   do/VBP
#   not/RB
#   cut/VB
#   ethical/JJ
#   corners/NNS
#   ,/,
#   and/CC
#   that/IN
#   recognize/VBP
#   the/DT
#   matchless/NN
#   value/NN
#   of/IN
#   every/DT
#   life/NN
#   ./.)
# (S
#   Tonight/NNP
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   pass/VB
#   legislation/NN
#   to/TO
#   prohibit/VB
#   the/DT
#   most/RBS
#   egregious/JJ
#   abuses/NNS
#   of/IN
#   medical/JJ
#   research/NN
#   :/:
#   human/JJ
#   cloning/VBG
#   in/IN
#   all/DT
#   its/PRP$
#   forms/NNS
#   ,/,
#   creating/VBG
#   or/CC
#   implanting/VBG
#   embryos/NN
#   for/IN
#   experiments/NNS
#   ,/,
#   creating/VBG
#   human-animal/JJ
#   hybrids/NNS
#   ,/,
#   and/CC
#   buying/NN
#   ,/,
#   selling/NN
#   ,/,
#   or/CC
#   patenting/VBG
#   human/JJ
#   embryos/NN
#   ./.)
# (S
#   (NE Human/NNP)
#   life/NN
#   is/VBZ
#   a/DT
#   gift/NN
#   from/IN
#   our/PRP$
#   Creator/NNP
#   --/:
#   and/CC
#   that/IN
#   gift/NN
#   should/MD
#   never/RB
#   be/VB
#   discarded/VBN
#   ,/,
#   devalued/VBD
#   or/CC
#   put/VB
#   up/RP
#   for/IN
#   sale/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   expects/VBZ
#   elected/VBN
#   officials/NNS
#   to/TO
#   uphold/VB
#   the/DT
#   public/JJ
#   trust/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   Honorable/JJ
#   people/NNS
#   in/IN
#   both/DT
#   parties/NNS
#   are/VBP
#   working/VBG
#   on/IN
#   reforms/NNS
#   to/TO
#   strengthen/VB
#   the/DT
#   ethical/JJ
#   standards/NNS
#   of/IN
#   (NE Washington/NNP)
#   --/:
#   I/PRP
#   support/VBP
#   your/PRP$
#   efforts/NNS
#   ./.)
# (S
#   Each/DT
#   of/IN
#   us/PRP
#   has/VBZ
#   made/VBN
#   a/DT
#   pledge/NN
#   to/TO
#   be/VB
#   worthy/JJ
#   of/IN
#   public/JJ
#   responsibility/NN
#   --/:
#   and/CC
#   that/DT
#   is/VBZ
#   a/DT
#   pledge/NN
#   we/PRP
#   must/MD
#   never/RB
#   forget/VB
#   ,/,
#   never/RB
#   dismiss/NN
#   ,/,
#   and/CC
#   never/RB
#   betray/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   As/IN
#   we/PRP
#   renew/VBP
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   institutions/NNS
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   show/VBP
#   the/DT
#   character/NN
#   of/IN
#   (NE America/NNP)
#   in/IN
#   our/PRP$
#   compassion/NN
#   and/CC
#   care/NN
#   for/IN
#   one/CD
#   another/DT
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   gives/VBZ
#   special/JJ
#   attention/NN
#   to/TO
#   children/NNS
#   who/WP
#   lack/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ./.)
# (S
#   Through/IN
#   the/DT
#   Helping/NNP
#   America/NNP
#   's/POS
#   (NE Youth/NNP Initiative/NNP)
#   ,/,
#   we/PRP
#   are/VBP
#   encouraging/VBG
#   caring/VBG
#   adults/NNS
#   to/TO
#   get/VB
#   involved/VBN
#   in/IN
#   the/DT
#   life/NN
#   of/IN
#   a/DT
#   child/NN
#   --/:
#   and/CC
#   this/DT
#   good/JJ
#   work/NN
#   is/VBZ
#   being/VBG
#   led/VBN
#   by/IN
#   our/PRP$
#   First/NNP
#   Lady/NNP
#   ,/,
#   (NE Laura/NNP Bush/NNP)
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   This/DT
#   year/NN
#   we/PRP
#   will/MD
#   add/VB
#   resources/NNS
#   to/TO
#   encourage/VB
#   young/JJ
#   people/NNS
#   to/TO
#   stay/VB
#   in/IN
#   school/NN
#   ,/,
#   so/RB
#   more/JJR
#   of/IN
#   (NE America/NNP)
#   's/POS
#   youth/NN
#   can/MD
#   raise/VB
#   their/PRP$
#   sights/NNS
#   and/CC
#   achieve/VBP
#   their/PRP$
#   dreams/NNS
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   comes/VBZ
#   to/TO
#   the/DT
#   aid/NN
#   of/IN
#   fellow/JJ
#   citizens/NNS
#   in/IN
#   times/NNS
#   of/IN
#   suffering/NN
#   and/CC
#   emergency/NN
#   --/:
#   and/CC
#   stays/NNS
#   at/IN
#   it/PRP
#   until/IN
#   they/PRP
#   're/VBP
#   back/RB
#   on/IN
#   their/PRP$
#   feet/NNS
#   ./.)
# (S
#   So/RB
#   far/RB
#   the/DT
#   federal/JJ
#   government/NN
#   has/VBZ
#   committed/VBN
#   $/$
#   85/CD
#   billion/CD
#   to/TO
#   the/DT
#   people/NNS
#   of/IN
#   the/DT
#   Gulf/NNP
#   Coast/NNP
#   and/CC
#   (NE New/NNP Orleans/NNP)
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   removing/VBG
#   debris/NN
#   and/CC
#   repairing/NN
#   highways/NNS
#   and/CC
#   rebuilding/VBG
#   stronger/JJR
#   levees/NNS
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   providing/VBG
#   business/NN
#   loans/NNS
#   and/CC
#   housing/NN
#   assistance/NN
#   ./.)
# (S
#   Yet/RB
#   as/IN
#   we/PRP
#   meet/VBP
#   these/DT
#   immediate/JJ
#   needs/NNS
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   address/VB
#   deeper/JJR
#   challenges/NNS
#   that/WDT
#   existed/VBD
#   before/IN
#   the/DT
#   storm/NN
#   arrived/VBD
#   ./.)
# (S
#   In/IN
#   (NE New/NNP Orleans/NNP)
#   and/CC
#   in/IN
#   other/JJ
#   places/NNS
#   ,/,
#   many/JJ
#   of/IN
#   our/PRP$
#   fellow/JJ
#   citizens/NNS
#   have/VBP
#   felt/VBN
#   excluded/VBN
#   from/IN
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   The/DT
#   answer/NN
#   is/VBZ
#   not/RB
#   only/RB
#   temporary/JJ
#   relief/NN
#   ,/,
#   but/CC
#   schools/NNS
#   that/WDT
#   teach/VBP
#   every/DT
#   child/NN
#   ,/,
#   and/CC
#   job/NN
#   skills/NNS
#   that/IN
#   bring/VBG
#   upward/JJ
#   mobility/NN
#   ,/,
#   and/CC
#   more/JJR
#   opportunities/NNS
#   to/TO
#   own/VB
#   a/DT
#   home/NN
#   and/CC
#   start/VB
#   a/DT
#   business/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   recover/VBP
#   from/IN
#   a/DT
#   disaster/NN
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   work/NN
#   for/IN
#   the/DT
#   day/NN
#   when/WRB
#   all/DT
#   Americans/NNPS
#   are/VBP
#   protected/VBN
#   by/IN
#   justice/NN
#   ,/,
#   equal/JJ
#   in/IN
#   hope/NN
#   ,/,
#   and/CC
#   rich/JJ
#   in/IN
#   opportunity/NN
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   acts/NNS
#   boldly/RB
#   to/TO
#   fight/VB
#   diseases/NNS
#   like/IN
#   HIV/AIDS/NNP
#   ,/,
#   which/WDT
#   can/MD
#   be/VB
#   prevented/VBN
#   ,/,
#   and/CC
#   treated/VBD
#   ,/,
#   and/CC
#   defeated/VBD
#   ./.)
# (S
#   More/JJR
#   than/IN
#   a/DT
#   million/CD
#   Americans/NNPS
#   live/VBP
#   with/IN
#   (NE HIV/NNP)
#   ,/,
#   and/CC
#   half/NN
#   of/IN
#   all/DT
#   AIDS/NNP
#   cases/NNS
#   occur/VBP
#   among/IN
#   (NE African/JJ Americans/NNPS)
#   ./.)
# (S
#   I/PRP
#   ask/VBP
#   (NE Congress/NNP)
#   to/TO
#   reform/VB
#   and/CC
#   reauthorize/VB
#   the/DT
#   (NE Ryan/NNP White/NNP Act/NNP)
#   ,/,
#   and/CC
#   provide/VB
#   new/JJ
#   funding/NN
#   to/TO
#   states/NNS
#   ,/,
#   so/IN
#   we/PRP
#   end/VBP
#   the/DT
#   waiting/NN
#   lists/NNS
#   for/IN
#   (NE AIDS/NNP)
#   medicines/NNS
#   in/IN
#   (NE America/NNP)
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   also/RB
#   lead/VB
#   a/DT
#   nationwide/JJ
#   effort/NN
#   ,/,
#   working/VBG
#   closely/RB
#   with/IN
#   (NE African/JJ)
#   (NE American/JJ)
#   churches/NNS
#   and/CC
#   faith-based/JJ
#   groups/NNS
#   ,/,
#   to/TO
#   deliver/VB
#   rapid/JJ
#   HIV/NNP
#   tests/NNS
#   to/TO
#   millions/NNS
#   ,/,
#   end/VBP
#   the/DT
#   stigma/NN
#   of/IN
#   (NE AIDS/NNP)
#   ,/,
#   and/CC
#   come/VB
#   closer/JJR
#   to/TO
#   the/DT
#   day/NN
#   when/WRB
#   there/EX
#   are/VBP
#   no/DT
#   new/JJ
#   infections/NNS
#   in/IN
#   (NE America/NNP)
#   ./.)
# (S (/( (NE Applause/NNP) ./. )/))
# (S
#   (NE Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   've/VBP
#   been/VBN
#   called/VBN
#   to/TO
#   leadership/NN
#   in/IN
#   a/DT
#   period/NN
#   of/IN
#   consequence/NN
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   entered/VBN
#   a/DT
#   great/JJ
#   ideological/JJ
#   conflict/NN
#   we/PRP
#   did/VBD
#   nothing/NN
#   to/TO
#   invite/VB
#   ./.)
# (S
#   We/PRP
#   see/VBP
#   great/JJ
#   changes/NNS
#   in/IN
#   science/NN
#   and/CC
#   commerce/NN
#   that/WDT
#   will/MD
#   influence/VB
#   all/DT
#   our/PRP$
#   lives/NNS
#   ./.)
# (S
#   Sometimes/RB
#   it/PRP
#   can/MD
#   seem/VB
#   that/DT
#   history/NN
#   is/VBZ
#   turning/VBG
#   in/IN
#   a/DT
#   wide/JJ
#   arc/NN
#   ,/,
#   toward/IN
#   an/DT
#   unknown/JJ
#   shore/NN
#   ./.)
# (S
#   Yet/CC
#   the/DT
#   destination/NN
#   of/IN
#   history/NN
#   is/VBZ
#   determined/VBN
#   by/IN
#   human/JJ
#   action/NN
#   ,/,
#   and/CC
#   every/DT
#   great/JJ
#   movement/NN
#   of/IN
#   history/NN
#   comes/VBZ
#   to/TO
#   a/DT
#   point/NN
#   of/IN
#   choosing/NN
#   ./.)
# (S
#   (NE Lincoln/NNP)
#   could/MD
#   have/VB
#   accepted/VBN
#   peace/NN
#   at/IN
#   the/DT
#   cost/NN
#   of/IN
#   disunity/NN
#   and/CC
#   continued/JJ
#   slavery/NN
#   ./.)
# (S
#   (NE Martin/NNP Luther/NNP King/NNP)
#   could/MD
#   have/VB
#   stopped/VBN
#   at/IN
#   (NE Birmingham/NNP)
#   or/CC
#   at/IN
#   (NE Selma/NNP)
#   ,/,
#   and/CC
#   achieved/VBD
#   only/RB
#   half/PDT
#   a/DT
#   victory/NN
#   over/IN
#   segregation/NN
#   ./.)
# (S
#   The/DT
#   (NE United/NNP States/NNPS)
#   could/MD
#   have/VB
#   accepted/VBN
#   the/DT
#   permanent/JJ
#   division/NN
#   of/IN
#   (NE Europe/NNP)
#   ,/,
#   and/CC
#   been/VBN
#   complicit/NNS
#   in/IN
#   the/DT
#   oppression/NN
#   of/IN
#   others/NNS
#   ./.)
# (S
#   Today/NN
#   ,/,
#   having/VBG
#   come/VBN
#   far/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   historical/JJ
#   journey/NN
#   ,/,
#   we/PRP
#   must/MD
#   decide/VB
#   :/:
#   Will/MD
#   we/PRP
#   turn/VB
#   back/RP
#   ,/,
#   or/CC
#   finish/VB
#   well/RB
#   ?/.)
# (S
#   Before/IN
#   history/NN
#   is/VBZ
#   written/VBN
#   down/RP
#   in/IN
#   books/NNS
#   ,/,
#   it/PRP
#   is/VBZ
#   written/VBN
#   in/IN
#   courage/NN
#   ./.)
# (S
#   Like/IN
#   Americans/NNPS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   will/MD
#   show/VB
#   that/DT
#   courage/NN
#   and/CC
#   we/PRP
#   will/MD
#   finish/VB
#   well/RB
#   ./.)
# (S We/PRP will/MD lead/VB freedom/NN 's/POS advance/NN ./.)
# (S
#   We/PRP
#   will/MD
#   compete/VB
#   and/CC
#   excel/VB
#   in/IN
#   the/DT
#   global/JJ
#   economy/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   renew/VB
#   the/DT
#   defining/VBG
#   moral/JJ
#   commitments/NNS
#   of/IN
#   this/DT
#   land/NN
#   ./.)
# (S
#   And/CC
#   so/RB
#   we/PRP
#   move/VBP
#   forward/RB
#   --/:
#   optimistic/JJ
#   about/IN
#   our/PRP$
#   country/NN
#   ,/,
#   faithful/JJ
#   to/TO
#   its/PRP$
#   cause/NN
#   ,/,
#   and/CC
#   confident/NN
#   of/IN
#   the/DT
#   victories/NNS
#   to/TO
#   come/VB
#   ./.)
# (S May/NNP God/NNP bless/NN (NE America/NNP) ./.)
# (S (/( (NE Applause/NNP) ./. )/))

# %%
from nltk import ne_chunk

ne_sen = "The US President stays in the White House"
ne_tokens = word_tokenize(ne_sen)
ne_tags = nltk.pos_tag(ne_tokens)         # without pos_tags , its hard to detect NER
ne_ner = ne_chunk(ne_tags)

print(ne_ner)       # US: recognised as Organisation, White House: is club together as single entity and recognised as Facility
# Out:
# (S
#   The/DT
#   (ORGANIZATION US/NNP)
#   President/NNP
#   stays/VBZ
#   in/IN
#   the/DT
#   (FACILITY White/NNP House/NNP))

# %% [markdown]
# # 8. Word Embeddings :

# %% [markdown]
# #### Word Embeddings are the texts converted into numbers and there may be different numerical representations of the same text.
# #### word embedding : vector representation of a particular word.

# %% [markdown]
# ### Types : 1.Count Vectorizer ,  2.TF-IDF ,  3.Co-Occurrence matrix, 4.Word2Vec, 5.FastText, 6.Glove

# %% [markdown]
# ## --------

# %% [markdown]
# ### 1.Count-Vectorizer (Bag of Words)

# %%
Bag of word: 
is a important step in text visualization or text preprocessing. 
we convert those texts into integer format before passing to a model.
If we pass in int or float format model will be able to do calculations w.r.t. those texts and
it can use them in a algorithm. Bag of words also called Document matrix.             
It also important for sentiment analysis.

# %%
Steps: 
Cleaning the texts :                                                                                                        
1.lower all texts(words or sentences) (ex: today & Today -model considers in separate way like 2 words)                        
2.Tokenization                                                                                                              
 
Creating Bag of Words (Document matrix) :                                                                                     
3.Histogram (most important step)- means count the frequency(no.) of words present in the sentences.                 
4.sort the Histogram- in descending order(no. of words(counts) greater is up and then lower - lower)                       
5.filter the words- most frequent words(which means we take otherwise remove).                                                 
6.Creating the matrix-> Bag of Words(Document matrix) 
In matrix, most frequent words(sorted words) created as columns and index are sentences. 
This matrix we create and this will be our input data provide to model. 
In sentiment analysis -> 1 more output column is created and other columns are (as input data).
and model will predict for the future data whether data is pos or neg.

# %%
Bag of words - Problem :
1.All words have same importance. 
(all 1 or 0 have same importance, but it should be like more positive more importance 
 than less positive word , similar for negative.)

2.No semantic information preserved.
(if much importance is not given to any words then semantic information is lost 
 for that partiular word in that sentence.)
so we use -- > TF-IDF  for Document matrix , its better than - Bag of Words

# %% [markdown]
# #### Implementation

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

paragraph = """Being unique will require excellence, let us understand what is excellence in more detail. Excellence is a
            self-imposed self-directed life-long process. Excellence is not by accident. It is a process, where an individual,
            organization or nation, continuously strives to better oneself. The performance standards are set by themselves, 
            they work on their dreams with focus and are prepared to take calculated risks and do not get deterred by failures 
            as they move towards their dreams. Then they step up their dreams as they tend to reach the original targets. 
            They strive to work to their potential, in the process, they increase their performance thereby multiplying further
            their potential and this is an unending life cycle phenomenon. They are not in competition with anyone else,
            but themselves. That is the culture of excellence. Let me share an important experience from the life of the father 
            of the nation. Students ought to think and think well. They should do no wrong? Students should do everything to
            build-up a new state of India which would be everybody's pride."""

# 1.Clean the texts(lowering texts , removing stopwords, (,) (.) lemmatizing it or stemming )

ps = PorterStemmer()
lem = WordNetLemmatizer()
sent_token = nltk.sent_tokenize(paragraph)          # 1st tokenize paragraph into sentences

corpus=[]      # after cleaning texts store in it , then we see differnce b/w sent_token and corpus.

for i in range(len(sent_token)):
    review = re.sub('[^a-zA-Z]', ' ', sent_token[i])   # this removes all (,) (.) (?) , punctuations etc. which not reqd.
    review = review.lower()   
    review = review.split()   # getting a list of words
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]  # use -> lem.lemmatize(word)
    review = ' '.join(review)  # after stemming joining all words into review
    corpus.append(review)      # then append to corpus
    
# print(sent_token)     # to check differnece print both -> sent_token  and corpus 
# print(50*"-")        # just to separate both , also we can use -> lemmatization (lem.lemmatize(word)) 
# print(corpus)

# %%
#  Now create  Bag of Words (Document matrix)- model   (it follows steps 3,4,5,6)

from sklearn.feature_extraction.text import CountVectorizer   # count vectorizer - create -> Bag of words (matrix)

cv = CountVectorizer()
x = cv.fit_transform(corpus).toarray()   # fit-transform convert corpus into matrix and toarray() used to see it properly
x.shape
# Out:
# (13, 69)

# %% [markdown]
# ## ------------------

# %% [markdown]
# ### 2.TF-IDF

# %% [markdown]
# TF : Term Frequency,  TF= No. of occurence of a word in doc. / Total no. of words in doc.
# TF-IDF : TF*IDF
#
# some semantic information is preserved as uncommon words are given more importance than common words.
#     Ex: 'She is beautiful'  , beautiful - more importance than 'She' or 'is'.
#
# <img src='TF.PNG'>

# %% [markdown]
# IDF : Inverse Document Frequency.  IDF = log(No. of documents / No.of documents containing that word)
#       here documents=sentence
#
# <img src='IDF.PNG'>

# %%
Steps : 
1.Cleaning the texts. 
2.Creating the TF-IDF model

# %% [markdown]
# #### Implementation

# %%
import nltk 
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer       
from nltk.stem import WordNetLemmatizer

paragraph = """Being unique will require excellence, let us understand what is excellence in more detail. Excellence is a
            self-imposed self-directed life-long process. Excellence is not by accident. It is a process, where an individual,
            organization or nation, continuously strives to better oneself. The performance standards are set by themselves, 
            they work on their dreams with focus and are prepared to take calculated risks and do not get deterred by failures 
            as they move towards their dreams. Then they step up their dreams as they tend to reach the original targets. 
            They strive to work to their potential, in the process, they increase their performance thereby multiplying further
            their potential and this is an unending life cycle phenomenon. They are not in competition with anyone else,
            but themselves. That is the culture of excellence. Let me share an important experience from the life of the father 
            of the nation. Students ought to think and think well. They should do no wrong? Students should do everything to
            build-up a new state of India which would be everybody's pride."""


# 1.Cleaning the texts

ps = PorterStemmer()
lem = WordNetLemmatizer()
sentences = nltk.sent_tokenize(paragraph)

corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [lem.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
# 2.Creating the TF-IDF model

from sklearn.feature_extraction.text import TfidfVectorizer

tv = TfidfVectorizer()
x = tv.fit_transform(corpus).toarray()
x.shape
# Out:
# (13, 69)

# %%
# x = tv.fit(corpus)

# x.vocabulary_      # gives vocabulary

# %% [markdown]
# ## --------------------------

# %% [markdown]
# ### 3. Co-Occurrence matrix with a fixed context window

# %%
Words co-occurrence matrix : 
describes how words occur together that in turn captures the relationships between words. 
Words co-occurrence matrix is computed simply by counting how two or more words occur together in a given corpus.

Ex:
1.penny wise and pound foolish.  
2.a penny saved is a penny earned.

# %% [markdown]
# <img src='co-occurrence-matrix1.png'>

# %%
The table shows that "a" is followed twice by "penny" while words "earned", "saved", and "wise"  
follows "penny" once in our corpus. Thus, "earned" is one out of three times probable to appear after “penny.” 
The count shown is called bigram frequency.
It looks into only the next word from a current word.
Remember this co-occurrence matrix is not the word vector representation that is generally used. 

Instead, this Co-occurrence matrix is decomposed using techniques like PCA, SVD etc. into factors and 
combination of these factors forms the word vector representation.

# %%
*Advantages of Co-occurrence Matrix : 
It preserves the semantic relationship between words. i.e man and woman tend to be closer than man and apple.  
It uses SVD at its core, which produces more accurate word vector representations than existing methods. 
It uses factorization which is a well-defined problem and can be efficiently solved. 
It has to be computed once and can be used anytime once computed. In this sense, it is faster in comparison to others.  
    
*Disadvantages of Co-Occurrence Matrix :        
It requires huge memory to store the co-occurrence matrix.  
But, this problem can be circumvented by factorizing the matrix out of the system, 
for example in Hadoop clusters etc. and can be saved.

# %% [markdown]
# ## ----------------------------

# %% [markdown]
# ### 4. Word2Vec( 1.CBOW , 2.Skip-Gram )

# %% [markdown]
# ### Word2Vec

# %%
Word2Vec can be used to find out the relations between words in a dataset, 
compute the similarity between them, or use the vector representation of those words 
as input for other applications such as text classification or clustering.

For example : 
"dog", "puppy" and "pup" are often used in similar situations, 
with similar surrounding words like "good", "fluffy" or "cute", and 
according to Word2Vec they will therefore share a similar vector representation.

# %% [markdown]
# <img src='word2vec.png'>

# %%
-Word Embedding is used to compute similar words, Create a group of related words, 
Feature for text classification, NLP, Document clustering.  

-Word2vec is a shallow two-layered neural network model to produce word embedding for better word representation.
The shallow neural network consists of the only a hidden layer between input and output 
whereas deep neural network contains multiple hidden layers between input and output. 

-Word2vec represents words in vector space representation. 
Words are represented in the form of vectors and placement is done in such a way that 
similar meaning words appear together and dissimilar words are located far away. 

-Word2vec used 2 architectures Continuous Bag of words (CBOW) and skip gram.

-'CBOW is several times faster than skip gram' 
and provides a better frequency for frequent words whereas                         
skip gram needs a small amount of training data and represents even rare words or phrases.  
 
-In CBOW, the current word is predicted using the window of surrounding context windows.
-Skip-Gram approach is used to predict a sentence given an input word.  
-Skip-gram and CBOW convert unsupervised representation to supervised form for model training.

# %%
We can also use google’s pre-trained model. It contains word vectors for a vocabulary 
of 3 million words trained on around 100 billion words from the google news dataset.

# %% [markdown]
# Downlad from here : https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit

# %% [markdown]
# #### Implementation
#
# written the code only not run that bcoz its an big file.

# %% [markdown]
# from gensim.models import Word2Vec
#
# model = Word2Vec.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True, norm_only=True)

# %% [raw]
# # Here is how you can train your own word vectors using gensim
#
# # sentence_df=[['first','sentence'],['second','sentence']]
# # model2 = Word2Vec(sentences=sentence_df, size=100, window=5, min_count=5, workers=4, sg=0)  # sg=1 : skip-Gram , sg=0 : CBOW

# %% [raw]
# # getting word vectors of a word
# dog = model['dog']
#
# #performing king queen magic
# print(model.most_similar(positive=['woman', 'king'], negative=['man']))
#
# #picking odd one out
# print(model.doesnt_match("breakfast cereal dinner lunch".split()))
#
# #printing similarity index
# print(model.similarity('woman', 'man'))

# %% [markdown]
# ## ---------------------

# %% [markdown]
# ## 5.FastText

# %%
FastText is an extension to Word2Vec proposed by Facebook in 2016. 
Instead of feeding individual words into the Neural Network, 
FastText breaks words into several n-grams (sub-words). 

For ex : the tri-grams for the word apple is app, ppl, and ple 
    (ignoring the starting and ending of boundaries of words). 

The word embedding vector for apple will be the sum of all these n-grams. 
After training the Neural Network, we will have word embeddings for all the n-grams given the training dataset. 
Rare words can now be properly represented since it is highly likely that some of their n-grams also appears in other words.

# %%
# from gensim.models import FastText

# model_ted = FastText(sentences_ted, size=100, window=5, min_count=5, workers=4,sg=1)

# print(model_ted.similarity('woman', 'man'))

# %% [markdown]
# ## ---------------

# %% [markdown]
# ## 6.Glove

# %% [markdown]
# -Word2Vec :
# takes texts as training data for a neural network. The resulting embedding captures whether words appear in similar contexts.
# -GloVe :
# focuses on words co-occurrences matrix over the whole corpus.
# Its embeddings relate to the probabilities that two words appear together.
# -FastText :
# improves on Word2Vec by taking word parts into account, too.
# This trick enables training of embeddings on smaller datasets and generalization to unknown words.
